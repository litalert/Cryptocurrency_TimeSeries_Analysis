# %% [markdown]
# ## Exploratory Data Analysis (EDA) of BTC/ETH prices and GoogleNews search frequency of the word "cryptocurrency"
#
# Due to volatility of crytocurrency market, one might wonder what is the best way to predict the currencies prices. As I came up with the project idea, the preliminary questions I had in mind were:
#
# 1. Is there any obvious correlation/lead-lag relationship between different crytocurrency market prices?
# 2. If the correlation between a pair of currencies A and B existed, can we use currency A price history to predict future price of currency B? Will it be more useful than using just historical prices of currency B alone?
# 3. Does the rise/fall in search frequency of the word "crytocurrency" on GoogleNews imply trading signal?
#
# The following code queries, visualizes, and tests data in order to explore the preliminary questions. The stretch goal is to gain insights beyond preliminary questions that will lead to better data analysis in the future

# %%
# Getting price data of BTC and ETH using Cryptocompare API

import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
import datetime

# Indicate how many rows of data here
lim = '15000' 
story_coin = ['BTC', 'ETH']
story_data = pd.DataFrame()
for i in story_coin:
    URL = 'https://min-api.cryptocompare.com/data/histohour?fsym='+i+'&tsym=USD&limit='+lim
    data = requests.get(URL)
    json_data = data.json()
    table = json_normalize(json_data, 'Data').set_index('time')
    table.index = pd.to_datetime(table.index ,unit='s')
    story_data = pd.concat([story_data, table.high], axis=1)
story_data.columns = story_coin

# %%
# Getting data from Google Trends using Pytrends API

from pytrends.request import TrendReq
# Login to Google. Only need to run this once
pytrend = TrendReq()
# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
# keyword = 'cryptocurrency', cathegory = 16 (news), timeframe- limit range to 8 months to get daily data
pytrend.build_payload(kw_list=['cryptocurrency'], cat=16, timeframe='2017-02-24 2017-10-24')  

story_ggtrends = pytrend.interest_over_time()
# Upsampling daily data to hourly data
story_ggtrends = story_ggtrends.resample('1h').pad().drop(['isPartial'], axis='columns')
story_ggtrends.columns = ['SearchFrequency']

# %%
# Joining two data frames
story_combined = pd.concat([story_data, story_ggtrends], axis=1).dropna(how='any')
story_combined_scaled = story_combined.copy(deep=True)

# %%
# Feature Scaling. This will capture trend information and makes visualization more meaningful
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
story_combined_scaled['BTC'] = sc_x.fit_transform(story_combined_scaled['BTC'].values.reshape(-1,1))
story_combined_scaled['ETH'] = sc_x.fit_transform(story_combined_scaled['ETH'].values.reshape(-1,1))
story_combined_scaled['SearchFrequency'] = sc_x.fit_transform(story_combined_scaled['SearchFrequency'].values.reshape(-1,1))

# %%
# Plot 1- scaled overlay plot of ETC/BTC prices and GoogleNews search frequency data
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.plot(story_combined_scaled.index, story_combined_scaled['ETH'], color='blue')
plt.plot(story_combined_scaled.index, story_combined_scaled['BTC'], color='green')
plt.plot(story_combined_scaled.index, story_combined_scaled['SearchFrequency'], color='red')
#plt.xlim(('2017-07-26', '2017-10-10'))
plt.legend(loc='upper left')
plt.xlabel('Time')
plt.ylabel('Prices & Search Frequency (scaled)')
plt.title('Plot 1')
plt.show()

# %% [markdown]
# From **Plot 1**, I've obsereved the following:
# 1. Sharp rises in search frequency are coupled with price drops
# 2. BTC and ETH prices tend to converge during drops, and not spikes (notice that the series were scaled)

# %%
# Plot 2- scaled overlay plot of ETC/BTC prices and GoogleNews search frequency data in 20 days timespand (during drop)

plt.plot(story_combined_scaled.index, story_combined_scaled['ETH'], color='blue')
plt.plot(story_combined_scaled.index, story_combined_scaled['BTC'], color='green')
plt.plot(story_combined_scaled.index, story_combined_scaled['SearchFrequency'], color='red')
plt.xlim(('2017-09-01', '2017-09-20'))
plt.legend(loc='lower left')
plt.xlabel('Time')
plt.ylabel('Prices & Search Frequency (scaled)')
plt.title('Plot 2')
plt.show()

# %% [markdown]
# According to **Plot 2**, it looks like sharp rise in search frequency leads ETH/BTC price drop. However, this conclusion is based on just 2 events

# %%
# Plot 3- BTC/ETH moving averages (scaled)
import numpy as np
a = 50
b = a-1
def moving_average(a, n):
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

ma_combined = pd.DataFrame()
ma_combined['ETH'] = moving_average(story_combined_scaled['ETH'].values, a)
ma_combined['BTC'] = moving_average(story_combined_scaled['BTC'].values, a)

plt.plot(ma_combined.index, ma_combined['BTC'], color='green', label = 'Avg_BTC')
plt.plot(ma_combined.index, ma_combined['ETH'], color='blue', label = 'Avg_ETH')
plt.legend(loc='upper left')
plt.ylabel('Prices(scaled)')
plt.xlabel('Time')
plt.title('Plot 3')
plt.show()

# %% [markdown]
# Based on **Plot 3** , there seem to be correlation between ETH and BTC prices and that ETH leads BTC. However, Granger Causality Test will be performed to confirm the relationship. There's no obvious trend (varying mean over time) or seasonality (varying variance over time) observed at this range. However, Dickey-Fuller test will be perfrom to confirm stationality of the series.

# %%
# Plot 4- Box plot by hour of the day
from datetime import datetime, timezone
from collections import OrderedDict
from collections import defaultdict

for coin in story_coin:
    group = OrderedDict.fromkeys(story_combined[coin].index.hour)
    group = defaultdict(list)
    for i in story_combined[coin].index:
        group[i.hour].append(story_combined[coin][i])
    lenght = []
    for key in group:
        lenght.append(len(group[key]))
    min_len = min(lenght)
    hour = pd.DataFrame()
    for key, value in group.items():
        hour[key] = value[:min_len]
    hour.boxplot()
    plt.ylabel('Price')
    plt.xlabel('Hours of the Days')
    plt.title('Plot 4-{}'.format(coin), loc='center')
    plt.show()

# %% [markdown]
# **plot 4** shows relatively constant mean, but varying variance throughout hours of the day. However, there's no common patterns observed between BTC and ETH prices stats, which leads me to belive seasonality doesn't exist in these series.

# %%
# Plot 5- Box plot by day of the month
for coin in story_coin:    
    group = OrderedDict.fromkeys(story_combined[coin].index.day)
    group = defaultdict(list)
    for i in story_combined[coin].index:
        group[i.day].append(story_combined[coin][i])
    lenght = []
    for key in group:
        lenght.append(len(group[key]))
    min_len = min(lenght)
    day = pd.DataFrame()
    for key, value in group.items():
        day[key] = value[:min_len]
    

    day.boxplot()
    plt.ylabel('Price')
    plt.xlabel('Days of the Months')
    plt.title('Plot 5-{}'.format(coin), loc='center')
    plt.show()

# %%
# Plot 6- BTC/ETH histogram
n_data = len(story_combined['ETH'])
n_bins = int(np.sqrt(n_data))
plt.subplot(1, 2, 1)
story_combined['ETH'].hist(bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Plot 6- ETH', loc='center')
plt.subplot(1, 2, 2)
story_combined['BTC'].hist(bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Plot 6- BTC', loc='center')
plt.show()

# %% [markdown]
# **Plot 4** shows that ETH has a sharp frequency peak at ~300, while BTC doesn't have such sharp peak. Depending on personal judgement, if the ETH peak was more extream, it might have been helpful to bias the ETH model to 300. Moreover, BTC histrogram is slightly skewed left, which may have implied BTC market is less "stable". We will further explore histograms of both series after differncing to better quantify "stability".

# %%
# Plot 7- BTC/ETH lag1 scatter plot
from pandas.plotting import lag_plot
plt.subplot(1, 2, 1)
lag_plot(story_combined['ETH'])
plt.title('Plot 7- ETH', loc='center')
plt.subplot(1, 2, 2)
lag_plot(story_combined['BTC'])
plt.title('Plot 7- BTC', loc='center')
plt.show()

# %% [markdown]
# **Plot 5** suggests positive correlation between observations and their consecutive observations (y_t and y_t-1) in both BTC and ETH. To further explore the series, we're going to look at Autocorrelation Function (ACF) and Partial Autocorrelation Function (PACF) plots which measure the linear predictability of the series at time t, say x_t, using the value x_s, where s and t denote two valuation points in time. Before we explore ACF and PACF plots, we need to stationarize the series.

# %%
# Result 1- Perform Dickey Fuller Test to determine stationality of BTC and ETC time series
from statsmodels.tsa.stattools import adfuller
x = story_combined['ETH'].values
DF_ETH = adfuller(x)
print('\n')
print('Result 1')
print('\n')
print('ADF Statistic (ETH): %f' % DF_ETH[0])
print('p-value: %f' % DF_ETH[1])
print('Critical Values:')
for key, value in DF_ETH[4].items():
    print('\t%s: %.3f' % (key, value))

y = story_combined['BTC'].values
DF_BTC = adfuller(y)
print('\n')
print('ADF Statistic (BTC): %f' % DF_BTC[0])
print('p-value: %f' % DF_BTC[1])
print('Critical Values:')
for key, value in DF_BTC[4].items():
    print('\t%s: %.3f' % (key, value))
print('\n')
# Out:
# Result 1
#
#
# ADF Statistic (ETH): -3.083591
# p-value: 0.027792
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#
#
# ADF Statistic (BTC): -1.297649
# p-value: 0.630247
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568

# %% [markdown]
# From **Result 1** above, Dickey-Fuller test shows that ETH is a stationary series (~95% confidence level), while BTC is NOT a stationary series. To stationarize the series, we're going to perform differencing. There are combinations of lag difference and difference order we could pick from. First, we're going to take the difference using lag 1 order 1 on both series.

# %%
# Perfrom differencing to stationalize the series

# create a differenced series, with default value of lag 1
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return diff

# difference the dataset
diff_BTC = difference(story_combined['BTC'])
diff_ETH = difference(story_combined['ETH'])

diff_2 = difference(story_combined['ETH'], 2)
diff_24 = difference(story_combined['ETH'], 24)

# invert differenced forecast #
#def inverse_difference(last_ob, value):
#    return value + last_ob
# invert the difference #
#inverted = [inverse_difference(data[i], diff[i]) for i in range(len(diff))]
#print(inverted)

# %%
#diff_BTC = np.diff(story_combined['BTC'], 2)
#diff_ETH = np.diff(story_combined['ETH'], 2)

# %%
# Result 2- Perfrom Dickey-Fuller Test on the differenced series
DF_diff_BTC = adfuller(diff_BTC)
print('\n')
print('Result 2')
print('\n')
print('ADF Statistic (BTC): %f' % DF_diff_BTC[0])
print('p-value: %f' % DF_diff_BTC[1])
print('Critical Values:')
for key, value in DF_diff_BTC[4].items():
    print('\t%s: %.3f' % (key, value))
    
    
DF_diff_ETH = adfuller(diff_ETH)
print('\n')
print('ADF Statistic (ETH): %f' % DF_diff_ETH[0])
print('p-value: %f' % DF_diff_ETH[1])
print('Critical Values:')
for key, value in DF_diff_ETH[4].items():
    print('\t%s: %.3f' % (key, value))
print('\n')
# Out:
# Result 2
#
#
# ADF Statistic (BTC): -40.312685
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#
#
# ADF Statistic (ETH): -13.598337
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568

# %% [markdown]
# Based on **Result 2**, differencing using lag 1 order 1 improved the stationarity. Both BTC and ETH are now stationary series.

# %%
# Plot8- Plotting Histogram of differenced series
n_data = len(diff_ETH)
n_bins = int(np.sqrt(n_data))
plt.subplot(1, 2, 1)
plt.hist(diff_BTC, bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Differenced Price')
plt.title('Plot 8- BTC', loc='center')
plt.subplot(1, 2, 2)
plt.hist(diff_ETH, bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Differenced Price')
plt.title('Plot 8- ETH', loc='center')
plt.show()

# %% [markdown]
# Histogram of the difference, **Plot 6**, shows that the distribution is skewed left. This distribution implies that rising is more rapid than falling. Threshold based on standard deviation of this plot could be used to define "stability" of the series.

# %%
# Result 3- Perfrom Granger Causality Test with the null hypothesis of ETH doesn't Granger cause BTC
import statsmodels.tsa.stattools as sm
diff_BTC_ETH = pd.DataFrame()
diff_BTC_ETH['BTC'] = diff_BTC
diff_BTC_ETH['ETH'] = diff_ETH
print('Result 3')
cor = sm.grangercausalitytests(diff_BTC_ETH, 50)
# Out:
# Result 3
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0036  , p=0.9522  , df_denom=1920, df_num=1
# ssr based chi2 test:   chi2=0.0036  , p=0.9522  , df=1
# likelihood ratio test: chi2=0.0036  , p=0.9522  , df=1
# parameter F test:         F=0.0036  , p=0.9522  , df_denom=1920, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3786  , p=0.6849  , df_denom=1917, df_num=2
# ssr based chi2 test:   chi2=0.7591  , p=0.6842  , df=2
# likelihood ratio test: chi2=0.7590  , p=0.6842  , df=2
# parameter F test:         F=0.3786  , p=0.6849  , df_denom=1917, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3441  , p=0.7934  , df_denom=1914, df_num=3
# ssr based chi2 test:   chi2=1.0361  , p=0.7925  , df=3
# likelihood ratio test: chi2=1.0359  , p=0.7926  , df=3
# parameter F test:         F=0.3441  , p=0.7934  , df_denom=1914, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5505  , p=0.6987  , df_denom=1911, df_num=4
# ssr based chi2 test:   chi2=2.2122  , p=0.6968  , df=4
# likelihood ratio test: chi2=2.2110  , p=0.6970  , df=4
# parameter F test:         F=0.5505  , p=0.6987  , df_denom=1911, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6454  , p=0.6651  , df_denom=1908, df_num=5
# ssr based chi2 test:   chi2=3.2455  , p=0.6622  , df=5
# likelihood ratio test: chi2=3.2428  , p=0.6626  , df=5
# parameter F test:         F=0.6454  , p=0.6651  , df_denom=1908, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5782  , p=0.7480  , df_denom=1905, df_num=6
# ssr based chi2 test:   chi2=3.4932  , p=0.7449  , df=6
# likelihood ratio test: chi2=3.4900  , p=0.7453  , df=6
# parameter F test:         F=0.5782  , p=0.7480  , df_denom=1905, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8414  , p=0.5528  , df_denom=1902, df_num=7
# ssr based chi2 test:   chi2=5.9363  , p=0.5472  , df=7
# likelihood ratio test: chi2=5.9271  , p=0.5483  , df=7
# parameter F test:         F=0.8414  , p=0.5528  , df_denom=1902, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7165  , p=0.6772  , df_denom=1899, df_num=8
# ssr based chi2 test:   chi2=5.7835  , p=0.6715  , df=8
# likelihood ratio test: chi2=5.7748  , p=0.6724  , df=8
# parameter F test:         F=0.7165  , p=0.6772  , df_denom=1899, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8969  , p=0.5271  , df_denom=1896, df_num=9
# ssr based chi2 test:   chi2=8.1530  , p=0.5188  , df=9
# likelihood ratio test: chi2=8.1357  , p=0.5205  , df=9
# parameter F test:         F=0.8969  , p=0.5271  , df_denom=1896, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0612  , p=0.3892  , df_denom=1893, df_num=10
# ssr based chi2 test:   chi2=10.7294 , p=0.3790  , df=10
# likelihood ratio test: chi2=10.6994 , p=0.3814  , df=10
# parameter F test:         F=1.0612  , p=0.3892  , df_denom=1893, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.0275  , p=0.4189  , df_denom=1890, df_num=11
# ssr based chi2 test:   chi2=11.4397 , p=0.4072  , df=11
# likelihood ratio test: chi2=11.4057 , p=0.4099  , df=11
# parameter F test:         F=1.0275  , p=0.4189  , df_denom=1890, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.9603  , p=0.4851  , df_denom=1887, df_num=12
# ssr based chi2 test:   chi2=11.6759 , p=0.4721  , df=12
# likelihood ratio test: chi2=11.6403 , p=0.4750  , df=12
# parameter F test:         F=0.9603  , p=0.4851  , df_denom=1887, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.9218  , p=0.5293  , df_denom=1884, df_num=13
# ssr based chi2 test:   chi2=12.1546 , p=0.5150  , df=13
# likelihood ratio test: chi2=12.1161 , p=0.5182  , df=13
# parameter F test:         F=0.9218  , p=0.5293  , df_denom=1884, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.8788  , p=0.5820  , df_denom=1881, df_num=14
# ssr based chi2 test:   chi2=12.4928 , p=0.5668  , df=14
# likelihood ratio test: chi2=12.4522 , p=0.5700  , df=14
# parameter F test:         F=0.8788  , p=0.5820  , df_denom=1881, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.0026  , p=0.4492  , df_denom=1878, df_num=15
# ssr based chi2 test:   chi2=15.2869 , p=0.4310  , df=15
# likelihood ratio test: chi2=15.2260 , p=0.4353  , df=15
# parameter F test:         F=1.0026  , p=0.4492  , df_denom=1878, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.9627  , p=0.4957  , df_denom=1875, df_num=16
# ssr based chi2 test:   chi2=15.6745 , p=0.4759  , df=16
# likelihood ratio test: chi2=15.6105 , p=0.4805  , df=16
# parameter F test:         F=0.9627  , p=0.4957  , df_denom=1875, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.0786  , p=0.3689  , df_denom=1872, df_num=17
# ssr based chi2 test:   chi2=18.6790 , p=0.3473  , df=17
# likelihood ratio test: chi2=18.5881 , p=0.3527  , df=17
# parameter F test:         F=1.0786  , p=0.3689  , df_denom=1872, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=0.9959  , p=0.4611  , df_denom=1869, df_num=18
# ssr based chi2 test:   chi2=18.2818 , p=0.4372  , df=18
# likelihood ratio test: chi2=18.1947 , p=0.4429  , df=18
# parameter F test:         F=0.9959  , p=0.4611  , df_denom=1869, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=0.9294  , p=0.5456  , df_denom=1866, df_num=19
# ssr based chi2 test:   chi2=18.0274 , p=0.5206  , df=19
# likelihood ratio test: chi2=17.9426 , p=0.5263  , df=19
# parameter F test:         F=0.9294  , p=0.5456  , df_denom=1866, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=0.8980  , p=0.5900  , df_denom=1863, df_num=20
# ssr based chi2 test:   chi2=18.3557 , p=0.5640  , df=20
# likelihood ratio test: chi2=18.2677 , p=0.5698  , df=20
# parameter F test:         F=0.8980  , p=0.5900  , df_denom=1863, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=0.8781  , p=0.6209  , df_denom=1860, df_num=21
# ssr based chi2 test:   chi2=18.8654 , p=0.5938  , df=21
# likelihood ratio test: chi2=18.7725 , p=0.5997  , df=21
# parameter F test:         F=0.8781  , p=0.6209  , df_denom=1860, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=0.8444  , p=0.6708  , df_denom=1857, df_num=22
# ssr based chi2 test:   chi2=19.0275 , p=0.6436  , df=22
# likelihood ratio test: chi2=18.9330 , p=0.6495  , df=22
# parameter F test:         F=0.8444  , p=0.6708  , df_denom=1857, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=0.8219  , p=0.7062  , df_denom=1854, df_num=23
# ssr based chi2 test:   chi2=19.3829 , p=0.6788  , df=23
# likelihood ratio test: chi2=19.2847 , p=0.6846  , df=23
# parameter F test:         F=0.8219  , p=0.7062  , df_denom=1854, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.0427  , p=0.4056  , df_denom=1851, df_num=24
# ssr based chi2 test:   chi2=25.6861 , p=0.3693  , df=24
# likelihood ratio test: chi2=25.5140 , p=0.3783  , df=24
# parameter F test:         F=1.0427  , p=0.4056  , df_denom=1851, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=0.9981  , p=0.4658  , df_denom=1848, df_num=25
# ssr based chi2 test:   chi2=25.6404 , p=0.4270  , df=25
# likelihood ratio test: chi2=25.4689 , p=0.4364  , df=25
# parameter F test:         F=0.9981  , p=0.4658  , df_denom=1848, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=0.9976  , p=0.4673  , df_denom=1845, df_num=26
# ssr based chi2 test:   chi2=26.6825 , p=0.4261  , df=26
# likelihood ratio test: chi2=26.4967 , p=0.4361  , df=26
# parameter F test:         F=0.9976  , p=0.4673  , df_denom=1845, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=0.9679  , p=0.5116  , df_denom=1842, df_num=27
# ssr based chi2 test:   chi2=26.9139 , p=0.4684  , df=27
# likelihood ratio test: chi2=26.7247 , p=0.4787  , df=27
# parameter F test:         F=0.9679  , p=0.5116  , df_denom=1842, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=0.9084  , p=0.6039  , df_denom=1839, df_num=28
# ssr based chi2 test:   chi2=26.2227 , p=0.5608  , df=28
# likelihood ratio test: chi2=26.0430 , p=0.5707  , df=28
# parameter F test:         F=0.9084  , p=0.6039  , df_denom=1839, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=0.9534  , p=0.5371  , df_denom=1836, df_num=29
# ssr based chi2 test:   chi2=28.5362 , p=0.4894  , df=29
# likelihood ratio test: chi2=28.3234 , p=0.5007  , df=29
# parameter F test:         F=0.9534  , p=0.5371  , df_denom=1836, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=0.9104  , p=0.6065  , df_denom=1833, df_num=30
# ssr based chi2 test:   chi2=28.2219 , p=0.5587  , df=30
# likelihood ratio test: chi2=28.0137 , p=0.5697  , df=30
# parameter F test:         F=0.9104  , p=0.6065  , df_denom=1833, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=0.9324  , p=0.5742  , df_denom=1830, df_num=31
# ssr based chi2 test:   chi2=29.8990 , p=0.5225  , df=31
# likelihood ratio test: chi2=29.6653 , p=0.5346  , df=31
# parameter F test:         F=0.9324  , p=0.5742  , df_denom=1830, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=0.9512  , p=0.5458  , df_denom=1827, df_num=32
# ssr based chi2 test:   chi2=31.5213 , p=0.4907  , df=32
# likelihood ratio test: chi2=31.2616 , p=0.5038  , df=32
# parameter F test:         F=0.9512  , p=0.5458  , df_denom=1827, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=0.9933  , p=0.4789  , df_denom=1824, df_num=33
# ssr based chi2 test:   chi2=33.9819 , p=0.4201  , df=33
# likelihood ratio test: chi2=33.6802 , p=0.4344  , df=33
# parameter F test:         F=0.9933  , p=0.4789  , df_denom=1824, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=0.9716  , p=0.5152  , df_denom=1821, df_num=34
# ssr based chi2 test:   chi2=34.2863 , p=0.4540  , df=34
# likelihood ratio test: chi2=33.9790 , p=0.4687  , df=34
# parameter F test:         F=0.9716  , p=0.5152  , df_denom=1821, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.1271  , p=0.2803  , df_denom=1818, df_num=35
# ssr based chi2 test:   chi2=40.9878 , p=0.2245  , df=35
# likelihood ratio test: chi2=40.5494 , p=0.2389  , df=35
# parameter F test:         F=1.1271  , p=0.2803  , df_denom=1818, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.1661  , p=0.2305  , df_denom=1815, df_num=36
# ssr based chi2 test:   chi2=43.6695 , p=0.1777  , df=36
# likelihood ratio test: chi2=43.1722 , p=0.1915  , df=36
# parameter F test:         F=1.1661  , p=0.2305  , df_denom=1815, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.1517  , p=0.2452  , df_denom=1812, df_num=37
# ssr based chi2 test:   chi2=44.3775 , p=0.1887  , df=37
# likelihood ratio test: chi2=43.8637 , p=0.2033  , df=37
# parameter F test:         F=1.1517  , p=0.2452  , df_denom=1812, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.1556  , p=0.2383  , df_denom=1809, df_num=38
# ssr based chi2 test:   chi2=45.7808 , p=0.1805  , df=38
# likelihood ratio test: chi2=45.2340 , p=0.1955  , df=38
# parameter F test:         F=1.1556  , p=0.2383  , df_denom=1809, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.1299  , p=0.2688  , df_denom=1806, df_num=39
# ssr based chi2 test:   chi2=45.9928 , p=0.2051  , df=39
# likelihood ratio test: chi2=45.4407 , p=0.2215  , df=39
# parameter F test:         F=1.1299  , p=0.2688  , df_denom=1806, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.1179  , p=0.2833  , df_denom=1803, df_num=40
# ssr based chi2 test:   chi2=46.7230 , p=0.2157  , df=40
# likelihood ratio test: chi2=46.1530 , p=0.2329  , df=40
# parameter F test:         F=1.1179  , p=0.2833  , df_denom=1803, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.0989  , p=0.3089  , df_denom=1800, df_num=41
# ssr based chi2 test:   chi2=47.1304 , p=0.2361  , df=41
# likelihood ratio test: chi2=46.5502 , p=0.2546  , df=41
# parameter F test:         F=1.0989  , p=0.3089  , df_denom=1800, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.0596  , p=0.3690  , df_denom=1797, df_num=42
# ssr based chi2 test:   chi2=46.6079 , p=0.2885  , df=42
# likelihood ratio test: chi2=46.0401 , p=0.3086  , df=42
# parameter F test:         F=1.0596  , p=0.3690  , df_denom=1797, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.0835  , p=0.3295  , df_denom=1794, df_num=43
# ssr based chi2 test:   chi2=48.8506 , p=0.2497  , df=43
# likelihood ratio test: chi2=48.2271 , p=0.2697  , df=43
# parameter F test:         F=1.0835  , p=0.3295  , df_denom=1794, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.1331  , p=0.2551  , df_denom=1791, df_num=44
# ssr based chi2 test:   chi2=52.3358 , p=0.1819  , df=44
# likelihood ratio test: chi2=51.6206 , p=0.2005  , df=44
# parameter F test:         F=1.1331  , p=0.2551  , df_denom=1791, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.0985  , p=0.3036  , df_denom=1788, df_num=45
# ssr based chi2 test:   chi2=51.9507 , p=0.2214  , df=45
# likelihood ratio test: chi2=51.2455 , p=0.2421  , df=45
# parameter F test:         F=1.0985  , p=0.3036  , df_denom=1788, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.1476  , p=0.2320  , df_denom=1785, df_num=46
# ssr based chi2 test:   chi2=55.5386 , p=0.1583  , df=46
# likelihood ratio test: chi2=54.7333 , p=0.1769  , df=46
# parameter F test:         F=1.1476  , p=0.2320  , df_denom=1785, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.1582  , p=0.2163  , df_denom=1782, df_num=47
# ssr based chi2 test:   chi2=57.3391 , p=0.1435  , df=47
# likelihood ratio test: chi2=56.4808 , p=0.1619  , df=47
# parameter F test:         F=1.1582  , p=0.2163  , df_denom=1782, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.1634  , p=0.2078  , df_denom=1779, df_num=48
# ssr based chi2 test:   chi2=58.8900 , p=0.1348  , df=48
# likelihood ratio test: chi2=57.9846 , p=0.1532  , df=48
# parameter F test:         F=1.1634  , p=0.2078  , df_denom=1779, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.1583  , p=0.2123  , df_denom=1776, df_num=49
# ssr based chi2 test:   chi2=59.9230 , p=0.1363  , df=49
# likelihood ratio test: chi2=58.9854 , p=0.1554  , df=49
# parameter F test:         F=1.1583  , p=0.2123  , df_denom=1776, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.2278  , p=0.1338  , df_denom=1773, df_num=50
# ssr based chi2 test:   chi2=64.8892 , p=0.0767  , df=50
# likelihood ratio test: chi2=63.7910 , p=0.0910  , df=50
# parameter F test:         F=1.2278  , p=0.1338  , df_denom=1773, df_num=50

# %%
# Result 4- Perform Granger Causality Test with the null hypothesis of BTC doesn't Granger cause ETH
diff_ETH_BTC = pd.DataFrame()
diff_ETH_BTC['ETH'] = diff_ETH
diff_ETH_BTC['BTC'] = diff_BTC
print('Result 4')
cor = sm.grangercausalitytests(diff_ETH_BTC, 50)
# Out:
# Result 4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.9868  , p=0.0841  , df_denom=1920, df_num=1
# ssr based chi2 test:   chi2=2.9915  , p=0.0837  , df=1
# likelihood ratio test: chi2=2.9891  , p=0.0838  , df=1
# parameter F test:         F=2.9868  , p=0.0841  , df_denom=1920, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7304  , p=0.1775  , df_denom=1917, df_num=2
# ssr based chi2 test:   chi2=3.4698  , p=0.1764  , df=2
# likelihood ratio test: chi2=3.4667  , p=0.1767  , df=2
# parameter F test:         F=1.7304  , p=0.1775  , df_denom=1917, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2205  , p=0.3007  , df_denom=1914, df_num=3
# ssr based chi2 test:   chi2=3.6748  , p=0.2988  , df=3
# likelihood ratio test: chi2=3.6713  , p=0.2992  , df=3
# parameter F test:         F=1.2205  , p=0.3007  , df_denom=1914, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=5.0630  , p=0.0005  , df_denom=1911, df_num=4
# ssr based chi2 test:   chi2=20.3475 , p=0.0004  , df=4
# likelihood ratio test: chi2=20.2404 , p=0.0004  , df=4
# parameter F test:         F=5.0630  , p=0.0005  , df_denom=1911, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.5253  , p=0.0004  , df_denom=1908, df_num=5
# ssr based chi2 test:   chi2=22.7572 , p=0.0004  , df=5
# likelihood ratio test: chi2=22.6233 , p=0.0004  , df=5
# parameter F test:         F=4.5253  , p=0.0004  , df_denom=1908, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.6709  , p=0.0013  , df_denom=1905, df_num=6
# ssr based chi2 test:   chi2=22.1757 , p=0.0011  , df=6
# likelihood ratio test: chi2=22.0484 , p=0.0012  , df=6
# parameter F test:         F=3.6709  , p=0.0013  , df_denom=1905, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.3538  , p=0.0015  , df_denom=1902, df_num=7
# ssr based chi2 test:   chi2=23.6618 , p=0.0013  , df=7
# likelihood ratio test: chi2=23.5169 , p=0.0014  , df=7
# parameter F test:         F=3.3538  , p=0.0015  , df_denom=1902, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.9241  , p=0.0030  , df_denom=1899, df_num=8
# ssr based chi2 test:   chi2=23.6026 , p=0.0027  , df=8
# likelihood ratio test: chi2=23.4584 , p=0.0028  , df=8
# parameter F test:         F=2.9241  , p=0.0030  , df_denom=1899, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.7174  , p=0.0038  , df_denom=1896, df_num=9
# ssr based chi2 test:   chi2=24.7014 , p=0.0033  , df=9
# likelihood ratio test: chi2=24.5434 , p=0.0035  , df=9
# parameter F test:         F=2.7174  , p=0.0038  , df_denom=1896, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.6184  , p=0.0037  , df_denom=1893, df_num=10
# ssr based chi2 test:   chi2=26.4741 , p=0.0032  , df=10
# likelihood ratio test: chi2=26.2927 , p=0.0034  , df=10
# parameter F test:         F=2.6184  , p=0.0037  , df_denom=1893, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.3155  , p=0.0081  , df_denom=1890, df_num=11
# ssr based chi2 test:   chi2=25.7801 , p=0.0070  , df=11
# likelihood ratio test: chi2=25.6080 , p=0.0074  , df=11
# parameter F test:         F=2.3155  , p=0.0081  , df_denom=1890, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.2608  , p=0.0077  , df_denom=1887, df_num=12
# ssr based chi2 test:   chi2=27.4890 , p=0.0066  , df=12
# likelihood ratio test: chi2=27.2933 , p=0.0070  , df=12
# parameter F test:         F=2.2608  , p=0.0077  , df_denom=1887, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=2.2669  , p=0.0059  , df_denom=1884, df_num=13
# ssr based chi2 test:   chi2=29.8922 , p=0.0049  , df=13
# likelihood ratio test: chi2=29.6608 , p=0.0053  , df=13
# parameter F test:         F=2.2669  , p=0.0059  , df_denom=1884, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=2.1616  , p=0.0074  , df_denom=1881, df_num=14
# ssr based chi2 test:   chi2=30.7292 , p=0.0060  , df=14
# likelihood ratio test: chi2=30.4846 , p=0.0065  , df=14
# parameter F test:         F=2.1616  , p=0.0074  , df_denom=1881, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=2.0629  , p=0.0094  , df_denom=1878, df_num=15
# ssr based chi2 test:   chi2=31.4540 , p=0.0076  , df=15
# likelihood ratio test: chi2=31.1977 , p=0.0083  , df=15
# parameter F test:         F=2.0629  , p=0.0094  , df_denom=1878, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.9916  , p=0.0109  , df_denom=1875, df_num=16
# ssr based chi2 test:   chi2=32.4268 , p=0.0088  , df=16
# likelihood ratio test: chi2=32.1543 , p=0.0095  , df=16
# parameter F test:         F=1.9916  , p=0.0109  , df_denom=1875, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.8409  , p=0.0191  , df_denom=1872, df_num=17
# ssr based chi2 test:   chi2=31.8803 , p=0.0156  , df=17
# likelihood ratio test: chi2=31.6168 , p=0.0168  , df=17
# parameter F test:         F=1.8409  , p=0.0191  , df_denom=1872, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.7563  , p=0.0253  , df_denom=1869, df_num=18
# ssr based chi2 test:   chi2=32.2384 , p=0.0206  , df=18
# likelihood ratio test: chi2=31.9688 , p=0.0222  , df=18
# parameter F test:         F=1.7563  , p=0.0253  , df_denom=1869, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.6636  , p=0.0357  , df_denom=1866, df_num=19
# ssr based chi2 test:   chi2=32.2687 , p=0.0291  , df=19
# likelihood ratio test: chi2=31.9984 , p=0.0313  , df=19
# parameter F test:         F=1.6636  , p=0.0357  , df_denom=1866, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.7368  , p=0.0224  , df_denom=1863, df_num=20
# ssr based chi2 test:   chi2=35.5014 , p=0.0176  , df=20
# likelihood ratio test: chi2=35.1744 , p=0.0192  , df=20
# parameter F test:         F=1.7368  , p=0.0224  , df_denom=1863, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.5708  , p=0.0478  , df_denom=1860, df_num=21
# ssr based chi2 test:   chi2=33.7487 , p=0.0385  , df=21
# likelihood ratio test: chi2=33.4529 , p=0.0414  , df=21
# parameter F test:         F=1.5708  , p=0.0478  , df_denom=1860, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.6867  , p=0.0240  , df_denom=1857, df_num=22
# ssr based chi2 test:   chi2=38.0073 , p=0.0183  , df=22
# likelihood ratio test: chi2=37.6326 , p=0.0201  , df=22
# parameter F test:         F=1.6867  , p=0.0240  , df_denom=1857, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.6676  , p=0.0244  , df_denom=1854, df_num=23
# ssr based chi2 test:   chi2=39.3273 , p=0.0183  , df=23
# likelihood ratio test: chi2=38.9260 , p=0.0202  , df=23
# parameter F test:         F=1.6676  , p=0.0244  , df_denom=1854, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.5869  , p=0.0353  , df_denom=1851, df_num=24
# ssr based chi2 test:   chi2=39.0948 , p=0.0267  , df=24
# likelihood ratio test: chi2=38.6980 , p=0.0294  , df=24
# parameter F test:         F=1.5869  , p=0.0353  , df_denom=1851, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.5750  , p=0.0352  , df_denom=1848, df_num=25
# ssr based chi2 test:   chi2=40.4605 , p=0.0261  , df=25
# likelihood ratio test: chi2=40.0355 , p=0.0289  , df=25
# parameter F test:         F=1.5750  , p=0.0352  , df_denom=1848, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.5529  , p=0.0373  , df_denom=1845, df_num=26
# ssr based chi2 test:   chi2=41.5349 , p=0.0274  , df=26
# likelihood ratio test: chi2=41.0870 , p=0.0304  , df=26
# parameter F test:         F=1.5529  , p=0.0373  , df_denom=1845, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.5187  , p=0.0428  , df_denom=1842, df_num=27
# ssr based chi2 test:   chi2=42.2292 , p=0.0312  , df=27
# likelihood ratio test: chi2=41.7660 , p=0.0347  , df=27
# parameter F test:         F=1.5187  , p=0.0428  , df_denom=1842, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.4755  , p=0.0521  , df_denom=1839, df_num=28
# ssr based chi2 test:   chi2=42.5949 , p=0.0381  , df=28
# likelihood ratio test: chi2=42.1235 , p=0.0422  , df=28
# parameter F test:         F=1.4755  , p=0.0521  , df_denom=1839, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.4383  , p=0.0617  , df_denom=1836, df_num=29
# ssr based chi2 test:   chi2=43.0505 , p=0.0450  , df=29
# likelihood ratio test: chi2=42.5688 , p=0.0499  , df=29
# parameter F test:         F=1.4383  , p=0.0617  , df_denom=1836, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.3968  , p=0.0752  , df_denom=1833, df_num=30
# ssr based chi2 test:   chi2=43.2982 , p=0.0551  , df=30
# likelihood ratio test: chi2=42.8107 , p=0.0609  , df=30
# parameter F test:         F=1.3968  , p=0.0752  , df_denom=1833, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.3498  , p=0.0950  , df_denom=1830, df_num=31
# ssr based chi2 test:   chi2=43.2846 , p=0.0703  , df=31
# likelihood ratio test: chi2=42.7971 , p=0.0772  , df=31
# parameter F test:         F=1.3498  , p=0.0950  , df_denom=1830, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.3144  , p=0.1126  , df_denom=1827, df_num=32
# ssr based chi2 test:   chi2=43.5564 , p=0.0836  , df=32
# likelihood ratio test: chi2=43.0626 , p=0.0916  , df=32
# parameter F test:         F=1.3144  , p=0.1126  , df_denom=1827, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.2949  , p=0.1223  , df_denom=1824, df_num=33
# ssr based chi2 test:   chi2=44.3022 , p=0.0904  , df=33
# likelihood ratio test: chi2=43.7912 , p=0.0992  , df=33
# parameter F test:         F=1.2949  , p=0.1223  , df_denom=1824, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.3129  , p=0.1076  , df_denom=1821, df_num=34
# ssr based chi2 test:   chi2=46.3284 , p=0.0773  , df=34
# likelihood ratio test: chi2=45.7697 , p=0.0856  , df=34
# parameter F test:         F=1.3129  , p=0.1076  , df_denom=1821, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.3031  , p=0.1111  , df_denom=1818, df_num=35
# ssr based chi2 test:   chi2=47.3887 , p=0.0789  , df=35
# likelihood ratio test: chi2=46.8041 , p=0.0876  , df=35
# parameter F test:         F=1.3031  , p=0.1111  , df_denom=1818, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.2784  , p=0.1254  , df_denom=1815, df_num=36
# ssr based chi2 test:   chi2=47.8740 , p=0.0891  , df=36
# likelihood ratio test: chi2=47.2771 , p=0.0989  , df=36
# parameter F test:         F=1.2784  , p=0.1254  , df_denom=1815, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.2730  , p=0.1266  , df_denom=1812, df_num=37
# ssr based chi2 test:   chi2=49.0508 , p=0.0888  , df=37
# likelihood ratio test: chi2=48.4242 , p=0.0990  , df=37
# parameter F test:         F=1.2730  , p=0.1266  , df_denom=1812, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.2565  , p=0.1369  , df_denom=1809, df_num=38
# ssr based chi2 test:   chi2=49.7779 , p=0.0956  , df=38
# likelihood ratio test: chi2=49.1323 , p=0.1066  , df=38
# parameter F test:         F=1.2565  , p=0.1369  , df_denom=1809, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.2449  , p=0.1439  , df_denom=1806, df_num=39
# ssr based chi2 test:   chi2=50.6739 , p=0.0998  , df=39
# likelihood ratio test: chi2=50.0047 , p=0.1114  , df=39
# parameter F test:         F=1.2449  , p=0.1439  , df_denom=1806, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.2758  , p=0.1168  , df_denom=1803, df_num=40
# ssr based chi2 test:   chi2=53.3244 , p=0.0773  , df=40
# likelihood ratio test: chi2=52.5837 , p=0.0878  , df=40
# parameter F test:         F=1.2758  , p=0.1168  , df_denom=1803, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.2662  , p=0.1216  , df_denom=1800, df_num=41
# ssr based chi2 test:   chi2=54.3069 , p=0.0797  , df=41
# likelihood ratio test: chi2=53.5385 , p=0.0907  , df=41
# parameter F test:         F=1.2662  , p=0.1216  , df_denom=1800, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.2376  , p=0.1427  , df_denom=1797, df_num=42
# ssr based chi2 test:   chi2=54.4364 , p=0.0945  , df=42
# likelihood ratio test: chi2=53.6640 , p=0.1071  , df=42
# parameter F test:         F=1.2376  , p=0.1427  , df_denom=1797, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.2173  , p=0.1591  , df_denom=1794, df_num=43
# ssr based chi2 test:   chi2=54.8830 , p=0.1057  , df=43
# likelihood ratio test: chi2=54.0976 , p=0.1195  , df=43
# parameter F test:         F=1.2173  , p=0.1591  , df_denom=1794, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.1776  , p=0.1990  , df_denom=1791, df_num=44
# ssr based chi2 test:   chi2=54.3889 , p=0.1356  , df=44
# likelihood ratio test: chi2=53.6170 , p=0.1518  , df=44
# parameter F test:         F=1.1776  , p=0.1990  , df_denom=1791, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.1648  , p=0.2121  , df_denom=1788, df_num=45
# ssr based chi2 test:   chi2=55.0841 , p=0.1442  , df=45
# likelihood ratio test: chi2=54.2921 , p=0.1615  , df=45
# parameter F test:         F=1.1648  , p=0.2121  , df_denom=1788, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.1368  , p=0.2464  , df_denom=1785, df_num=46
# ssr based chi2 test:   chi2=55.0179 , p=0.1702  , df=46
# likelihood ratio test: chi2=54.2274 , p=0.1894  , df=46
# parameter F test:         F=1.1368  , p=0.2464  , df_denom=1785, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.1103  , p=0.2828  , df_denom=1782, df_num=47
# ssr based chi2 test:   chi2=54.9668 , p=0.1984  , df=47
# likelihood ratio test: chi2=54.1774 , p=0.2196  , df=47
# parameter F test:         F=1.1103  , p=0.2828  , df_denom=1782, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.0975  , p=0.3011  , df_denom=1779, df_num=48
# ssr based chi2 test:   chi2=55.5524 , p=0.2116  , df=48
# likelihood ratio test: chi2=54.7457 , p=0.2339  , df=48
# parameter F test:         F=1.0975  , p=0.3011  , df_denom=1779, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.0859  , p=0.3185  , df_denom=1776, df_num=49
# ssr based chi2 test:   chi2=56.1773 , p=0.2239  , df=49
# likelihood ratio test: chi2=55.3522 , p=0.2474  , df=49
# parameter F test:         F=1.0859  , p=0.3185  , df_denom=1776, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.1595  , p=0.2090  , df_denom=1773, df_num=50
# ssr based chi2 test:   chi2=61.2755 , p=0.1318  , df=50
# likelihood ratio test: chi2=60.2950 , p=0.1511  , df=50
# parameter F test:         F=1.1595  , p=0.2090  , df_denom=1773, df_num=50

# %% [markdown]
# Based on **Result 3-4**, it's most likely that BTC causes ETH. From ~lag 4 to ~lag 16 (4-16 hours), we observed >99% confidence level. On the other hand, Granger Test failed to prove that ETH causes BTC(failed to reject the null hypothesis). However, the p values improve beyond ~lag 50 (~2days), with confidence level of ~90%.

# %%
# Plot 9- ACF plot of the differenced series using lag 1 order 1
from statsmodels.graphics.tsaplots import plot_acf
from pandas import tseries
plot_acf(diff_ETH)
plt.title('Plot 9- ETH', loc='center')
plt.xlim((0, 100))
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plot_acf(diff_BTC)
plt.title('Plot 9- BTC', loc='center')
plt.xlim((0, 100))
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plt.show()

# %%
# Plot 10- PACF plot of the differenced series using lag 1 order 1
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_pacf

plot_pacf(diff_ETH, lags=80)
plt.title('Plot 10- ETH', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')

plot_pacf(diff_BTC, lags=80)
plt.title('Plot 10- BTC', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')
plt.show()

# %% [markdown]
# Since there combinations of lag difference and difference order we could pick from, the following sections explore the combinations.

# %%
# Dickey Fuller Test result, ACF, and PACF plots of differenced series using lag 2 order 1
DF_diff_2 = adfuller(diff_2)
print('\n')
print('ADF Statistic: %f' % DF_diff_2[0])
print('p-value: %f' % DF_diff_2[1])
print('Critical Values:')
for key, value in DF_diff_2[4].items():
    print('\t%s: %.3f' % (key, value))
    
plot_acf(diff_2)
plt.title('Plot 11- diff_2 ACF', loc='center')
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plt.xlim([0, 80])
plt.show()

plot_pacf(diff_2, lags=80)
plt.title('Plot 12- diff_2 PACF', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')    
plt.show()
# Out:
# ADF Statistic: -8.774223
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568

# %%
# Dickey Fuller Test result, ACF, and PACF plots of differenced series using lag 2 order 1
DF_diff_24 = adfuller(diff_24)
print('\n')
print('ADF Statistic: %f' % DF_diff_24[0])
print('p-value: %f' % DF_diff_24[1])
print('Critical Values:')
for key, value in DF_diff_24[4].items():
    print('\t%s: %.3f' % (key, value))
    
plot_acf(diff_24)
plt.title('Plot 13- diff_24 ACF', loc='center')
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plt.xlim([0, 80])
plt.show()

plot_pacf(diff_24, lags=80)
plt.title('Plot 14- diff_2 PACF', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')    
plt.show()
# Out:
# ADF Statistic: -5.566813
# p-value: 0.000001
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568

# %% [markdown]
# ### Conclusion:
# -  There seem to be high correlation between the rise in search frequency and the drop in currencies prices
# -  High correlation between BTC and ETH ( >99% confidence level )
# -  There is a correlation between an observation and it's lag 1 (x_t and x_t-1)
# -  Both series have no obvious trends or seasonalities
# -  Price rise is more "rapid" than fall
# <br><br>
# From the conclusion above, my hypothesis is that classical time series analysis ( historical prices alone- i.e. ARIMA model ) might be insufficent when predicting such volatile markets. Using Machine Learning with variety of features such GoogleNews search frequency, relationship with other correlated coins, ther social media APIs and ARIMA model will improve prediction performance significantly.

# %% [markdown]
# Next steps are:
# 1. Search for more social media APIs for potential features
# 2. Identify cointegrated crytocurrency pairs (based on Granger Test) and model the relationship between the pairs
# 3. Analyze price history using ARIMA
# 4. Based on 1,2,3 come up with a Machine Learning model that best predict future prices
# 5. Compare the Machine Learning model performance with ARIMA performance

# %%
#ar1
