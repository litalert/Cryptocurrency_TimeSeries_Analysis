# %% [markdown]
# # Milestone 1
# ## Statistical Inference and EDA of BTC/ETH prices and GoogleNews search frequency of the word "cryptocurrency"
#
# Due to volatility of crytocurrency market, one might wonder what is the best way to predict the currencies prices. As I came up with the project idea, the preliminary questions I had in mind were:
#
# 1. Is there any obvious correlation/lead-lag relationship between different crytocurrency market prices?
# 2. If the correlation between a pair of currencies A and B existed, can we use currency A price history to predict future price of currency B? Will it be more useful than using just historical prices of currency B alone?
# 3. Does the rise/fall in search frequency of the word "crytocurrency" on GoogleNews imply trading signal?
#
# The following code queries, visualizes, and tests data in order to explore the preliminary questions. The stretch goal is to gain insights beyond preliminary questions that will lead to better data analysis in the future

# %%
# Getting price data of BTC and ETH using Cryptocompare API

import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
import datetime

# Indicate how many rows of data here
lim = '15000' 
story_coin = ['BTC', 'ETH']
story_data = pd.DataFrame()
for i in story_coin:
    URL = 'https://min-api.cryptocompare.com/data/histohour?fsym='+i+'&tsym=USD&limit='+lim
    data = requests.get(URL)
    json_data = data.json()
    table = json_normalize(json_data, 'Data').set_index('time')
    table.index = pd.to_datetime(table.index ,unit='s')
    story_data = pd.concat([story_data, table.high], axis=1)
story_data.columns = story_coin

# %%
# Getting data from Google Trends using Pytrends API

from pytrends.request import TrendReq
# Login to Google. Only need to run this once
pytrend = TrendReq()
# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
# keyword = 'cryptocurrency', cathegory = 16 (news), timeframe- limit range to 8 months to get daily data
pytrend.build_payload(kw_list=['cryptocurrency'], cat=16, timeframe='2017-02-24 2017-10-24')  

story_ggtrends = pytrend.interest_over_time()
# Upsampling daily data to hourly data
story_ggtrends = story_ggtrends.resample('1h').pad().drop(['isPartial'], axis='columns')
story_ggtrends.columns = ['SearchFrequency']

# %%
# Joining two data frames

story_combined = pd.concat([story_data, story_ggtrends], axis=1).dropna(how='any')
story_combined_scaled = story_combined.copy(deep=True)

# %%
# Feature Scaling. This will capture trend information and makes visualization more meaningful

from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
story_combined_scaled['BTC'] = sc_x.fit_transform(story_combined_scaled['BTC'].values.reshape(-1,1))
story_combined_scaled['ETH'] = sc_x.fit_transform(story_combined_scaled['ETH'].values.reshape(-1,1))
story_combined_scaled['SearchFrequency'] = sc_x.fit_transform(story_combined_scaled['SearchFrequency'].values.reshape(-1,1))

# %%
# Plot 1- scaled overlay plot of ETC/BTC prices and GoogleNews search frequency data

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.plot(story_combined_scaled.index, story_combined_scaled['ETH'], color='blue')
plt.plot(story_combined_scaled.index, story_combined_scaled['BTC'], color='green')
plt.plot(story_combined_scaled.index, story_combined_scaled['SearchFrequency'], color='red')
#plt.xlim(('2017-07-26', '2017-10-10'))
plt.legend(loc='upper left')
plt.xlabel('Time')
plt.ylabel('Prices & Search Frequency (scaled)')
plt.title('Plot 1')
plt.show()

# %% [markdown]
# From **Plot 1**, I've obsereved the following:
# 1. Sharp rises in search frequency are coupled with price drops
# 2. BTC and ETH prices tend to converge during drops, and not spikes (notice that the series were scaled)

# %%
# Plot 2- scaled overlay plot of ETC/BTC prices and GoogleNews search frequency data in 20 days timespand (during drop)

plt.plot(story_combined_scaled.index, story_combined_scaled['ETH'], color='blue')
plt.plot(story_combined_scaled.index, story_combined_scaled['BTC'], color='green')
plt.plot(story_combined_scaled.index, story_combined_scaled['SearchFrequency'], color='red')
plt.xlim(('2017-09-01', '2017-09-20'))
plt.legend(loc='lower left')
plt.xlabel('Time')
plt.ylabel('Prices & Search Frequency (scaled)')
plt.title('Plot 2')
plt.show()

# %% [markdown]
# According to **Plot 2**, it looks like sharp rise in search frequency leads ETH/BTC price drop. However, this conclusion is based on just 2 events

# %%
# Plot 3- BTC/ETH moving averages (scaled)

import numpy as np
a = 50
b = a-1
def moving_average(a, n):
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

ma_combined = pd.DataFrame()
ma_combined['ETH'] = moving_average(story_combined_scaled['ETH'].values, a)
ma_combined['BTC'] = moving_average(story_combined_scaled['BTC'].values, a)

plt.plot(ma_combined.index, ma_combined['BTC'], color='green', label = 'Avg_BTC')
plt.plot(ma_combined.index, ma_combined['ETH'], color='blue', label = 'Avg_ETH')
plt.legend(loc='lower left')
plt.ylabel('Prices(scaled)')
plt.xlabel('Time')
plt.title('Plot 3')
plt.show()

# %% [markdown]
# Based on **Plot 3** , there seem to be correlation between ETH and BTC prices and that ETH leads BTC. However, Granger Causality Test will be performed to confirm the relationship. There's no obvious trend (varying mean over time) or seasonality (varying variance over time) observed at this range. However, Dickey-Fuller test will be perfrom to confirm stationality of the series.

# %%
# Plot 4- Box plot by hour of the day

from datetime import datetime, timezone
from collections import OrderedDict
from collections import defaultdict

for coin in story_coin:
    group = OrderedDict.fromkeys(story_combined[coin].index.hour)
    group = defaultdict(list)
    for i in story_combined[coin].index:
        group[i.hour].append(story_combined[coin][i])
    lenght = []
    for key in group:
        lenght.append(len(group[key]))
    min_len = min(lenght)
    hour = pd.DataFrame()
    for key, value in group.items():
        hour[key] = value[:min_len]
    hour.boxplot()
    plt.ylabel('Price')
    plt.xlabel('Hours of the Days')
    plt.title('Plot 4-{}'.format(coin), loc='center')
    plt.show()

# %%
# Plot 5- Box plot by day of the month

for coin in story_coin:    
    group = OrderedDict.fromkeys(story_combined[coin].index.day)
    group = defaultdict(list)
    for i in story_combined[coin].index:
        group[i.day].append(story_combined[coin][i])
    lenght = []
    for key in group:
        lenght.append(len(group[key]))
    min_len = min(lenght)
    day = pd.DataFrame()
    for key, value in group.items():
        day[key] = value[:min_len]
    

    day.boxplot()
    plt.ylabel('Price')
    plt.xlabel('Days of the Months')
    plt.title('Plot 5-{}'.format(coin), loc='center')
    plt.show()

# %% [markdown]
# **plot 4** shows relatively constant mean, but varying variance throughout hours of the day. However, there's no common patterns observed between BTC and ETH prices stats, which leads me to belive seasonality doesn't exist in these series.

# %%
# Plot 6- BTC/ETH histogram

n_data = len(story_combined['ETH'])
n_bins = int(np.sqrt(n_data))
plt.subplot(1, 2, 1)
story_combined['ETH'].hist(bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Plot 6- ETH', loc='center')
plt.subplot(1, 2, 2)
story_combined['BTC'].hist(bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Plot 6- BTC', loc='center')
plt.show()

# %% [markdown]
# **Plot 4** shows that ETH has a sharp frequency peak at ~300, while BTC doesn't have such sharp peak. Depending on personal judgement, if the ETH peak was more extream, it might have been helpful to bias the ETH model to 300. Moreover, BTC histrogram is slightly skewed left, which may have implied BTC market is less "stable". We will further explore histograms of both series after differncing to better quantify "stability".

# %%
# Plot 7- BTC/ETH lag1 scatter plot

from pandas.plotting import lag_plot
plt.subplot(1, 2, 1)
lag_plot(story_combined['ETH'])
plt.title('Plot 7- ETH', loc='center')
plt.subplot(1, 2, 2)
lag_plot(story_combined['BTC'])
plt.title('Plot 7- BTC', loc='center')
plt.show()

# %% [markdown]
# **Plot 5** suggests positive correlation between observations and their consecutive observations (y_t and y_t-1) in both BTC and ETH. To further explore the series, we're going to look at Autocorrelation Function (ACF) and Partial Autocorrelation Function (PACF) plots which measure the linear predictability of the series at time t, say x_t, using the value x_s, where s and t denote two valuation points in time. Before we explore ACF and PACF plots, we need to stationarize the series.

# %%
# Result 1- Perform Dickey Fuller Test to determine stationality of BTC and ETC time series

from statsmodels.tsa.stattools import adfuller
x = story_combined['ETH'].values
DF_ETH = adfuller(x)
print('\n')
print('\033[1m' + 'Result 1' + '\033[0m')
print('ADF Statistic (ETH): %f' % DF_ETH[0])
print('p-value: %f' % DF_ETH[1])
print('Critical Values:')
for key, value in DF_ETH[4].items():
    print('\t%s: %.3f' % (key, value))

y = story_combined['BTC'].values
DF_BTC = adfuller(y)
print('\n')
print('ADF Statistic (BTC): %f' % DF_BTC[0])
print('p-value: %f' % DF_BTC[1])
print('Critical Values:')
for key, value in DF_BTC[4].items():
    print('\t%s: %.3f' % (key, value))
print('\n')
# Out:
# Result 1
# ADF Statistic (ETH): -1.943381
# p-value: 0.311936
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
#
#
# ADF Statistic (BTC): -0.346005
# p-value: 0.918731
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# From **Result 1** above, Dickey-Fuller test shows that both ETH and BTC are NOT stationary series. To stationarize the series, we're going to perform differencing. There are combinations of lag difference and difference order we could pick from. First, we're going to take the difference using lag 1 order 1 on both series.

# %%
# Perfrom differencing to stationalize the series

# create a differenced series, with default value of lag 1
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return diff

# difference the dataset
diff_BTC = difference(story_combined['BTC'])
diff_ETH = difference(story_combined['ETH'])

diff_2 = difference(story_combined['ETH'], 2)
diff_24 = difference(story_combined['ETH'], 24)

# invert differenced forecast #
#def inverse_difference(last_ob, value):
#    return value + last_ob
# invert the difference #
#inverted = [inverse_difference(data[i], diff[i]) for i in range(len(diff))]
#print(inverted)

# %%
#diff_BTC = np.diff(story_combined['BTC'], 2)
#diff_ETH = np.diff(story_combined['ETH'], 2)

# %%
# Result 2- Perfrom Dickey-Fuller Test on the differenced series

DF_diff_BTC = adfuller(diff_BTC)
print('\n')
print('\033[1m' + 'Result 2' + '\033[0m')
print('ADF Statistic (BTC): %f' % DF_diff_BTC[0])
print('p-value: %f' % DF_diff_BTC[1])
print('Critical Values:')
for key, value in DF_diff_BTC[4].items():
    print('\t%s: %.3f' % (key, value))
    
    
DF_diff_ETH = adfuller(diff_ETH)
print('\n')
print('ADF Statistic (ETH): %f' % DF_diff_ETH[0])
print('p-value: %f' % DF_diff_ETH[1])
print('Critical Values:')
for key, value in DF_diff_ETH[4].items():
    print('\t%s: %.3f' % (key, value))
print('\n')
# Out:
# Result 2
# ADF Statistic (BTC): -35.899636
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
#
#
# ADF Statistic (ETH): -11.990558
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# Based on **Result 2**, differencing using lag 1 order 1 improved the stationarity. Both BTC and ETH are now stationary series.

# %%
# Plot8- Plotting Histogram of differenced series

n_data = len(diff_ETH)
n_bins = int(np.sqrt(n_data))
plt.subplot(1, 2, 1)
plt.hist(diff_BTC, bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Differenced Price')
plt.title('Plot 8- BTC', loc='center')
plt.subplot(1, 2, 2)
plt.hist(diff_ETH, bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Differenced Price')
plt.title('Plot 8- ETH', loc='center')
plt.show()

# %% [markdown]
# Histogram of the difference, **Plot 6**, shows that the distribution is skewed left. This distribution implies that spiking is more "rapid" than falling. Threshold based on standard deviation of this plot could be used to define "stability" of the series.

# %%
# Result 3- Perfrom Granger Causality Test with the null hypothesis of ETH doesn't Granger cause BTC

import statsmodels.tsa.stattools as sm
diff_BTC_ETH = pd.DataFrame()
diff_BTC_ETH['BTC'] = diff_BTC
diff_BTC_ETH['ETH'] = diff_ETH
print('Result 3')
cor = sm.grangercausalitytests(diff_BTC_ETH, 50)
# Out:
# Result 3
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5624  , p=0.4534  , df_denom=1473, df_num=1
# ssr based chi2 test:   chi2=0.5635  , p=0.4529  , df=1
# likelihood ratio test: chi2=0.5634  , p=0.4529  , df=1
# parameter F test:         F=0.5624  , p=0.4534  , df_denom=1473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8252  , p=0.4384  , df_denom=1470, df_num=2
# ssr based chi2 test:   chi2=1.6560  , p=0.4369  , df=2
# likelihood ratio test: chi2=1.6551  , p=0.4371  , df=2
# parameter F test:         F=0.8252  , p=0.4384  , df_denom=1470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5341  , p=0.6589  , df_denom=1467, df_num=3
# ssr based chi2 test:   chi2=1.6099  , p=0.6571  , df=3
# likelihood ratio test: chi2=1.6091  , p=0.6573  , df=3
# parameter F test:         F=0.5341  , p=0.6589  , df_denom=1467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7448  , p=0.5615  , df_denom=1464, df_num=4
# ssr based chi2 test:   chi2=2.9974  , p=0.5583  , df=4
# likelihood ratio test: chi2=2.9944  , p=0.5588  , df=4
# parameter F test:         F=0.7448  , p=0.5615  , df_denom=1464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8415  , p=0.5202  , df_denom=1461, df_num=5
# ssr based chi2 test:   chi2=4.2391  , p=0.5155  , df=5
# likelihood ratio test: chi2=4.2330  , p=0.5164  , df=5
# parameter F test:         F=0.8415  , p=0.5202  , df_denom=1461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6801  , p=0.6658  , df_denom=1458, df_num=6
# ssr based chi2 test:   chi2=4.1170  , p=0.6608  , df=6
# likelihood ratio test: chi2=4.1113  , p=0.6616  , df=6
# parameter F test:         F=0.6801  , p=0.6658  , df_denom=1458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8670  , p=0.5320  , df_denom=1455, df_num=7
# ssr based chi2 test:   chi2=6.1318  , p=0.5245  , df=7
# likelihood ratio test: chi2=6.1190  , p=0.5259  , df=7
# parameter F test:         F=0.8670  , p=0.5320  , df_denom=1455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7471  , p=0.6499  , df_denom=1452, df_num=8
# ssr based chi2 test:   chi2=6.0465  , p=0.6420  , df=8
# likelihood ratio test: chi2=6.0341  , p=0.6434  , df=8
# parameter F test:         F=0.7471  , p=0.6499  , df_denom=1452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2679  , p=0.2497  , df_denom=1449, df_num=9
# ssr based chi2 test:   chi2=11.5608 , p=0.2392  , df=9
# likelihood ratio test: chi2=11.5155 , p=0.2420  , df=9
# parameter F test:         F=1.2679  , p=0.2497  , df_denom=1449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.6816  , p=0.0797  , df_denom=1446, df_num=10
# ssr based chi2 test:   chi2=17.0601 , p=0.0730  , df=10
# likelihood ratio test: chi2=16.9617 , p=0.0752  , df=10
# parameter F test:         F=1.6816  , p=0.0797  , df_denom=1446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.5750  , p=0.1000  , df_denom=1443, df_num=11
# ssr based chi2 test:   chi2=17.6015 , p=0.0913  , df=11
# likelihood ratio test: chi2=17.4967 , p=0.0940  , df=11
# parameter F test:         F=1.5750  , p=0.1000  , df_denom=1443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.4433  , p=0.1395  , df_denom=1440, df_num=12
# ssr based chi2 test:   chi2=17.6202 , p=0.1277  , df=12
# likelihood ratio test: chi2=17.5151 , p=0.1312  , df=12
# parameter F test:         F=1.4433  , p=0.1395  , df_denom=1440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.4095  , p=0.1473  , df_denom=1437, df_num=13
# ssr based chi2 test:   chi2=18.6682 , p=0.1338  , df=13
# likelihood ratio test: chi2=18.5502 , p=0.1377  , df=13
# parameter F test:         F=1.4095  , p=0.1473  , df_denom=1437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.6086  , p=0.0700  , df_denom=1434, df_num=14
# ssr based chi2 test:   chi2=22.9754 , p=0.0607  , df=14
# likelihood ratio test: chi2=22.7968 , p=0.0637  , df=14
# parameter F test:         F=1.6086  , p=0.0700  , df_denom=1434, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.5482  , p=0.0812  , df_denom=1431, df_num=15
# ssr based chi2 test:   chi2=23.7262 , p=0.0699  , df=15
# likelihood ratio test: chi2=23.5357 , p=0.0734  , df=15
# parameter F test:         F=1.5482  , p=0.0812  , df_denom=1431, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.4514  , p=0.1098  , df_denom=1428, df_num=16
# ssr based chi2 test:   chi2=23.7596 , p=0.0949  , df=16
# likelihood ratio test: chi2=23.5685 , p=0.0994  , df=16
# parameter F test:         F=1.4514  , p=0.1098  , df_denom=1428, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.4565  , p=0.1022  , df_denom=1425, df_num=17
# ssr based chi2 test:   chi2=25.3691 , p=0.0867  , df=17
# likelihood ratio test: chi2=25.1512 , p=0.0914  , df=17
# parameter F test:         F=1.4565  , p=0.1022  , df_denom=1425, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.3610  , p=0.1416  , df_denom=1422, df_num=18
# ssr based chi2 test:   chi2=25.1361 , p=0.1212  , df=18
# likelihood ratio test: chi2=24.9220 , p=0.1271  , df=18
# parameter F test:         F=1.3610  , p=0.1416  , df_denom=1422, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.2776  , p=0.1881  , df_denom=1419, df_num=19
# ssr based chi2 test:   chi2=24.9416 , p=0.1625  , df=19
# likelihood ratio test: chi2=24.7307 , p=0.1696  , df=19
# parameter F test:         F=1.2776  , p=0.1881  , df_denom=1419, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.2156  , p=0.2313  , df_denom=1416, df_num=20
# ssr based chi2 test:   chi2=25.0152 , p=0.2008  , df=20
# likelihood ratio test: chi2=24.8029 , p=0.2091  , df=20
# parameter F test:         F=1.2156  , p=0.2313  , df_denom=1416, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.1492  , p=0.2888  , df_denom=1413, df_num=21
# ssr based chi2 test:   chi2=24.8670 , p=0.2530  , df=21
# likelihood ratio test: chi2=24.6571 , p=0.2623  , df=21
# parameter F test:         F=1.1492  , p=0.2888  , df_denom=1413, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.1083  , p=0.3294  , df_denom=1410, df_num=22
# ssr based chi2 test:   chi2=25.1604 , p=0.2895  , df=22
# likelihood ratio test: chi2=24.9454 , p=0.2997  , df=22
# parameter F test:         F=1.1083  , p=0.3294  , df_denom=1410, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.0691  , p=0.3734  , df_denom=1407, df_num=23
# ssr based chi2 test:   chi2=25.4110 , p=0.3294  , df=23
# likelihood ratio test: chi2=25.1915 , p=0.3405  , df=23
# parameter F test:         F=1.0691  , p=0.3734  , df_denom=1407, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.3723  , p=0.1082  , df_denom=1404, df_num=24
# ssr based chi2 test:   chi2=34.0845 , p=0.0832  , df=24
# likelihood ratio test: chi2=33.6909 , p=0.0903  , df=24
# parameter F test:         F=1.3723  , p=0.1082  , df_denom=1404, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.3308  , p=0.1273  , df_denom=1401, df_num=25
# ssr based chi2 test:   chi2=34.4820 , p=0.0980  , df=25
# likelihood ratio test: chi2=34.0789 , p=0.1062  , df=25
# parameter F test:         F=1.3308  , p=0.1273  , df_denom=1401, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.3069  , p=0.1386  , df_denom=1398, df_num=26
# ssr based chi2 test:   chi2=35.2683 , p=0.1060  , df=26
# likelihood ratio test: chi2=34.8465 , p=0.1150  , df=26
# parameter F test:         F=1.3069  , p=0.1386  , df_denom=1398, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.2897  , p=0.1466  , df_denom=1395, df_num=27
# ssr based chi2 test:   chi2=36.1950 , p=0.1111  , df=27
# likelihood ratio test: chi2=35.7506 , p=0.1209  , df=27
# parameter F test:         F=1.2897  , p=0.1466  , df_denom=1395, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.2345  , p=0.1861  , df_denom=1392, df_num=28
# ssr based chi2 test:   chi2=35.9813 , p=0.1431  , df=28
# likelihood ratio test: chi2=35.5418 , p=0.1546  , df=28
# parameter F test:         F=1.2345  , p=0.1861  , df_denom=1392, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.2666  , p=0.1566  , df_denom=1389, df_num=29
# ssr based chi2 test:   chi2=38.2905 , p=0.1160  , df=29
# likelihood ratio test: chi2=37.7930 , p=0.1270  , df=29
# parameter F test:         F=1.2666  , p=0.1566  , df_denom=1389, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.2244  , p=0.1885  , df_denom=1386, df_num=30
# ssr based chi2 test:   chi2=38.3497 , p=0.1410  , df=30
# likelihood ratio test: chi2=37.8503 , p=0.1536  , df=30
# parameter F test:         F=1.2244  , p=0.1885  , df_denom=1386, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.1904  , p=0.2181  , df_denom=1383, df_num=31
# ssr based chi2 test:   chi2=38.5838 , p=0.1642  , df=31
# likelihood ratio test: chi2=38.0780 , p=0.1784  , df=31
# parameter F test:         F=1.1904  , p=0.2181  , df_denom=1383, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.1797  , p=0.2265  , df_denom=1380, df_num=32
# ssr based chi2 test:   chi2=39.5274 , p=0.1691  , df=32
# likelihood ratio test: chi2=38.9964 , p=0.1841  , df=32
# parameter F test:         F=1.1797  , p=0.2265  , df_denom=1380, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.2478  , p=0.1590  , df_denom=1377, df_num=33
# ssr based chi2 test:   chi2=43.1802 , p=0.1105  , df=33
# likelihood ratio test: chi2=42.5472 , p=0.1234  , df=33
# parameter F test:         F=1.2478  , p=0.1590  , df_denom=1377, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.1868  , p=0.2137  , df_denom=1374, df_num=34
# ssr based chi2 test:   chi2=42.3774 , p=0.1534  , df=34
# likelihood ratio test: chi2=41.7670 , p=0.1690  , df=34
# parameter F test:         F=1.1868  , p=0.2137  , df_denom=1374, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.3075  , p=0.1091  , df_denom=1371, df_num=35
# ssr based chi2 test:   chi2=48.1341 , p=0.0687  , df=35
# likelihood ratio test: chi2=47.3482 , p=0.0794  , df=35
# parameter F test:         F=1.3075  , p=0.1091  , df_denom=1371, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.3838  , p=0.0659  , df_denom=1368, df_num=36
# ssr based chi2 test:   chi2=52.4761 , p=0.0374  , df=36
# likelihood ratio test: chi2=51.5431 , p=0.0450  , df=36
# parameter F test:         F=1.3838  , p=0.0659  , df_denom=1368, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.3347  , p=0.0876  , df_denom=1365, df_num=37
# ssr based chi2 test:   chi2=52.0976 , p=0.0509  , df=37
# likelihood ratio test: chi2=51.1773 , p=0.0605  , df=37
# parameter F test:         F=1.3347  , p=0.0876  , df_denom=1365, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.4072  , p=0.0524  , df_denom=1362, df_num=38
# ssr based chi2 test:   chi2=56.4964 , p=0.0271  , df=38
# likelihood ratio test: chi2=55.4156 , p=0.0337  , df=38
# parameter F test:         F=1.4072  , p=0.0524  , df_denom=1362, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.3820  , p=0.0602  , df_denom=1359, df_num=39
# ssr based chi2 test:   chi2=57.0295 , p=0.0311  , df=39
# likelihood ratio test: chi2=55.9277 , p=0.0386  , df=39
# parameter F test:         F=1.3820  , p=0.0602  , df_denom=1359, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.3549  , p=0.0702  , df_denom=1356, df_num=40
# ssr based chi2 test:   chi2=57.4314 , p=0.0364  , df=40
# likelihood ratio test: chi2=56.3135 , p=0.0451  , df=40
# parameter F test:         F=1.3549  , p=0.0702  , df_denom=1356, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.3514  , p=0.0698  , df_denom=1353, df_num=41
# ssr based chi2 test:   chi2=58.8048 , p=0.0353  , df=41
# likelihood ratio test: chi2=57.6327 , p=0.0440  , df=41
# parameter F test:         F=1.3514  , p=0.0698  , df_denom=1353, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.3212  , p=0.0835  , df_denom=1350, df_num=42
# ssr based chi2 test:   chi2=58.9864 , p=0.0427  , df=42
# likelihood ratio test: chi2=57.8063 , p=0.0530  , df=42
# parameter F test:         F=1.3212  , p=0.0835  , df_denom=1350, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.3237  , p=0.0800  , df_denom=1347, df_num=43
# ssr based chi2 test:   chi2=60.5940 , p=0.0395  , df=43
# likelihood ratio test: chi2=59.3487 , p=0.0496  , df=43
# parameter F test:         F=1.3237  , p=0.0800  , df_denom=1347, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.3142  , p=0.0834  , df_denom=1344, df_num=44
# ssr based chi2 test:   chi2=61.6561 , p=0.0404  , df=44
# likelihood ratio test: chi2=60.3666 , p=0.0510  , df=44
# parameter F test:         F=1.3142  , p=0.0834  , df_denom=1344, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.2588  , p=0.1192  , df_denom=1341, df_num=45
# ssr based chi2 test:   chi2=60.4890 , p=0.0613  , df=45
# likelihood ratio test: chi2=59.2464 , p=0.0755  , df=45
# parameter F test:         F=1.2588  , p=0.1192  , df_denom=1341, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.3266  , p=0.0725  , df_denom=1338, df_num=46
# ssr based chi2 test:   chi2=65.2650 , p=0.0322  , df=46
# likelihood ratio test: chi2=63.8205 , p=0.0420  , df=46
# parameter F test:         F=1.3266  , p=0.0725  , df_denom=1338, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.3711  , p=0.0501  , df_denom=1335, df_num=47
# ssr based chi2 test:   chi2=69.0273 , p=0.0198  , df=47
# likelihood ratio test: chi2=67.4131 , p=0.0270  , df=47
# parameter F test:         F=1.3711  , p=0.0501  , df_denom=1335, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.4014  , p=0.0379  , df_denom=1332, df_num=48
# ssr based chi2 test:   chi2=72.1632 , p=0.0136  , df=48
# likelihood ratio test: chi2=70.4002 , p=0.0192  , df=48
# parameter F test:         F=1.4014  , p=0.0379  , df_denom=1332, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.3971  , p=0.0379  , df_denom=1329, df_num=49
# ssr based chi2 test:   chi2=73.5596 , p=0.0131  , df=49
# likelihood ratio test: chi2=71.7276 , p=0.0188  , df=49
# parameter F test:         F=1.3971  , p=0.0379  , df_denom=1329, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.4681  , p=0.0196  , df_denom=1326, df_num=50
# ssr based chi2 test:   chi2=78.9964 , p=0.0056  , df=50
# likelihood ratio test: chi2=76.8873 , p=0.0086  , df=50
# parameter F test:         F=1.4681  , p=0.0196  , df_denom=1326, df_num=50

# %%
# Result 4- Perform Granger Causality Test with the null hypothesis of BTC doesn't Granger cause ETH

diff_ETH_BTC = pd.DataFrame()
diff_ETH_BTC['ETH'] = diff_ETH
diff_ETH_BTC['BTC'] = diff_BTC
print('Result 4')
cor = sm.grangercausalitytests(diff_ETH_BTC, 50)
# Out:
# Result 4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0686  , p=0.3014  , df_denom=1473, df_num=1
# ssr based chi2 test:   chi2=1.0708  , p=0.3008  , df=1
# likelihood ratio test: chi2=1.0704  , p=0.3009  , df=1
# parameter F test:         F=1.0686  , p=0.3014  , df_denom=1473, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7636  , p=0.4662  , df_denom=1470, df_num=2
# ssr based chi2 test:   chi2=1.5323  , p=0.4648  , df=2
# likelihood ratio test: chi2=1.5315  , p=0.4650  , df=2
# parameter F test:         F=0.7636  , p=0.4662  , df_denom=1470, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6291  , p=0.5962  , df_denom=1467, df_num=3
# ssr based chi2 test:   chi2=1.8964  , p=0.5942  , df=3
# likelihood ratio test: chi2=1.8952  , p=0.5944  , df=3
# parameter F test:         F=0.6291  , p=0.5962  , df_denom=1467, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=5.6120  , p=0.0002  , df_denom=1464, df_num=4
# ssr based chi2 test:   chi2=22.5861 , p=0.0002  , df=4
# likelihood ratio test: chi2=22.4147 , p=0.0002  , df=4
# parameter F test:         F=5.6120  , p=0.0002  , df_denom=1464, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.6536  , p=0.0003  , df_denom=1461, df_num=5
# ssr based chi2 test:   chi2=23.4430 , p=0.0003  , df=5
# likelihood ratio test: chi2=23.2583 , p=0.0003  , df=5
# parameter F test:         F=4.6536  , p=0.0003  , df_denom=1461, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.7563  , p=0.0010  , df_denom=1458, df_num=6
# ssr based chi2 test:   chi2=22.7385 , p=0.0009  , df=6
# likelihood ratio test: chi2=22.5645 , p=0.0010  , df=6
# parameter F test:         F=3.7563  , p=0.0010  , df_denom=1458, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.3888  , p=0.0014  , df_denom=1455, df_num=7
# ssr based chi2 test:   chi2=23.9661 , p=0.0012  , df=7
# likelihood ratio test: chi2=23.7728 , p=0.0012  , df=7
# parameter F test:         F=3.3888  , p=0.0014  , df_denom=1455, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.0490  , p=0.0021  , df_denom=1452, df_num=8
# ssr based chi2 test:   chi2=24.6776 , p=0.0018  , df=8
# likelihood ratio test: chi2=24.4726 , p=0.0019  , df=8
# parameter F test:         F=3.0490  , p=0.0021  , df_denom=1452, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.7332  , p=0.0036  , df_denom=1449, df_num=9
# ssr based chi2 test:   chi2=24.9213 , p=0.0031  , df=9
# likelihood ratio test: chi2=24.7121 , p=0.0033  , df=9
# parameter F test:         F=2.7332  , p=0.0036  , df_denom=1449, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.7255  , p=0.0025  , df_denom=1446, df_num=10
# ssr based chi2 test:   chi2=27.6505 , p=0.0021  , df=10
# likelihood ratio test: chi2=27.3932 , p=0.0023  , df=10
# parameter F test:         F=2.7255  , p=0.0025  , df_denom=1446, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.5053  , p=0.0040  , df_denom=1443, df_num=11
# ssr based chi2 test:   chi2=27.9970 , p=0.0032  , df=11
# likelihood ratio test: chi2=27.7331 , p=0.0036  , df=11
# parameter F test:         F=2.5053  , p=0.0040  , df_denom=1443, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.4988  , p=0.0030  , df_denom=1440, df_num=12
# ssr based chi2 test:   chi2=30.5067 , p=0.0023  , df=12
# likelihood ratio test: chi2=30.1934 , p=0.0026  , df=12
# parameter F test:         F=2.4988  , p=0.0030  , df_denom=1440, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=2.5332  , p=0.0019  , df_denom=1437, df_num=13
# ssr based chi2 test:   chi2=33.5505 , p=0.0014  , df=13
# likelihood ratio test: chi2=33.1719 , p=0.0016  , df=13
# parameter F test:         F=2.5332  , p=0.0019  , df_denom=1437, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=2.3473  , p=0.0033  , df_denom=1434, df_num=14
# ssr based chi2 test:   chi2=33.5273 , p=0.0024  , df=14
# likelihood ratio test: chi2=33.1489 , p=0.0027  , df=14
# parameter F test:         F=2.3473  , p=0.0033  , df_denom=1434, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=2.2419  , p=0.0041  , df_denom=1431, df_num=15
# ssr based chi2 test:   chi2=34.3563 , p=0.0030  , df=15
# likelihood ratio test: chi2=33.9588 , p=0.0035  , df=15
# parameter F test:         F=2.2419  , p=0.0041  , df_denom=1431, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=2.2095  , p=0.0039  , df_denom=1428, df_num=16
# ssr based chi2 test:   chi2=36.1688 , p=0.0027  , df=16
# likelihood ratio test: chi2=35.7283 , p=0.0032  , df=16
# parameter F test:         F=2.2095  , p=0.0039  , df_denom=1428, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=2.0481  , p=0.0071  , df_denom=1425, df_num=17
# ssr based chi2 test:   chi2=35.6722 , p=0.0051  , df=17
# likelihood ratio test: chi2=35.2434 , p=0.0058  , df=17
# parameter F test:         F=2.0481  , p=0.0071  , df_denom=1425, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.9275  , p=0.0110  , df_denom=1422, df_num=18
# ssr based chi2 test:   chi2=35.5975 , p=0.0079  , df=18
# likelihood ratio test: chi2=35.1702 , p=0.0090  , df=18
# parameter F test:         F=1.9275  , p=0.0110  , df_denom=1422, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.8209  , p=0.0165  , df_denom=1419, df_num=19
# ssr based chi2 test:   chi2=35.5481 , p=0.0120  , df=19
# likelihood ratio test: chi2=35.1217 , p=0.0135  , df=19
# parameter F test:         F=1.8209  , p=0.0165  , df_denom=1419, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.9679  , p=0.0065  , df_denom=1416, df_num=20
# ssr based chi2 test:   chi2=40.4982 , p=0.0043  , df=20
# likelihood ratio test: chi2=39.9456 , p=0.0051  , df=20
# parameter F test:         F=1.9679  , p=0.0065  , df_denom=1416, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.8823  , p=0.0092  , df_denom=1413, df_num=21
# ssr based chi2 test:   chi2=40.7302 , p=0.0061  , df=21
# likelihood ratio test: chi2=40.1709 , p=0.0071  , df=21
# parameter F test:         F=1.8823  , p=0.0092  , df_denom=1413, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.8395  , p=0.0103  , df_denom=1410, df_num=22
# ssr based chi2 test:   chi2=41.7609 , p=0.0067  , df=22
# likelihood ratio test: chi2=41.1728 , p=0.0079  , df=22
# parameter F test:         F=1.8395  , p=0.0103  , df_denom=1410, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.8686  , p=0.0076  , df_denom=1407, df_num=23
# ssr based chi2 test:   chi2=44.4137 , p=0.0047  , df=23
# likelihood ratio test: chi2=43.7488 , p=0.0056  , df=23
# parameter F test:         F=1.8686  , p=0.0076  , df_denom=1407, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.7615  , p=0.0130  , df_denom=1404, df_num=24
# ssr based chi2 test:   chi2=43.7518 , p=0.0082  , df=24
# likelihood ratio test: chi2=43.1061 , p=0.0097  , df=24
# parameter F test:         F=1.7615  , p=0.0130  , df_denom=1404, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.9265  , p=0.0040  , df_denom=1401, df_num=25
# ssr based chi2 test:   chi2=49.9150 , p=0.0022  , df=25
# likelihood ratio test: chi2=49.0762 , p=0.0028  , df=25
# parameter F test:         F=1.9265  , p=0.0040  , df_denom=1401, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.8610  , p=0.0054  , df_denom=1398, df_num=26
# ssr based chi2 test:   chi2=50.2200 , p=0.0030  , df=26
# likelihood ratio test: chi2=49.3704 , p=0.0037  , df=26
# parameter F test:         F=1.8610  , p=0.0054  , df_denom=1398, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.8162  , p=0.0065  , df_denom=1395, df_num=27
# ssr based chi2 test:   chi2=50.9702 , p=0.0035  , df=27
# likelihood ratio test: chi2=50.0948 , p=0.0044  , df=27
# parameter F test:         F=1.8162  , p=0.0065  , df_denom=1395, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.8126  , p=0.0060  , df_denom=1392, df_num=28
# ssr based chi2 test:   chi2=52.8320 , p=0.0031  , df=28
# likelihood ratio test: chi2=51.8917 , p=0.0039  , df=28
# parameter F test:         F=1.8126  , p=0.0060  , df_denom=1392, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.7979  , p=0.0059  , df_denom=1389, df_num=29
# ssr based chi2 test:   chi2=54.3537 , p=0.0029  , df=29
# likelihood ratio test: chi2=53.3584 , p=0.0038  , df=29
# parameter F test:         F=1.7979  , p=0.0059  , df_denom=1389, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.7336  , p=0.0085  , df_denom=1386, df_num=30
# ssr based chi2 test:   chi2=54.2973 , p=0.0043  , df=30
# likelihood ratio test: chi2=53.3034 , p=0.0055  , df=30
# parameter F test:         F=1.7336  , p=0.0085  , df_denom=1386, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.7094  , p=0.0092  , df_denom=1383, df_num=31
# ssr based chi2 test:   chi2=55.4051 , p=0.0045  , df=31
# likelihood ratio test: chi2=54.3700 , p=0.0059  , df=31
# parameter F test:         F=1.7094  , p=0.0092  , df_denom=1383, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.6646  , p=0.0117  , df_denom=1380, df_num=32
# ssr based chi2 test:   chi2=55.7748 , p=0.0057  , df=32
# likelihood ratio test: chi2=54.7253 , p=0.0074  , df=32
# parameter F test:         F=1.6646  , p=0.0117  , df_denom=1380, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.6409  , p=0.0128  , df_denom=1377, df_num=33
# ssr based chi2 test:   chi2=56.7845 , p=0.0062  , df=33
# likelihood ratio test: chi2=55.6964 , p=0.0080  , df=33
# parameter F test:         F=1.6409  , p=0.0128  , df_denom=1377, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.6447  , p=0.0115  , df_denom=1374, df_num=34
# ssr based chi2 test:   chi2=58.7279 , p=0.0053  , df=34
# likelihood ratio test: chi2=57.5643 , p=0.0070  , df=34
# parameter F test:         F=1.6447  , p=0.0115  , df_denom=1374, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.6368  , p=0.0113  , df_denom=1371, df_num=35
# ssr based chi2 test:   chi2=60.2566 , p=0.0050  , df=35
# likelihood ratio test: chi2=59.0317 , p=0.0067  , df=35
# parameter F test:         F=1.6368  , p=0.0113  , df_denom=1371, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.5989  , p=0.0141  , df_denom=1368, df_num=36
# ssr based chi2 test:   chi2=60.6324 , p=0.0063  , df=36
# likelihood ratio test: chi2=59.3915 , p=0.0084  , df=36
# parameter F test:         F=1.5989  , p=0.0141  , df_denom=1368, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.5677  , p=0.0168  , df_denom=1365, df_num=37
# ssr based chi2 test:   chi2=61.1931 , p=0.0074  , df=37
# likelihood ratio test: chi2=59.9286 , p=0.0099  , df=37
# parameter F test:         F=1.5677  , p=0.0168  , df_denom=1365, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.5421  , p=0.0193  , df_denom=1362, df_num=38
# ssr based chi2 test:   chi2=61.9121 , p=0.0084  , df=38
# likelihood ratio test: chi2=60.6172 , p=0.0113  , df=38
# parameter F test:         F=1.5421  , p=0.0193  , df_denom=1362, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.5058  , p=0.0243  , df_denom=1359, df_num=39
# ssr based chi2 test:   chi2=62.1381 , p=0.0107  , df=39
# likelihood ratio test: chi2=60.8330 , p=0.0142  , df=39
# parameter F test:         F=1.5058  , p=0.0243  , df_denom=1359, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.5519  , p=0.0159  , df_denom=1356, df_num=40
# ssr based chi2 test:   chi2=65.7845 , p=0.0063  , df=40
# likelihood ratio test: chi2=64.3232 , p=0.0087  , df=40
# parameter F test:         F=1.5519  , p=0.0159  , df_denom=1356, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.5143  , p=0.0204  , df_denom=1353, df_num=41
# ssr based chi2 test:   chi2=65.8957 , p=0.0081  , df=41
# likelihood ratio test: chi2=64.4285 , p=0.0112  , df=41
# parameter F test:         F=1.5143  , p=0.0204  , df_denom=1353, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.4572  , p=0.0306  , df_denom=1350, df_num=42
# ssr based chi2 test:   chi2=65.0540 , p=0.0128  , df=42
# likelihood ratio test: chi2=63.6225 , p=0.0172  , df=42
# parameter F test:         F=1.4572  , p=0.0306  , df_denom=1350, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.4383  , p=0.0341  , df_denom=1347, df_num=43
# ssr based chi2 test:   chi2=65.8399 , p=0.0141  , df=43
# likelihood ratio test: chi2=64.3731 , p=0.0190  , df=43
# parameter F test:         F=1.4383  , p=0.0341  , df_denom=1347, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.4002  , p=0.0442  , df_denom=1344, df_num=44
# ssr based chi2 test:   chi2=65.6869 , p=0.0186  , df=44
# likelihood ratio test: chi2=64.2259 , p=0.0249  , df=44
# parameter F test:         F=1.4002  , p=0.0442  , df_denom=1344, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.3785  , p=0.0505  , df_denom=1341, df_num=45
# ssr based chi2 test:   chi2=66.2407 , p=0.0213  , df=45
# likelihood ratio test: chi2=64.7543 , p=0.0283  , df=45
# parameter F test:         F=1.3785  , p=0.0505  , df_denom=1341, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.3689  , p=0.0526  , df_denom=1338, df_num=46
# ssr based chi2 test:   chi2=67.3465 , p=0.0217  , df=46
# likelihood ratio test: chi2=65.8098 , p=0.0291  , df=46
# parameter F test:         F=1.3689  , p=0.0526  , df_denom=1338, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.3245  , p=0.0718  , df_denom=1335, df_num=47
# ssr based chi2 test:   chi2=66.6794 , p=0.0309  , df=47
# likelihood ratio test: chi2=65.1715 , p=0.0407  , df=47
# parameter F test:         F=1.3245  , p=0.0718  , df_denom=1335, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.3013  , p=0.0832  , df_denom=1332, df_num=48
# ssr based chi2 test:   chi2=67.0087 , p=0.0362  , df=48
# likelihood ratio test: chi2=65.4851 , p=0.0474  , df=48
# parameter F test:         F=1.3013  , p=0.0832  , df_denom=1332, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.2984  , p=0.0831  , df_denom=1329, df_num=49
# ssr based chi2 test:   chi2=68.3596 , p=0.0351  , df=49
# likelihood ratio test: chi2=66.7738 , p=0.0464  , df=49
# parameter F test:         F=1.2984  , p=0.0831  , df_denom=1329, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.3390  , p=0.0593  , df_denom=1326, df_num=50
# ssr based chi2 test:   chi2=72.0491 , p=0.0222  , df=50
# likelihood ratio test: chi2=70.2892 , p=0.0307  , df=50
# parameter F test:         F=1.3390  , p=0.0593  , df_denom=1326, df_num=50

# %% [markdown]
# Based on **Result 3-4**, it's most likely that BTC causes ETH. From ~lag 4 to ~lag 16 (4-16 hours), we observed >99% confidence level. On the other hand, Granger Test failed to prove that ETH causes BTC(failed to reject the null hypothesis). However, the p values improve beyond ~lag 50 (~2days), with confidence level of ~90%.

# %%
# Plot 9- ACF plot of the differenced series using lag 1 order 1

from statsmodels.graphics.tsaplots import plot_acf
from pandas import tseries
plot_acf(diff_ETH)
plt.title('Plot 9- ETH', loc='center')
plt.xlim((0, 100))
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plot_acf(diff_BTC)
plt.title('Plot 9- BTC', loc='center')
plt.xlim((0, 100))
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plt.show()

# %%
# Plot 10- PACF plot of the differenced series using lag 1 order 1

from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_pacf

plot_pacf(diff_ETH, lags=80)
plt.title('Plot 10- ETH', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')

plot_pacf(diff_BTC, lags=80)
plt.title('Plot 10- BTC', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')
plt.show()

# %% [markdown]
# Since there combinations of lag difference and difference order we could pick from, the following sections explore the combinations.

# %%
# Dickey Fuller Test result, ACF, and PACF plots of differenced series using lag 2 order 1

DF_diff_2 = adfuller(diff_2)
print('\n')
print('ADF Statistic: %f' % DF_diff_2[0])
print('p-value: %f' % DF_diff_2[1])
print('Critical Values:')
for key, value in DF_diff_2[4].items():
    print('\t%s: %.3f' % (key, value))
    
plot_acf(diff_2)
plt.title('Plot 11- diff_2 ACF', loc='center')
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plt.xlim([0, 80])
plt.show()

plot_pacf(diff_2, lags=80)
plt.title('Plot 12- diff_2 PACF', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')    
plt.show()
# Out:
# ADF Statistic: -7.999024
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %%
# Dickey Fuller Test result, ACF, and PACF plots of differenced series using lag 2 order 1

DF_diff_24 = adfuller(diff_24)
print('\n')
print('ADF Statistic: %f' % DF_diff_24[0])
print('p-value: %f' % DF_diff_24[1])
print('Critical Values:')
for key, value in DF_diff_24[4].items():
    print('\t%s: %.3f' % (key, value))
    
plot_acf(diff_24)
plt.title('Plot 13- diff_24 ACF', loc='center')
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plt.xlim([0, 80])
plt.show()

plot_pacf(diff_24, lags=80)
plt.title('Plot 14- diff_2 PACF', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')    
plt.show()
# Out:
# ADF Statistic: -4.483549
# p-value: 0.000211
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# ### Conclusion:
# -  There seem to be high correlation between the rise in search frequency and the drop in currencies prices
# -  High correlation between BTC and ETH ( >99% confidence level )
# -  There is a low correlation between an observation and it's lag 1 (x_t and x_t-1)
# -  Both series have no obvious trends or seasonalities
# -  Spike is more "rapid" than fall
# -  BTC and ETH prices (scaled) converged during fall, but not spike
# <br><br>
# From the conclusion above, my hypothesis is that classical time series analysis ( historical prices alone) might be insufficent when predicting such volatile markets. Using Machine Learning with variety of predictorss such GoogleNews search frequency and relationship with other correlated coins on top of ARIMA model will improve prediction performance significantly.

# %% [markdown]
# ### Next steps:
# 1. Search for more potential features: social media APIs? macroeconomic covariates? differencing function? node count? mining time? GPU sales (AMD, Nvidia)?
# 2. Identify cointegrated crytocurrency pairs (based on Granger Test) and model the relationship between the pairs
# 3. Analyze price history using ARIMA model
# 4. Based on 1,2,3 come up with a Machine Learning model that best predict future prices
# 5. Compare the Machine Learning model performance with ARIMA performance

# %%
#ar1
