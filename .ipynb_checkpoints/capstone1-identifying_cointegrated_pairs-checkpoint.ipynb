# %% [markdown]
# ## Identifying cryptocurrency cointegrated pair based on Granger Causality test

# %%
#print list of currencies being analyzed and construct the list of currencies symbols

import cryptocompare
coin = cryptocompare.get_coin_list(format=False)

#list the currencies you wish to analyze here
coin_top10 = ['Bitcoin', 'Ethereum ', 'Bitcoin Cash / BCC', 'Ripple', 'Litecoin', 'NEM', 'DigitalCash', 'ZCash','Monero', 'IOTA', 'Ethereum Classic', 'Nxt', 'Stellar']
coin_top10_sym = []
for key, value in coin.items():
    if value['CoinName'] in coin_top10:
        print(key, value['CoinName'])
        coin_top10_sym.append(key)
# Out:
# BTC Bitcoin
# NXT Nxt
# BCH Bitcoin Cash / BCC
# DASH DigitalCash
# LTC Litecoin
# XLM Stellar
# XRP Ripple
# XEM NEM
# ETC Ethereum Classic
# XMR Monero
# ZEC ZCash
# IOT IOTA

# %%
#making API calls to get hourly price data then construct a dataframe of each currencies price data with UNIX timestamp as index

import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

#determine how many rows of data here
lim = '18000' #querying 2 weeks back

df = pd.DataFrame()
for i in coin_top10_sym:
    URL = 'https://min-api.cryptocompare.com/data/histohour?fsym='+i+'&tsym=USD&limit='+lim
    data = requests.get(URL)
    json_data = data.json()
    table = json_normalize(json_data, 'Data').set_index('time')
    table.index = pd.to_datetime(table.index ,unit='s')
    df = pd.concat([df, table.high], axis=1)
df.columns = coin_top10_sym

# %%
#df = df.loc[:'2017-11-03', :]

# %%
# Performing Dickey-Fuller stationary test

from statsmodels.tsa.stattools import adfuller

for i in df.columns: 
    x = df[i].values
    result = adfuller(x)
    print('\033[1m' + i + '\033[0m')
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
# Out:
# BTC
# ADF Statistic: -0.0862684968996
# p-value: 0.950789184758
# NXT
# ADF Statistic: -2.44915831319
# p-value: 0.12833958675
# BCH
# ADF Statistic: -1.01091956106
# p-value: 0.749260836204
# DASH
# ADF Statistic: -1.62891926234
# p-value: 0.468056465113
# LTC
# ADF Statistic: -2.34202475086
# p-value: 0.158772021605
# XLM
# ADF Statistic: -1.62813197797
# p-value: 0.468468661127
# XRP
# ADF Statistic: -2.38219590152
# p-value: 0.1468246644
# XEM
# ADF Statistic: -1.97382952133
# p-value: 0.298164492443
# ETC
# ADF Statistic: -1.57981806366
# p-value: 0.493723125199
# XMR
# ADF Statistic: -2.0230220917
# p-value: 0.276570825377
# ZEC
# ADF Statistic: -2.47424607046
# p-value: 0.121866931667
# IOT
# ADF Statistic: -2.07083917054
# p-value: 0.256400790598

# %%
# Perfrom differencing to stationalize the series

# Creat difference function, with default value of lag 1
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return diff

# Differencing the dataset 
df_diff = pd.DataFrame()
for i in df.columns:
    df_diff[i] = difference(df[i])

# %%
# Re-perform Dickey-fuller test to test the differenced series for stationality

for i in df.columns: 
    x = df_diff[i].values
    result = adfuller(x)
    print('\033[1m' + i + '\033[0m')
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
# Out:
# BTC
# ADF Statistic: -33.7432687975
# p-value: 0.0
# NXT
# ADF Statistic: -14.7927131179
# p-value: 2.15885124626e-27
# BCH
# ADF Statistic: -9.00953950097
# p-value: 6.17925578267e-15
# DASH
# ADF Statistic: -9.61935199195
# p-value: 1.72571079354e-16
# LTC
# ADF Statistic: -18.5234854445
# p-value: 2.10731283899e-30
# XLM
# ADF Statistic: -8.34913726766
# p-value: 3.02795171485e-13
# XRP
# ADF Statistic: -22.3824982461
# p-value: 0.0
# XEM
# ADF Statistic: -31.8773754372
# p-value: 0.0
# ETC
# ADF Statistic: -9.61928088828
# p-value: 1.72642678748e-16
# XMR
# ADF Statistic: -10.815147913
# p-value: 1.86540134387e-19
# ZEC
# ADF Statistic: -8.99773100644
# p-value: 6.62444757042e-15
# IOT
# ADF Statistic: -31.8465124033
# p-value: 0.0

# %%
#create dataframes for each of the posible currencies combinations

from itertools import permutations
com = list(permutations(coin_top10_sym, 2))
pair_list = []
count = 0
for i in com:
    globals()[str(i[0]) + '_' + str(i[1])] = df_diff[[com[count][0], com[count][1]]]
    count = count + 1
    pair_list.append(str(i[0]) + '_' + str(i[1]))

# %%
# Performing Granger Causality Test

import statsmodels.tsa.stattools as sm
lag = 24
cor = {}
for i in pair_list:
    cor[i] = sm.grangercausalitytests(eval(i), lag)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3005  , p=0.5837  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=0.3009  , p=0.5833  , df=1
# likelihood ratio test: chi2=0.3009  , p=0.5833  , df=1
# parameter F test:         F=0.3005  , p=0.5837  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0457  , p=0.9553  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=0.0916  , p=0.9552  , df=2
# likelihood ratio test: chi2=0.0916  , p=0.9552  , df=2
# parameter F test:         F=0.0457  , p=0.9553  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1395  , p=0.9364  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=0.4201  , p=0.9361  , df=3
# likelihood ratio test: chi2=0.4201  , p=0.9361  , df=3
# parameter F test:         F=0.1395  , p=0.9364  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3659  , p=0.8331  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=1.4700  , p=0.8319  , df=4
# likelihood ratio test: chi2=1.4695  , p=0.8320  , df=4
# parameter F test:         F=0.3659  , p=0.8331  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8181  , p=0.5366  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=4.1132  , p=0.5332  , df=5
# likelihood ratio test: chi2=4.1090  , p=0.5338  , df=5
# parameter F test:         F=0.8181  , p=0.5366  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6889  , p=0.6586  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=4.1606  , p=0.6550  , df=6
# likelihood ratio test: chi2=4.1563  , p=0.6555  , df=6
# parameter F test:         F=0.6889  , p=0.6586  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5688  , p=0.7818  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=4.0117  , p=0.7784  , df=7
# likelihood ratio test: chi2=4.0077  , p=0.7789  , df=7
# parameter F test:         F=0.5688  , p=0.7818  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5805  , p=0.7947  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=4.6840  , p=0.7908  , df=8
# likelihood ratio test: chi2=4.6785  , p=0.7913  , df=8
# parameter F test:         F=0.5805  , p=0.7947  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5498  , p=0.8386  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=4.9961  , p=0.8347  , df=9
# likelihood ratio test: chi2=4.9898  , p=0.8352  , df=9
# parameter F test:         F=0.5498  , p=0.8386  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5011  , p=0.8902  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=5.0646  , p=0.8868  , df=10
# likelihood ratio test: chi2=5.0582  , p=0.8873  , df=10
# parameter F test:         F=0.5011  , p=0.8902  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.3165  , p=0.2085  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=14.6511 , p=0.1990  , df=11
# likelihood ratio test: chi2=14.5974 , p=0.2017  , df=11
# parameter F test:         F=1.3165  , p=0.2085  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.2910  , p=0.2167  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=15.6898 , p=0.2059  , df=12
# likelihood ratio test: chi2=15.6282 , p=0.2089  , df=12
# parameter F test:         F=1.2910  , p=0.2167  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.4734  , p=0.1196  , df_denom=1960, df_num=13
# ssr based chi2 test:   chi2=19.4186 , p=0.1107  , df=13
# likelihood ratio test: chi2=19.3243 , p=0.1134  , df=13
# parameter F test:         F=1.4734  , p=0.1196  , df_denom=1960, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.6702  , p=0.0553  , df_denom=1957, df_num=14
# ssr based chi2 test:   chi2=23.7297 , p=0.0494  , df=14
# likelihood ratio test: chi2=23.5891 , p=0.0513  , df=14
# parameter F test:         F=1.6702  , p=0.0553  , df_denom=1957, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.5606  , p=0.0770  , df_denom=1954, df_num=15
# ssr based chi2 test:   chi2=23.7809 , p=0.0689  , df=15
# likelihood ratio test: chi2=23.6396 , p=0.0715  , df=15
# parameter F test:         F=1.5606  , p=0.0770  , df_denom=1954, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.4445  , p=0.1122  , df_denom=1951, df_num=16
# ssr based chi2 test:   chi2=23.5026 , p=0.1009  , df=16
# likelihood ratio test: chi2=23.3644 , p=0.1043  , df=16
# parameter F test:         F=1.4445  , p=0.1122  , df_denom=1951, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.4514  , p=0.1037  , df_denom=1948, df_num=17
# ssr based chi2 test:   chi2=25.1177 , p=0.0921  , df=17
# likelihood ratio test: chi2=24.9599 , p=0.0956  , df=17
# parameter F test:         F=1.4514  , p=0.1037  , df_denom=1948, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.4189  , p=0.1123  , df_denom=1945, df_num=18
# ssr based chi2 test:   chi2=26.0268 , p=0.0991  , df=18
# likelihood ratio test: chi2=25.8574 , p=0.1031  , df=18
# parameter F test:         F=1.4189  , p=0.1123  , df_denom=1945, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.3466  , p=0.1438  , df_denom=1942, df_num=19
# ssr based chi2 test:   chi2=26.0996 , p=0.1274  , df=19
# likelihood ratio test: chi2=25.9291 , p=0.1322  , df=19
# parameter F test:         F=1.3466  , p=0.1438  , df_denom=1942, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.3363  , p=0.1449  , df_denom=1939, df_num=20
# ssr based chi2 test:   chi2=27.2901 , p=0.1273  , df=20
# likelihood ratio test: chi2=27.1037 , p=0.1324  , df=20
# parameter F test:         F=1.3363  , p=0.1449  , df_denom=1939, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.3305  , p=0.1437  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=28.5610 , p=0.1249  , df=21
# likelihood ratio test: chi2=28.3569 , p=0.1303  , df=21
# parameter F test:         F=1.3305  , p=0.1437  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.3053  , p=0.1551  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=29.3851 , p=0.1342  , df=22
# likelihood ratio test: chi2=29.1690 , p=0.1401  , df=22
# parameter F test:         F=1.3053  , p=0.1551  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.3372  , p=0.1309  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=31.5037 , p=0.1109  , df=23
# likelihood ratio test: chi2=31.2553 , p=0.1166  , df=23
# parameter F test:         F=1.3372  , p=0.1309  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.2898  , p=0.1571  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=31.7428 , p=0.1335  , df=24
# likelihood ratio test: chi2=31.4905 , p=0.1401  , df=24
# parameter F test:         F=1.2898  , p=0.1571  , df_denom=1927, df_num=24
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.6991  , p=0.0097  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=6.7092  , p=0.0096  , df=1
# likelihood ratio test: chi2=6.6979  , p=0.0097  , df=1
# parameter F test:         F=6.6991  , p=0.0097  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=15.6423 , p=0.0000  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=31.3631 , p=0.0000  , df=2
# likelihood ratio test: chi2=31.1195 , p=0.0000  , df=2
# parameter F test:         F=15.6423 , p=0.0000  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=15.4892 , p=0.0000  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=46.6311 , p=0.0000  , df=3
# likelihood ratio test: chi2=46.0950 , p=0.0000  , df=3
# parameter F test:         F=15.4892 , p=0.0000  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=11.8913 , p=0.0000  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=47.7808 , p=0.0000  , df=4
# likelihood ratio test: chi2=47.2178 , p=0.0000  , df=4
# parameter F test:         F=11.8913 , p=0.0000  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=10.9946 , p=0.0000  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=55.2777 , p=0.0000  , df=5
# likelihood ratio test: chi2=54.5257 , p=0.0000  , df=5
# parameter F test:         F=10.9946 , p=0.0000  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=10.6991 , p=0.0000  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=64.6161 , p=0.0000  , df=6
# likelihood ratio test: chi2=63.5912 , p=0.0000  , df=6
# parameter F test:         F=10.6991 , p=0.0000  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=9.1077  , p=0.0000  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=64.2374 , p=0.0000  , df=7
# likelihood ratio test: chi2=63.2239 , p=0.0000  , df=7
# parameter F test:         F=9.1077  , p=0.0000  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=8.4523  , p=0.0000  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=68.2004 , p=0.0000  , df=8
# likelihood ratio test: chi2=67.0589 , p=0.0000  , df=8
# parameter F test:         F=8.4523  , p=0.0000  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=7.7418  , p=0.0000  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=70.3476 , p=0.0000  , df=9
# likelihood ratio test: chi2=69.1334 , p=0.0000  , df=9
# parameter F test:         F=7.7418  , p=0.0000  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=6.9798  , p=0.0000  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=70.5427 , p=0.0000  , df=10
# likelihood ratio test: chi2=69.3211 , p=0.0000  , df=10
# parameter F test:         F=6.9798  , p=0.0000  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=6.3270  , p=0.0000  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=70.4110 , p=0.0000  , df=11
# likelihood ratio test: chi2=69.1933 , p=0.0000  , df=11
# parameter F test:         F=6.3270  , p=0.0000  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=5.8508  , p=0.0000  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=71.1038 , p=0.0000  , df=12
# likelihood ratio test: chi2=69.8617 , p=0.0000  , df=12
# parameter F test:         F=5.8508  , p=0.0000  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=5.4026  , p=0.0000  , df_denom=1960, df_num=13
# ssr based chi2 test:   chi2=71.2015 , p=0.0000  , df=13
# likelihood ratio test: chi2=69.9554 , p=0.0000  , df=13
# parameter F test:         F=5.4026  , p=0.0000  , df_denom=1960, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=5.0065  , p=0.0000  , df_denom=1957, df_num=14
# ssr based chi2 test:   chi2=71.1297 , p=0.0000  , df=14
# likelihood ratio test: chi2=69.8855 , p=0.0000  , df=14
# parameter F test:         F=5.0065  , p=0.0000  , df_denom=1957, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=4.8585  , p=0.0000  , df_denom=1954, df_num=15
# ssr based chi2 test:   chi2=74.0333 , p=0.0000  , df=15
# likelihood ratio test: chi2=72.6861 , p=0.0000  , df=15
# parameter F test:         F=4.8585  , p=0.0000  , df_denom=1954, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=4.6531  , p=0.0000  , df_denom=1951, df_num=16
# ssr based chi2 test:   chi2=75.7082 , p=0.0000  , df=16
# likelihood ratio test: chi2=74.2994 , p=0.0000  , df=16
# parameter F test:         F=4.6531  , p=0.0000  , df_denom=1951, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=5.2829  , p=0.0000  , df_denom=1948, df_num=17
# ssr based chi2 test:   chi2=91.4230 , p=0.0000  , df=17
# likelihood ratio test: chi2=89.3781 , p=0.0000  , df=17
# parameter F test:         F=5.2829  , p=0.0000  , df_denom=1948, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=4.9459  , p=0.0000  , df_denom=1945, df_num=18
# ssr based chi2 test:   chi2=90.7192 , p=0.0000  , df=18
# likelihood ratio test: chi2=88.7043 , p=0.0000  , df=18
# parameter F test:         F=4.9459  , p=0.0000  , df_denom=1945, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=5.4834  , p=0.0000  , df_denom=1942, df_num=19
# ssr based chi2 test:   chi2=106.2770, p=0.0000  , df=19
# likelihood ratio test: chi2=103.5242, p=0.0000  , df=19
# parameter F test:         F=5.4834  , p=0.0000  , df_denom=1942, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=5.2322  , p=0.0000  , df_denom=1939, df_num=20
# ssr based chi2 test:   chi2=106.8559, p=0.0000  , df=20
# likelihood ratio test: chi2=104.0723, p=0.0000  , df=20
# parameter F test:         F=5.2322  , p=0.0000  , df_denom=1939, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=5.1806  , p=0.0000  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=111.2097, p=0.0000  , df=21
# likelihood ratio test: chi2=108.1973, p=0.0000  , df=21
# parameter F test:         F=5.1806  , p=0.0000  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=5.3784  , p=0.0000  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=121.0788, p=0.0000  , df=22
# likelihood ratio test: chi2=117.5176, p=0.0000  , df=22
# parameter F test:         F=5.3784  , p=0.0000  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=5.3314  , p=0.0000  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=125.6079, p=0.0000  , df=23
# likelihood ratio test: chi2=121.7791, p=0.0000  , df=23
# parameter F test:         F=5.3314  , p=0.0000  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=5.1631  , p=0.0000  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=127.0643, p=0.0000  , df=24
# likelihood ratio test: chi2=123.1460, p=0.0000  , df=24
# parameter F test:         F=5.1631  , p=0.0000  , df_denom=1927, df_num=24
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2059  , p=0.2723  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=1.2077  , p=0.2718  , df=1
# likelihood ratio test: chi2=1.2074  , p=0.2719  , df=1
# parameter F test:         F=1.2059  , p=0.2723  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6036  , p=0.2014  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=3.2153  , p=0.2004  , df=2
# likelihood ratio test: chi2=3.2128  , p=0.2006  , df=2
# parameter F test:         F=1.6036  , p=0.2014  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0689  , p=0.3611  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=3.2179  , p=0.3592  , df=3
# likelihood ratio test: chi2=3.2154  , p=0.3596  , df=3
# parameter F test:         F=1.0689  , p=0.3611  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3199  , p=0.2602  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=5.3034  , p=0.2576  , df=4
# likelihood ratio test: chi2=5.2964  , p=0.2582  , df=4
# parameter F test:         F=1.3199  , p=0.2602  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.7213  , p=0.1264  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=8.6544  , p=0.1237  , df=5
# likelihood ratio test: chi2=8.6357  , p=0.1245  , df=5
# parameter F test:         F=1.7213  , p=0.1264  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4443  , p=0.1939  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=8.7229  , p=0.1898  , df=6
# likelihood ratio test: chi2=8.7039  , p=0.1909  , df=6
# parameter F test:         F=1.4443  , p=0.1939  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4031  , p=0.1996  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=9.8961  , p=0.1945  , df=7
# likelihood ratio test: chi2=9.8716  , p=0.1960  , df=7
# parameter F test:         F=1.4031  , p=0.1996  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.4815  , p=0.1588  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=11.9537 , p=0.1533  , df=8
# likelihood ratio test: chi2=11.9179 , p=0.1549  , df=8
# parameter F test:         F=1.4815  , p=0.1588  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4968  , p=0.1433  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=13.6013 , p=0.1372  , df=9
# likelihood ratio test: chi2=13.5551 , p=0.1391  , df=9
# parameter F test:         F=1.4968  , p=0.1433  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3751  , p=0.1856  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=13.8979 , p=0.1777  , df=10
# likelihood ratio test: chi2=13.8496 , p=0.1800  , df=10
# parameter F test:         F=1.3751  , p=0.1856  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.4434  , p=0.1468  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=16.0629 , p=0.1388  , df=11
# likelihood ratio test: chi2=15.9984 , p=0.1412  , df=11
# parameter F test:         F=1.4434  , p=0.1468  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.4032  , p=0.1569  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=17.0526 , p=0.1476  , df=12
# likelihood ratio test: chi2=16.9799 , p=0.1504  , df=12
# parameter F test:         F=1.4032  , p=0.1569  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.2990  , p=0.2057  , df_denom=1960, df_num=13
# ssr based chi2 test:   chi2=17.1196 , p=0.1939  , df=13
# likelihood ratio test: chi2=17.0463 , p=0.1972  , df=13
# parameter F test:         F=1.2990  , p=0.2057  , df_denom=1960, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.5755  , p=0.0786  , df_denom=1957, df_num=14
# ssr based chi2 test:   chi2=22.3838 , p=0.0711  , df=14
# likelihood ratio test: chi2=22.2586 , p=0.0735  , df=14
# parameter F test:         F=1.5755  , p=0.0786  , df_denom=1957, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.6326  , p=0.0583  , df_denom=1954, df_num=15
# ssr based chi2 test:   chi2=24.8778 , p=0.0516  , df=15
# likelihood ratio test: chi2=24.7232 , p=0.0538  , df=15
# parameter F test:         F=1.6326  , p=0.0583  , df_denom=1954, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.6306  , p=0.0539  , df_denom=1951, df_num=16
# ssr based chi2 test:   chi2=26.5310 , p=0.0470  , df=16
# likelihood ratio test: chi2=26.3552 , p=0.0492  , df=16
# parameter F test:         F=1.6306  , p=0.0539  , df_denom=1951, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.5613  , p=0.0664  , df_denom=1948, df_num=17
# ssr based chi2 test:   chi2=27.0183 , p=0.0578  , df=17
# likelihood ratio test: chi2=26.8359 , p=0.0605  , df=17
# parameter F test:         F=1.5613  , p=0.0664  , df_denom=1948, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.5097  , p=0.0772  , df_denom=1945, df_num=18
# ssr based chi2 test:   chi2=27.6924 , p=0.0669  , df=18
# likelihood ratio test: chi2=27.5007 , p=0.0701  , df=18
# parameter F test:         F=1.5097  , p=0.0772  , df_denom=1945, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.6227  , p=0.0433  , df_denom=1942, df_num=19
# ssr based chi2 test:   chi2=31.4511 , p=0.0360  , df=19
# likelihood ratio test: chi2=31.2041 , p=0.0383  , df=19
# parameter F test:         F=1.6227  , p=0.0433  , df_denom=1942, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.5450  , p=0.0579  , df_denom=1939, df_num=20
# ssr based chi2 test:   chi2=31.5527 , p=0.0483  , df=20
# likelihood ratio test: chi2=31.3040 , p=0.0513  , df=20
# parameter F test:         F=1.5450  , p=0.0579  , df_denom=1939, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.4854  , p=0.0721  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=31.8865 , p=0.0601  , df=21
# likelihood ratio test: chi2=31.6324 , p=0.0638  , df=21
# parameter F test:         F=1.4854  , p=0.0721  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.5054  , p=0.0618  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=33.8888 , p=0.0504  , df=22
# likelihood ratio test: chi2=33.6018 , p=0.0539  , df=22
# parameter F test:         F=1.5054  , p=0.0618  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.4585  , p=0.0737  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=34.3620 , p=0.0601  , df=23
# likelihood ratio test: chi2=34.0668 , p=0.0642  , df=23
# parameter F test:         F=1.4585  , p=0.0737  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.7271  , p=0.0157  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=42.5045 , p=0.0113  , df=24
# likelihood ratio test: chi2=42.0538 , p=0.0127  , df=24
# parameter F test:         F=1.7271  , p=0.0157  , df_denom=1927, df_num=24
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4428  , p=0.5059  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=0.4434  , p=0.5055  , df=1
# likelihood ratio test: chi2=0.4434  , p=0.5055  , df=1
# parameter F test:         F=0.4428  , p=0.5059  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9389  , p=0.1441  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=3.8874  , p=0.1432  , df=2
# likelihood ratio test: chi2=3.8837  , p=0.1434  , df=2
# parameter F test:         F=1.9389  , p=0.1441  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0534  , p=0.1044  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=6.1819  , p=0.1031  , df=3
# likelihood ratio test: chi2=6.1723  , p=0.1035  , df=3
# parameter F test:         F=2.0534  , p=0.1044  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5433  , p=0.1871  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=6.2010  , p=0.1846  , df=4
# likelihood ratio test: chi2=6.1913  , p=0.1853  , df=4
# parameter F test:         F=1.5433  , p=0.1871  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2153  , p=0.2993  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=6.1100  , p=0.2957  , df=5
# likelihood ratio test: chi2=6.1007  , p=0.2965  , df=5
# parameter F test:         F=1.2153  , p=0.2993  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3944  , p=0.2131  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=8.4214  , p=0.2088  , df=6
# likelihood ratio test: chi2=8.4036  , p=0.2100  , df=6
# parameter F test:         F=1.3944  , p=0.2131  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2125  , p=0.2922  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=8.5519  , p=0.2864  , df=7
# likelihood ratio test: chi2=8.5336  , p=0.2879  , df=7
# parameter F test:         F=1.2125  , p=0.2922  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1514  , p=0.3254  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=9.2905  , p=0.3184  , df=8
# likelihood ratio test: chi2=9.2689  , p=0.3201  , df=8
# parameter F test:         F=1.1514  , p=0.3254  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3809  , p=0.1911  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=12.5478 , p=0.1842  , df=9
# likelihood ratio test: chi2=12.5084 , p=0.1861  , df=9
# parameter F test:         F=1.3809  , p=0.1911  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7527  , p=0.0643  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=17.7143 , p=0.0600  , df=10
# likelihood ratio test: chi2=17.6359 , p=0.0614  , df=10
# parameter F test:         F=1.7527  , p=0.0643  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.6787  , p=0.0723  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=18.6819 , p=0.0670  , df=11
# likelihood ratio test: chi2=18.5947 , p=0.0688  , df=11
# parameter F test:         F=1.6787  , p=0.0723  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.5990  , p=0.0851  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=19.4318 , p=0.0786  , df=12
# likelihood ratio test: chi2=19.3375 , p=0.0807  , df=12
# parameter F test:         F=1.5990  , p=0.0851  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.5302  , p=0.0991  , df_denom=1960, df_num=13
# ssr based chi2 test:   chi2=20.1660 , p=0.0911  , df=13
# likelihood ratio test: chi2=20.0644 , p=0.0936  , df=13
# parameter F test:         F=1.5302  , p=0.0991  , df_denom=1960, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.5561  , p=0.0843  , df_denom=1957, df_num=14
# ssr based chi2 test:   chi2=22.1085 , p=0.0764  , df=14
# likelihood ratio test: chi2=21.9864 , p=0.0789  , df=14
# parameter F test:         F=1.5561  , p=0.0843  , df_denom=1957, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.4500  , p=0.1159  , df_denom=1954, df_num=15
# ssr based chi2 test:   chi2=22.0946 , p=0.1053  , df=15
# likelihood ratio test: chi2=21.9726 , p=0.1085  , df=15
# parameter F test:         F=1.4500  , p=0.1159  , df_denom=1954, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.3753  , p=0.1445  , df_denom=1951, df_num=16
# ssr based chi2 test:   chi2=22.3777 , p=0.1314  , df=16
# likelihood ratio test: chi2=22.2525 , p=0.1352  , df=16
# parameter F test:         F=1.3753  , p=0.1445  , df_denom=1951, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.3450  , p=0.1552  , df_denom=1948, df_num=17
# ssr based chi2 test:   chi2=23.2763 , p=0.1405  , df=17
# likelihood ratio test: chi2=23.1407 , p=0.1447  , df=17
# parameter F test:         F=1.3450  , p=0.1552  , df_denom=1948, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.2654  , p=0.2009  , df_denom=1945, df_num=18
# ssr based chi2 test:   chi2=23.2106 , p=0.1826  , df=18
# likelihood ratio test: chi2=23.0758 , p=0.1877  , df=18
# parameter F test:         F=1.2654  , p=0.2009  , df_denom=1945, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.2077  , p=0.2413  , df_denom=1942, df_num=19
# ssr based chi2 test:   chi2=23.4069 , p=0.2199  , df=19
# likelihood ratio test: chi2=23.2697 , p=0.2257  , df=19
# parameter F test:         F=1.2077  , p=0.2413  , df_denom=1942, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.2576  , p=0.1974  , df_denom=1939, df_num=20
# ssr based chi2 test:   chi2=25.6829 , p=0.1765  , df=20
# likelihood ratio test: chi2=25.5178 , p=0.1823  , df=20
# parameter F test:         F=1.2576  , p=0.1974  , df_denom=1939, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.2677  , p=0.1855  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=27.2137 , p=0.1639  , df=21
# likelihood ratio test: chi2=27.0283 , p=0.1699  , df=21
# parameter F test:         F=1.2677  , p=0.1855  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.2286  , p=0.2120  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=27.6574 , p=0.1873  , df=22
# likelihood ratio test: chi2=27.4658 , p=0.1941  , df=22
# parameter F test:         F=1.2286  , p=0.2120  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.1906  , p=0.2418  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=28.0507 , p=0.2139  , df=23
# likelihood ratio test: chi2=27.8535 , p=0.2214  , df=23
# parameter F test:         F=1.1906  , p=0.2418  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.4142  , p=0.0876  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=34.8030 , p=0.0714  , df=24
# likelihood ratio test: chi2=34.5000 , p=0.0762  , df=24
# parameter F test:         F=1.4142  , p=0.0876  , df_denom=1927, df_num=24
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0142  , p=0.9051  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=0.0142  , p=0.9050  , df=1
# likelihood ratio test: chi2=0.0142  , p=0.9050  , df=1
# parameter F test:         F=0.0142  , p=0.9051  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1334  , p=0.8751  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=0.2674  , p=0.8748  , df=2
# likelihood ratio test: chi2=0.2674  , p=0.8748  , df=2
# parameter F test:         F=0.1334  , p=0.8751  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4082  , p=0.7471  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=1.2291  , p=0.7460  , df=3
# likelihood ratio test: chi2=1.2287  , p=0.7461  , df=3
# parameter F test:         F=0.4082  , p=0.7471  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9153  , p=0.4540  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=3.6778  , p=0.4514  , df=4
# likelihood ratio test: chi2=3.6744  , p=0.4519  , df=4
# parameter F test:         F=0.9153  , p=0.4540  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7791  , p=0.5647  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=3.9170  , p=0.5614  , df=5
# likelihood ratio test: chi2=3.9131  , p=0.5620  , df=5
# parameter F test:         F=0.7791  , p=0.5647  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7130  , p=0.6392  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=4.3058  , p=0.6354  , df=6
# likelihood ratio test: chi2=4.3012  , p=0.6360  , df=6
# parameter F test:         F=0.7130  , p=0.6392  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1636  , p=0.3205  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=8.2073  , p=0.3147  , df=7
# likelihood ratio test: chi2=8.1904  , p=0.3161  , df=7
# parameter F test:         F=1.1636  , p=0.3205  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2006  , p=0.2945  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=9.6876  , p=0.2876  , df=8
# likelihood ratio test: chi2=9.6641  , p=0.2894  , df=8
# parameter F test:         F=1.2006  , p=0.2945  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1657  , p=0.3129  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=10.5924 , p=0.3047  , df=9
# likelihood ratio test: chi2=10.5644 , p=0.3068  , df=9
# parameter F test:         F=1.1657  , p=0.3129  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0433  , p=0.4039  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=10.5442 , p=0.3941  , df=10
# likelihood ratio test: chi2=10.5164 , p=0.3964  , df=10
# parameter F test:         F=1.0433  , p=0.4039  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.0319  , p=0.4149  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=11.4834 , p=0.4037  , df=11
# likelihood ratio test: chi2=11.4504 , p=0.4063  , df=11
# parameter F test:         F=1.0319  , p=0.4149  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.1181  , p=0.3402  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=13.5886 , p=0.3277  , df=12
# likelihood ratio test: chi2=13.5424 , p=0.3309  , df=12
# parameter F test:         F=1.1181  , p=0.3402  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.0363  , p=0.4127  , df_denom=1960, df_num=13
# ssr based chi2 test:   chi2=13.6570 , p=0.3984  , df=13
# likelihood ratio test: chi2=13.6103 , p=0.4019  , df=13
# parameter F test:         F=1.0363  , p=0.4127  , df_denom=1960, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.9887  , p=0.4621  , df_denom=1957, df_num=14
# ssr based chi2 test:   chi2=14.0464 , p=0.4463  , df=14
# likelihood ratio test: chi2=13.9969 , p=0.4499  , df=14
# parameter F test:         F=0.9887  , p=0.4621  , df_denom=1957, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.9339  , p=0.5251  , df_denom=1954, df_num=15
# ssr based chi2 test:   chi2=14.2311 , p=0.5081  , df=15
# likelihood ratio test: chi2=14.1803 , p=0.5119  , df=15
# parameter F test:         F=0.9339  , p=0.5251  , df_denom=1954, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.9002  , p=0.5688  , df_denom=1951, df_num=16
# ssr based chi2 test:   chi2=14.6467 , p=0.5507  , df=16
# likelihood ratio test: chi2=14.5929 , p=0.5546  , df=16
# parameter F test:         F=0.9002  , p=0.5688  , df_denom=1951, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=0.8718  , p=0.6084  , df_denom=1948, df_num=17
# ssr based chi2 test:   chi2=15.0867 , p=0.5892  , df=17
# likelihood ratio test: chi2=15.0296 , p=0.5933  , df=17
# parameter F test:         F=0.8718  , p=0.6084  , df_denom=1948, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=0.8317  , p=0.6637  , df_denom=1945, df_num=18
# ssr based chi2 test:   chi2=15.2562 , p=0.6443  , df=18
# likelihood ratio test: chi2=15.1978 , p=0.6483  , df=18
# parameter F test:         F=0.8317  , p=0.6637  , df_denom=1945, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=0.8130  , p=0.6934  , df_denom=1942, df_num=19
# ssr based chi2 test:   chi2=15.7565 , p=0.6735  , df=19
# likelihood ratio test: chi2=15.6942 , p=0.6776  , df=19
# parameter F test:         F=0.8130  , p=0.6934  , df_denom=1942, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.5291  , p=0.0624  , df_denom=1939, df_num=20
# ssr based chi2 test:   chi2=31.2292 , p=0.0522  , df=20
# likelihood ratio test: chi2=30.9855 , p=0.0554  , df=20
# parameter F test:         F=1.5291  , p=0.0624  , df_denom=1939, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.5047  , p=0.0658  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=32.2996 , p=0.0546  , df=21
# likelihood ratio test: chi2=32.0389 , p=0.0580  , df=21
# parameter F test:         F=1.5047  , p=0.0658  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.4503  , p=0.0807  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=32.6499 , p=0.0670  , df=22
# likelihood ratio test: chi2=32.3833 , p=0.0711  , df=22
# parameter F test:         F=1.4503  , p=0.0807  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.3879  , p=0.1037  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=32.7002 , p=0.0864  , df=23
# likelihood ratio test: chi2=32.4327 , p=0.0915  , df=23
# parameter F test:         F=1.3879  , p=0.1037  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.3187  , p=0.1380  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=32.4543 , p=0.1161  , df=24
# likelihood ratio test: chi2=32.1906 , p=0.1223  , df=24
# parameter F test:         F=1.3187  , p=0.1380  , df_denom=1927, df_num=24
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.6810  , p=0.1017  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=2.6850  , p=0.1013  , df=1
# likelihood ratio test: chi2=2.6832  , p=0.1014  , df=1
# parameter F test:         F=2.6810  , p=0.1017  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0928  , p=0.3355  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=2.1910  , p=0.3344  , df=2
# likelihood ratio test: chi2=2.1898  , p=0.3346  , df=2
# parameter F test:         F=1.0928  , p=0.3355  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7954  , p=0.4964  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=2.3946  , p=0.4946  , df=3
# likelihood ratio test: chi2=2.3932  , p=0.4949  , df=3
# parameter F test:         F=0.7954  , p=0.4964  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7257  , p=0.5743  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=2.9159  , p=0.5720  , df=4
# likelihood ratio test: chi2=2.9137  , p=0.5724  , df=4
# parameter F test:         F=0.7257  , p=0.5743  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0480  , p=0.3877  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=5.2689  , p=0.3840  , df=5
# likelihood ratio test: chi2=5.2620  , p=0.3848  , df=5
# parameter F test:         F=1.0480  , p=0.3877  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9091  , p=0.4872  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=5.4904  , p=0.4826  , df=6
# likelihood ratio test: chi2=5.4828  , p=0.4835  , df=6
# parameter F test:         F=0.9091  , p=0.4872  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6301  , p=0.7314  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=4.4438  , p=0.7275  , df=7
# likelihood ratio test: chi2=4.4389  , p=0.7281  , df=7
# parameter F test:         F=0.6301  , p=0.7314  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5448  , p=0.8232  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=4.3960  , p=0.8197  , df=8
# likelihood ratio test: chi2=4.3912  , p=0.8202  , df=8
# parameter F test:         F=0.5448  , p=0.8232  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6216  , p=0.7796  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=5.6481  , p=0.7746  , df=9
# likelihood ratio test: chi2=5.6401  , p=0.7753  , df=9
# parameter F test:         F=0.6216  , p=0.7796  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6407  , p=0.7797  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=6.4755  , p=0.7739  , df=10
# likelihood ratio test: chi2=6.4650  , p=0.7748  , df=10
# parameter F test:         F=0.6407  , p=0.7797  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.7288  , p=0.7116  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=8.1104  , p=0.7034  , df=11
# likelihood ratio test: chi2=8.0939  , p=0.7049  , df=11
# parameter F test:         F=0.7288  , p=0.7116  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.7324  , p=0.7206  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=8.9007  , p=0.7114  , df=12
# likelihood ratio test: chi2=8.8808  , p=0.7131  , df=12
# parameter F test:         F=0.7324  , p=0.7206  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.7322  , p=0.7324  , df_denom=1960, df_num=13
# ssr based chi2 test:   chi2=9.6501  , p=0.7223  , df=13
# likelihood ratio test: chi2=9.6267  , p=0.7241  , df=13
# parameter F test:         F=0.7322  , p=0.7324  , df_denom=1960, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.9861  , p=0.4648  , df_denom=1957, df_num=14
# ssr based chi2 test:   chi2=14.0094 , p=0.4490  , df=14
# likelihood ratio test: chi2=13.9602 , p=0.4527  , df=14
# parameter F test:         F=0.9861  , p=0.4648  , df_denom=1957, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.9363  , p=0.5224  , df_denom=1954, df_num=15
# ssr based chi2 test:   chi2=14.2673 , p=0.5054  , df=15
# likelihood ratio test: chi2=14.2163 , p=0.5092  , df=15
# parameter F test:         F=0.9363  , p=0.5224  , df_denom=1954, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.9055  , p=0.5625  , df_denom=1951, df_num=16
# ssr based chi2 test:   chi2=14.7334 , p=0.5442  , df=16
# likelihood ratio test: chi2=14.6790 , p=0.5483  , df=16
# parameter F test:         F=0.9055  , p=0.5625  , df_denom=1951, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.0383  , p=0.4119  , df_denom=1948, df_num=17
# ssr based chi2 test:   chi2=17.9682 , p=0.3908  , df=17
# likelihood ratio test: chi2=17.8873 , p=0.3960  , df=17
# parameter F test:         F=1.0383  , p=0.4119  , df_denom=1948, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.0023  , p=0.4535  , df_denom=1945, df_num=18
# ssr based chi2 test:   chi2=18.3851 , p=0.4306  , df=18
# likelihood ratio test: chi2=18.3004 , p=0.4360  , df=18
# parameter F test:         F=1.0023  , p=0.4535  , df_denom=1945, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.0059  , p=0.4503  , df_denom=1942, df_num=19
# ssr based chi2 test:   chi2=19.4960 , p=0.4255  , df=19
# likelihood ratio test: chi2=19.4007 , p=0.4314  , df=19
# parameter F test:         F=1.0059  , p=0.4503  , df_denom=1942, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=0.9496  , p=0.5227  , df_denom=1939, df_num=20
# ssr based chi2 test:   chi2=19.3931 , p=0.4964  , df=20
# likelihood ratio test: chi2=19.2987 , p=0.5025  , df=20
# parameter F test:         F=0.9496  , p=0.5227  , df_denom=1939, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=0.9454  , p=0.5308  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=20.2948 , p=0.5027  , df=21
# likelihood ratio test: chi2=20.1915 , p=0.5092  , df=21
# parameter F test:         F=0.9454  , p=0.5308  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=0.9922  , p=0.4707  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=22.3377 , p=0.4399  , df=22
# likelihood ratio test: chi2=22.2125 , p=0.4473  , df=22
# parameter F test:         F=0.9922  , p=0.4707  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.0545  , p=0.3910  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=24.8440 , p=0.3584  , df=23
# likelihood ratio test: chi2=24.6892 , p=0.3665  , df=23
# parameter F test:         F=1.0545  , p=0.3910  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.0122  , p=0.4458  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=24.9099 , p=0.4107  , df=24
# likelihood ratio test: chi2=24.7542 , p=0.4192  , df=24
# parameter F test:         F=1.0122  , p=0.4458  , df_denom=1927, df_num=24
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1292  , p=0.7193  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=0.1294  , p=0.7190  , df=1
# likelihood ratio test: chi2=0.1294  , p=0.7190  , df=1
# parameter F test:         F=0.1292  , p=0.7193  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9027  , p=0.1494  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=3.8150  , p=0.1484  , df=2
# likelihood ratio test: chi2=3.8114  , p=0.1487  , df=2
# parameter F test:         F=1.9027  , p=0.1494  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4905  , p=0.2152  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=4.4873  , p=0.2134  , df=3
# likelihood ratio test: chi2=4.4823  , p=0.2139  , df=3
# parameter F test:         F=1.4905  , p=0.2152  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3956  , p=0.2330  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=5.6077  , p=0.2304  , df=4
# likelihood ratio test: chi2=5.5999  , p=0.2311  , df=4
# parameter F test:         F=1.3956  , p=0.2330  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2164  , p=0.2987  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=6.1159  , p=0.2951  , df=5
# likelihood ratio test: chi2=6.1066  , p=0.2960  , df=5
# parameter F test:         F=1.2164  , p=0.2987  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0078  , p=0.4183  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=6.0864  , p=0.4136  , df=6
# likelihood ratio test: chi2=6.0772  , p=0.4146  , df=6
# parameter F test:         F=1.0078  , p=0.4183  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9634  , p=0.4563  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=6.7952  , p=0.4505  , df=7
# likelihood ratio test: chi2=6.7836  , p=0.4517  , df=7
# parameter F test:         F=0.9634  , p=0.4563  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8527  , p=0.5562  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=6.8802  , p=0.5496  , df=8
# likelihood ratio test: chi2=6.8683  , p=0.5509  , df=8
# parameter F test:         F=0.8527  , p=0.5562  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8278  , p=0.5904  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=7.5220  , p=0.5829  , df=9
# likelihood ratio test: chi2=7.5078  , p=0.5844  , df=9
# parameter F test:         F=0.8278  , p=0.5904  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8575  , p=0.5730  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=8.6662  , p=0.5640  , df=10
# likelihood ratio test: chi2=8.6474  , p=0.5659  , df=10
# parameter F test:         F=0.8575  , p=0.5730  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.8197  , p=0.6204  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=9.1218  , p=0.6107  , df=11
# likelihood ratio test: chi2=9.1009  , p=0.6126  , df=11
# parameter F test:         F=0.8197  , p=0.6204  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.7640  , p=0.6883  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=9.2850  , p=0.6784  , df=12
# likelihood ratio test: chi2=9.2634  , p=0.6803  , df=12
# parameter F test:         F=0.7640  , p=0.6883  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ...
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.6215  , p=0.0370  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=34.8068 , p=0.0296  , df=21
# likelihood ratio test: chi2=34.5042 , p=0.0320  , df=21
# parameter F test:         F=1.6215  , p=0.0370  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.5652  , p=0.0457  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=35.2355 , p=0.0366  , df=22
# likelihood ratio test: chi2=34.9253 , p=0.0394  , df=22
# parameter F test:         F=1.5652  , p=0.0457  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.5352  , p=0.0499  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=36.1706 , p=0.0396  , df=23
# likelihood ratio test: chi2=35.8437 , p=0.0428  , df=23
# parameter F test:         F=1.5352  , p=0.0499  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.4887  , p=0.0600  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=36.6368 , p=0.0475  , df=24
# likelihood ratio test: chi2=36.3013 , p=0.0513  , df=24
# parameter F test:         F=1.4887  , p=0.0600  , df_denom=1927, df_num=24
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6758  , p=0.4111  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=0.6768  , p=0.4107  , df=1
# likelihood ratio test: chi2=0.6767  , p=0.4107  , df=1
# parameter F test:         F=0.6758  , p=0.4111  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2997  , p=0.7411  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=0.6010  , p=0.7405  , df=2
# likelihood ratio test: chi2=0.6009  , p=0.7405  , df=2
# parameter F test:         F=0.2997  , p=0.7411  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8715  , p=0.4551  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=2.6237  , p=0.4533  , df=3
# likelihood ratio test: chi2=2.6220  , p=0.4536  , df=3
# parameter F test:         F=0.8715  , p=0.4551  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6960  , p=0.5947  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=2.7968  , p=0.5924  , df=4
# likelihood ratio test: chi2=2.7948  , p=0.5927  , df=4
# parameter F test:         F=0.6960  , p=0.5947  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7219  , p=0.6070  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=3.6295  , p=0.6039  , df=5
# likelihood ratio test: chi2=3.6262  , p=0.6044  , df=5
# parameter F test:         F=0.7219  , p=0.6070  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6348  , p=0.7025  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=3.8337  , p=0.6992  , df=6
# likelihood ratio test: chi2=3.8300  , p=0.6997  , df=6
# parameter F test:         F=0.6348  , p=0.7025  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9757  , p=0.4471  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=6.8819  , p=0.4413  , df=7
# likelihood ratio test: chi2=6.8701  , p=0.4425  , df=7
# parameter F test:         F=0.9757  , p=0.4471  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9694  , p=0.4581  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=7.8223  , p=0.4510  , df=8
# likelihood ratio test: chi2=7.8069  , p=0.4526  , df=8
# parameter F test:         F=0.9694  , p=0.4581  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0202  , p=0.4211  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=9.2703  , p=0.4127  , df=9
# likelihood ratio test: chi2=9.2488  , p=0.4146  , df=9
# parameter F test:         F=1.0202  , p=0.4211  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8993  , p=0.5330  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=9.0888  , p=0.5237  , df=10
# likelihood ratio test: chi2=9.0682  , p=0.5256  , df=10
# parameter F test:         F=0.8993  , p=0.5330  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.7992  , p=0.6411  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=8.8946  , p=0.6316  , df=11
# likelihood ratio test: chi2=8.8748  , p=0.6335  , df=11
# parameter F test:         F=0.7992  , p=0.6411  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.7698  , p=0.6824  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=9.3548  , p=0.6724  , df=12
# likelihood ratio test: chi2=9.3329  , p=0.6743  , df=12
# parameter F test:         F=0.7698  , p=0.6824  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.7257  , p=0.7392  , df_denom=1960, df_num=13
# ssr based chi2 test:   chi2=9.5637  , p=0.7292  , df=13
# likelihood ratio test: chi2=9.5407  , p=0.7310  , df=13
# parameter F test:         F=0.7257  , p=0.7392  , df_denom=1960, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.7078  , p=0.7684  , df_denom=1957, df_num=14
# ssr based chi2 test:   chi2=10.0557 , p=0.7581  , df=14
# likelihood ratio test: chi2=10.0303 , p=0.7600  , df=14
# parameter F test:         F=0.7078  , p=0.7684  , df_denom=1957, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.6732  , p=0.8131  , df_denom=1954, df_num=15
# ssr based chi2 test:   chi2=10.2579 , p=0.8032  , df=15
# likelihood ratio test: chi2=10.2314 , p=0.8049  , df=15
# parameter F test:         F=0.6732  , p=0.8131  , df_denom=1954, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.6877  , p=0.8088  , df_denom=1951, df_num=16
# ssr based chi2 test:   chi2=11.1886 , p=0.7977  , df=16
# likelihood ratio test: chi2=11.1572 , p=0.7997  , df=16
# parameter F test:         F=0.6877  , p=0.8088  , df_denom=1951, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=0.6904  , p=0.8153  , df_denom=1948, df_num=17
# ssr based chi2 test:   chi2=11.9468 , p=0.8033  , df=17
# likelihood ratio test: chi2=11.9110 , p=0.8055  , df=17
# parameter F test:         F=0.6904  , p=0.8153  , df_denom=1948, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=0.7161  , p=0.7975  , df_denom=1945, df_num=18
# ssr based chi2 test:   chi2=13.1353 , p=0.7835  , df=18
# likelihood ratio test: chi2=13.0920 , p=0.7861  , df=18
# parameter F test:         F=0.7161  , p=0.7975  , df_denom=1945, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=0.7127  , p=0.8091  , df_denom=1942, df_num=19
# ssr based chi2 test:   chi2=13.8134 , p=0.7945  , df=19
# likelihood ratio test: chi2=13.7655 , p=0.7972  , df=19
# parameter F test:         F=0.7127  , p=0.8091  , df_denom=1942, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=0.7239  , p=0.8048  , df_denom=1939, df_num=20
# ssr based chi2 test:   chi2=14.7836 , p=0.7887  , df=20
# likelihood ratio test: chi2=14.7286 , p=0.7917  , df=20
# parameter F test:         F=0.7239  , p=0.8048  , df_denom=1939, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.0036  , p=0.4550  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=21.5448 , p=0.4261  , df=21
# likelihood ratio test: chi2=21.4283 , p=0.4331  , df=21
# parameter F test:         F=1.0036  , p=0.4550  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=0.9671  , p=0.5042  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=21.7706 , p=0.4737  , df=22
# likelihood ratio test: chi2=21.6516 , p=0.4808  , df=22
# parameter F test:         F=0.9671  , p=0.5042  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=0.9144  , p=0.5792  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=21.5428 , p=0.5480  , df=23
# likelihood ratio test: chi2=21.4262 , p=0.5551  , df=23
# parameter F test:         F=0.9144  , p=0.5792  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.0621  , p=0.3807  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=26.1398 , p=0.3461  , df=24
# likelihood ratio test: chi2=25.9684 , p=0.3548  , df=24
# parameter F test:         F=1.0621  , p=0.3807  , df_denom=1927, df_num=24
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0902  , p=0.7639  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=0.0904  , p=0.7637  , df=1
# likelihood ratio test: chi2=0.0904  , p=0.7637  , df=1
# parameter F test:         F=0.0902  , p=0.7639  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2845  , p=0.2770  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=2.5754  , p=0.2759  , df=2
# likelihood ratio test: chi2=2.5737  , p=0.2761  , df=2
# parameter F test:         F=1.2845  , p=0.2770  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0288  , p=0.3788  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=3.0972  , p=0.3769  , df=3
# likelihood ratio test: chi2=3.0948  , p=0.3772  , df=3
# parameter F test:         F=1.0288  , p=0.3788  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0307  , p=0.3899  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=4.1416  , p=0.3872  , df=4
# likelihood ratio test: chi2=4.1373  , p=0.3877  , df=4
# parameter F test:         F=1.0307  , p=0.3899  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1152  , p=0.3501  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=5.6068  , p=0.3464  , df=5
# likelihood ratio test: chi2=5.5990  , p=0.3472  , df=5
# parameter F test:         F=1.1152  , p=0.3501  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9073  , p=0.4885  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=5.4798  , p=0.4839  , df=6
# likelihood ratio test: chi2=5.4723  , p=0.4848  , df=6
# parameter F test:         F=0.9073  , p=0.4885  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8464  , p=0.5487  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=5.9697  , p=0.5433  , df=7
# likelihood ratio test: chi2=5.9608  , p=0.5443  , df=7
# parameter F test:         F=0.8464  , p=0.5487  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9394  , p=0.4825  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=7.5800  , p=0.4755  , df=8
# likelihood ratio test: chi2=7.5656  , p=0.4770  , df=8
# parameter F test:         F=0.9394  , p=0.4825  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7712  , p=0.6433  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=7.0078  , p=0.6363  , df=9
# likelihood ratio test: chi2=6.9955  , p=0.6376  , df=9
# parameter F test:         F=0.7712  , p=0.6433  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7484  , p=0.6790  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=7.5639  , p=0.6713  , df=10
# likelihood ratio test: chi2=7.5496  , p=0.6727  , df=10
# parameter F test:         F=0.7484  , p=0.6790  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.7296  , p=0.7108  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=8.1193  , p=0.7026  , df=11
# likelihood ratio test: chi2=8.1028  , p=0.7041  , df=11
# parameter F test:         F=0.7296  , p=0.7108  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.8271  , p=0.0391  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=22.2046 , p=0.0353  , df=12
# likelihood ratio test: chi2=22.0815 , p=0.0366  , df=12
# parameter F test:         F=1.8271  , p=0.0391  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.6809  , p=0.0587  , df_denom=1960, df_num=13
# ssr based chi2 test:   chi2=22.1524 , p=0.0530  , df=13
# likelihood ratio test: chi2=22.0298 , p=0.0549  , df=13
# parameter F test:         F=1.6809  , p=0.0587  , df_denom=1960, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.5808  , p=0.0771  , df_denom=1957, df_num=14
# ssr based chi2 test:   chi2=22.4587 , p=0.0697  , df=14
# likelihood ratio test: chi2=22.3327 , p=0.0720  , df=14
# parameter F test:         F=1.5808  , p=0.0771  , df_denom=1957, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.4533  , p=0.1145  , df_denom=1954, df_num=15
# ssr based chi2 test:   chi2=22.1449 , p=0.1041  , df=15
# likelihood ratio test: chi2=22.0223 , p=0.1072  , df=15
# parameter F test:         F=1.4533  , p=0.1145  , df_denom=1954, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=1.3825  , p=0.1408  , df_denom=1951, df_num=16
# ssr based chi2 test:   chi2=22.4941 , p=0.1279  , df=16
# likelihood ratio test: chi2=22.3676 , p=0.1317  , df=16
# parameter F test:         F=1.3825  , p=0.1408  , df_denom=1951, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.3878  , p=0.1324  , df_denom=1948, df_num=17
# ssr based chi2 test:   chi2=24.0167 , p=0.1190  , df=17
# likelihood ratio test: chi2=23.8724 , p=0.1229  , df=17
# parameter F test:         F=1.3878  , p=0.1324  , df_denom=1948, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.3909  , p=0.1255  , df_denom=1945, df_num=18
# ssr based chi2 test:   chi2=25.5133 , p=0.1114  , df=18
# likelihood ratio test: chi2=25.3505 , p=0.1156  , df=18
# parameter F test:         F=1.3909  , p=0.1255  , df_denom=1945, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.3223  , p=0.1582  , df_denom=1942, df_num=19
# ssr based chi2 test:   chi2=25.6280 , p=0.1409  , df=19
# likelihood ratio test: chi2=25.4637 , p=0.1458  , df=19
# parameter F test:         F=1.3223  , p=0.1582  , df_denom=1942, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.2682  , p=0.1896  , df_denom=1939, df_num=20
# ssr based chi2 test:   chi2=25.9002 , p=0.1691  , df=20
# likelihood ratio test: chi2=25.7322 , p=0.1748  , df=20
# parameter F test:         F=1.2682  , p=0.1896  , df_denom=1939, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.2202  , p=0.2229  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=26.1941 , p=0.1991  , df=21
# likelihood ratio test: chi2=26.0223 , p=0.2056  , df=21
# parameter F test:         F=1.2202  , p=0.2229  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.1831  , p=0.2522  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=26.6336 , p=0.2255  , df=22
# likelihood ratio test: chi2=26.4559 , p=0.2326  , df=22
# parameter F test:         F=1.1831  , p=0.2522  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.2406  , p=0.1982  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=29.2286 , p=0.1728  , df=23
# likelihood ratio test: chi2=29.0147 , p=0.1798  , df=23
# parameter F test:         F=1.2406  , p=0.1982  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.4498  , p=0.0733  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=35.6790 , p=0.0589  , df=24
# likelihood ratio test: chi2=35.3607 , p=0.0632  , df=24
# parameter F test:         F=1.4498  , p=0.0733  , df_denom=1927, df_num=24

# %%
# Granger Causality test results

for key, values in cor.items():
    print('\n')
    print('\033[1m' + key + '\033[0m')
    for i in range(1, lag+1):
        print('lag', i, '=', values[i][0]['lrtest'][1])
# Out:
# BTC_NXT
# lag 1 = 0.583321928118
# lag 2 = 0.955234350412
# lag 3 = 0.936066163662
# lag 4 = 0.832031431649
# lag 5 = 0.53383127305
# lag 6 = 0.655537375215
# lag 7 = 0.778889316687
# lag 8 = 0.791323717864
# lag 9 = 0.835196480211
# lag 10 = 0.887257687389
# lag 11 = 0.201681171882
# lag 12 = 0.208863737611
# lag 13 = 0.113386148486
# lag 14 = 0.0513347567588
# lag 15 = 0.07147256456
# lag 16 = 0.104334038764
# lag 17 = 0.0956101231425
# lag 18 = 0.103063086899
# lag 19 = 0.132175844343
# lag 20 = 0.132370435405
# lag 21 = 0.130316875833
# lag 22 = 0.14009897307
# lag 23 = 0.116648414346
# lag 24 = 0.140137442491
#
#
# BTC_BCH
# lag 1 = 0.00965252620289
# lag 2 = 1.74779285531e-07
# lag 3 = 5.4137932071e-10
# lag 4 = 1.37363858489e-09
# lag 5 = 1.63409055271e-10
# lag 6 = 8.36282278226e-12
# lag 7 = 3.41774052132e-11
# lag 8 = 1.88746542703e-11
# lag 9 = 2.25129849248e-11
# lag 10 = 5.99477559372e-11
# lag 11 = 1.73845860652e-10
# lag 12 = 3.39956206694e-10
# lag 13 = 8.18005942476e-10
# lag 14 = 2.02444375e-09
# lag 15 = 1.47798276585e-09
# lag 16 = 1.74150831162e-09
# lag 17 = 7.91905984347e-12
# lag 18 = 2.46503596696e-11
# lag 19 = 1.2261033527e-13
# lag 20 = 2.33587576739e-13
# lag 21 = 9.95587805892e-14
# lag 22 = 4.91603352332e-15
# lag 23 = 1.98918338297e-15
# lag 24 = 2.66077213645e-15
#
#
# BTC_DASH
# lag 1 = 0.271853948069
# lag 2 = 0.200612747606
# lag 3 = 0.359598931513
# lag 4 = 0.25821686088
# lag 5 = 0.124507872975
# lag 6 = 0.190928386506
# lag 7 = 0.195965398104
# lag 8 = 0.154902992911
# lag 9 = 0.139055414647
# lag 10 = 0.179962959731
# lag 11 = 0.141189054429
# lag 12 = 0.150356606027
# lag 13 = 0.197197848909
# lag 14 = 0.0734540508979
# lag 15 = 0.0537861867022
# lag 16 = 0.049230493894
# lag 17 = 0.0605193766401
# lag 18 = 0.0700710415803
# lag 19 = 0.0383387630826
# lag 20 = 0.0513034504725
# lag 21 = 0.063758624404
# lag 22 = 0.0538954133653
# lag 23 = 0.0641981556272
# lag 24 = 0.0127268684729
#
#
# BTC_LTC
# lag 1 = 0.50548897009
# lag 2 = 0.143441163269
# lag 3 = 0.103521339741
# lag 4 = 0.185306633545
# lag 5 = 0.296546684335
# lag 6 = 0.209998498305
# lag 7 = 0.287896189616
# lag 8 = 0.320125829298
# lag 9 = 0.186139624515
# lag 10 = 0.0614252178706
# lag 11 = 0.0687688373789
# lag 12 = 0.0807031518301
# lag 13 = 0.0936165270346
# lag 14 = 0.0788951780409
# lag 15 = 0.108525111829
# lag 16 = 0.135224808613
# lag 17 = 0.14472524247
# lag 18 = 0.187694466985
# lag 19 = 0.225671911207
# lag 20 = 0.182335229747
# lag 21 = 0.169919398613
# lag 22 = 0.194065212694
# lag 23 = 0.221370901146
# lag 24 = 0.076166103806
#
#
# BTC_XLM
# lag 1 = 0.90499487705
# lag 2 = 0.874847336836
# lag 3 = 0.746135809565
# lag 4 = 0.451855699995
# lag 5 = 0.561988671233
# lag 6 = 0.635993084793
# lag 7 = 0.316103348217
# lag 8 = 0.289394289554
# lag 9 = 0.306755356564
# lag 10 = 0.396414616061
# lag 11 = 0.406336378336
# lag 12 = 0.330881315938
# lag 13 = 0.401851647317
# lag 14 = 0.449939424994
# lag 15 = 0.511898603379
# lag 16 = 0.554632253183
# lag 17 = 0.593347300177
# lag 18 = 0.648345194718
# lag 19 = 0.677576809697
# lag 20 = 0.0553821685457
# lag 21 = 0.0580215490441
# lag 22 = 0.071091496423
# lag 23 = 0.0914730880266
# lag 24 = 0.122335163693
#
#
# BTC_XRP
# lag 1 = 0.101411941448
# lag 2 = 0.334571260667
# lag 3 = 0.494906098084
# lag 4 = 0.572364590407
# lag 5 = 0.384752467524
# lag 6 = 0.48353341107
# lag 7 = 0.728063661843
# lag 8 = 0.820219589026
# lag 9 = 0.775328663818
# lag 10 = 0.774799310467
# lag 11 = 0.704869657156
# lag 12 = 0.713074607242
# lag 13 = 0.724138094537
# lag 14 = 0.452678855474
# lag 15 = 0.509194703388
# lag 16 = 0.548265485
# lag 17 = 0.395984889564
# lag 18 = 0.43603459994
# lag 19 = 0.431416309199
# lag 20 = 0.502492406399
# lag 21 = 0.509163006275
# lag 22 = 0.44726807323
# lag 23 = 0.366504518518
# lag 24 = 0.419213414222
#
#
# BTC_XEM
# lag 1 = 0.71902815933
# lag 2 = 0.148719469075
# lag 3 = 0.213874236356
# lag 4 = 0.231089785379
# lag 5 = 0.295984599539
# lag 6 = 0.414601583888
# lag 7 = 0.451748682137
# lag 8 = 0.550903934094
# lag 9 = 0.584400948746
# lag 10 = 0.565861913351
# lag 11 = 0.612575786149
# lag 12 = 0.68028464369
# lag 13 = 0.755484777337
# lag 14 = 0.845991255041
# lag 15 = 0.871640217398
# lag 16 = 0.900509623746
# lag 17 = 0.925084044343
# lag 18 = 0.797404220267
# lag 19 = 0.823047589274
# lag 20 = 0.871514471387
# lag 21 = 0.905461562225
# lag 22 = 0.91956001152
# lag 23 = 0.939880819367
# lag 24 = 0.863113074597
#
#
# BTC_ETC
# lag 1 = 0.594585603929
# lag 2 = 0.339106341752
# lag 3 = 0.491905443212
# lag 4 = 0.652888983351
# lag 5 = 0.334973232086
# lag 6 = 0.31357090617
# lag 7 = 0.414698838555
# lag 8 = 0.364049539343
# lag 9 = 0.458219283967
# lag 10 = 0.471736924747
# lag 11 = 0.223925993884
# lag 12 = 0.200784146009
# lag 13 = 0.215235420502
# lag 14 = 0.289688072421
# lag 15 = 0.353212094444
# lag 16 = 0.388609227375
# lag 17 = 0.346324954866
# lag 18 = 0.266261361039
# lag 19 = 0.206683948864
# lag 20 = 0.155376583513
# lag 21 = 0.114460806539
# lag 22 = 0.0861629736329
# lag 23 = 0.10651759364
# lag 24 = 0.0562524452945
#
#
# BTC_XMR
# lag 1 = 0.582033478954
# lag 2 = 0.876423104919
# lag 3 = 0.968796770383
# lag 4 = 0.977571850899
# lag 5 = 0.976505168782
# lag 6 = 0.989300987312
# lag 7 = 0.992302644664
# lag 8 = 0.99595029453
# lag 9 = 0.998960974082
# lag 10 = 0.999207812932
# lag 11 = 0.999611916195
# lag 12 = 0.999792042283
# lag 13 = 0.892643007869
# lag 14 = 0.848761023153
# lag 15 = 0.890049222754
# lag 16 = 0.828759360752
# lag 17 = 0.729890527683
# lag 18 = 0.754176639201
# lag 19 = 0.80805556534
# lag 20 = 0.862465258767
# lag 21 = 0.914426147034
# lag 22 = 0.941374056975
# lag 23 = 0.943398220873
# lag 24 = 0.924595702893
#
#
# BTC_ZEC
# lag 1 = 0.438647920121
# lag 2 = 0.63455192399
# lag 3 = 0.796072859675
# lag 4 = 0.594486062216
# lag 5 = 0.695972849013
# lag 6 = 0.763623709433
# lag 7 = 0.840349870842
# lag 8 = 0.732556281612
# lag 9 = 0.801193181478
# lag 10 = 0.86049920773
# lag 11 = 0.866807489359
# lag 12 = 0.892572170561
# lag 13 = 0.926725414296
# lag 14 = 0.709410291615
# lag 15 = 0.773074726713
# lag 16 = 0.792926136537
# lag 17 = 0.792386013169
# lag 18 = 0.762151799925
# lag 19 = 0.813895767147
# lag 20 = 0.851842880336
# lag 21 = 0.875732599001
# lag 22 = 0.906075488148
# lag 23 = 0.85376641737
# lag 24 = 0.861794077741
#
#
# BTC_IOT
# lag 1 = 0.0102910931892
# lag 2 = 0.0277115248935
# lag 3 = 0.0401188352712
# lag 4 = 0.0773224551842
# lag 5 = 0.0770094636748
# lag 6 = 0.0785888889531
# lag 7 = 0.0759076271355
# lag 8 = 0.113357176554
# lag 9 = 0.170954864387
# lag 10 = 0.232504822427
# lag 11 = 0.308430191353
# lag 12 = 0.0914767923286
# lag 13 = 0.102925150681
# lag 14 = 0.103873036063
# lag 15 = 0.136581071304
# lag 16 = 0.151372069263
# lag 17 = 0.0491519552339
# lag 18 = 0.0467543809826
# lag 19 = 0.0589906773553
# lag 20 = 0.0700311165915
# lag 21 = 0.099412458764
# lag 22 = 0.0845500588427
# lag 23 = 0.10353170497
# lag 24 = 0.146508449745
#
#
# NXT_BTC
# lag 1 = 0.0226559993078
# lag 2 = 0.012379615909
# lag 3 = 0.0316476909828
# lag 4 = 0.0446348773813
# lag 5 = 0.0468359144332
# lag 6 = 0.0771351066019
# lag 7 = 0.118002943401
# lag 8 = 0.172119042856
# lag 9 = 0.189685193114
# lag 10 = 0.165193329458
# lag 11 = 0.0861965822519
# lag 12 = 0.0800511483513
# lag 13 = 0.0927408066681
# lag 14 = 0.0512628515835
# lag 15 = 0.027702956791
# lag 16 = 0.0369367664232
# lag 17 = 0.0497819343546
# lag 18 = 0.0664343130572
# lag 19 = 0.0848741310952
# lag 20 = 0.0763745827338
# lag 21 = 0.0802188361273
# lag 22 = 0.0948282050777
# lag 23 = 0.119191322916
# lag 24 = 0.114322719254
#
#
# NXT_BCH
# lag 1 = 0.192862619311
# lag 2 = 0.079794749323
# lag 3 = 0.0531974390479
# lag 4 = 0.0802607219209
# lag 5 = 0.158681408363
# lag 6 = 0.187008827269
# lag 7 = 0.247835787354
# lag 8 = 0.279614983283
# lag 9 = 0.34837131202
# lag 10 = 0.394702605415
# lag 11 = 0.423331495762
# lag 12 = 0.477716923217
# lag 13 = 0.600183444388
# lag 14 = 0.679914524309
# lag 15 = 0.741469152828
# lag 16 = 0.644154119228
# lag 17 = 0.670831575855
# lag 18 = 0.678939485928
# lag 19 = 0.739832369487
# lag 20 = 0.623272252196
# lag 21 = 0.6680732296
# lag 22 = 0.463429822908
# lag 23 = 0.490025702928
# lag 24 = 0.533949905592
#
#
# NXT_DASH
# lag 1 = 0.00101469299087
# lag 2 = 0.000782122883415
# lag 3 = 0.00205359129072
# lag 4 = 0.00179635413644
# lag 5 = 0.00131916043327
# lag 6 = 0.000390618875499
# lag 7 = 0.00101444195254
# lag 8 = 0.000929512068476
# lag 9 = 0.000246636234371
# lag 10 = 0.000480563850129
# lag 11 = 0.00140806382004
# lag 12 = 0.00178538685059
# lag 13 = 0.00137708652967
# lag 14 = 0.00163223295374
# lag 15 = 0.00237485952008
# lag 16 = 0.00305291572788
# lag 17 = 0.0019214578356
# lag 18 = 0.00306635030376
# lag 19 = 0.00487508487204
# lag 20 = 0.00755670242731
# lag 21 = 0.00636521561945
# lag 22 = 0.0056333830995
# lag 23 = 0.00802456933769
# lag 24 = 0.00600204088873
#
#
# NXT_LTC
# lag 1 = 3.58498047098e-11
# lag 2 = 1.93941607242e-12
# lag 3 = 1.1887229165e-13
# lag 4 = 9.49020598167e-14
# lag 5 = 5.09592784482e-13
# lag 6 = 1.27389503811e-12
# lag 7 = 1.03066336673e-12
# lag 8 = 2.27943342847e-12
# lag 9 = 3.48405255351e-12
# lag 10 = 3.52696377913e-12
# lag 11 = 4.80797144466e-12
# lag 12 = 7.80533581529e-12
# lag 13 = 4.32535046338e-12
# lag 14 = 3.31829080928e-12
# lag 15 = 5.23359457488e-12
# lag 16 = 1.45563813851e-11
# lag 17 = 3.46744532129e-12
# lag 18 = 6.05432006909e-12
# lag 19 = 1.07563492835e-11
# lag 20 = 3.11311316205e-12
# lag 21 = 6.42203781551e-12
# lag 22 = 1.15764517678e-11
# lag 23 = 1.23749021054e-11
# lag 24 = 7.13622427179e-12
#
#
# NXT_XLM
# lag 1 = 0.0474566341871
# lag 2 = 0.00422334332507
# lag 3 = 0.0114321181793
# lag 4 = 0.00755061714133
# lag 5 = 0.0106353591253
# lag 6 = 0.0148574978387
# lag 7 = 0.025967778831
# lag 8 = 0.0361685904919
# lag 9 = 0.022134809275
# lag 10 = 0.0306757802558
# lag 11 = 0.0479534619767
# lag 12 = 0.0634674226093
# lag 13 = 0.0744219181345
# lag 14 = 0.098608725105
# lag 15 = 0.083879541148
# lag 16 = 0.121110722799
# lag 17 = 0.12082578871
# lag 18 = 0.151496202099
# lag 19 = 0.167012198826
# lag 20 = 0.203297349173
# lag 21 = 0.246687145083
# lag 22 = 0.271666117071
# lag 23 = 0.312869879113
# lag 24 = 0.378549204426
#
#
# NXT_XRP
# lag 1 = 0.000267644013004
# lag 2 = 0.00147338772589
# lag 3 = 0.000797945172111
# lag 4 = 0.00134519280292
# lag 5 = 0.00306873045611
# lag 6 = 0.00168612665081
# lag 7 = 0.00346651951684
# lag 8 = 0.00440697889727
# lag 9 = 0.0179764923645
# lag 10 = 0.0168280680454
# lag 11 = 0.0262953632966
# lag 12 = 0.0351143812241
# lag 13 = 0.0216539407381
# lag 14 = 0.0301316593818
# lag 15 = 0.0247738058692
# lag 16 = 0.0337055244682
# lag 17 = 0.0132486968494
# lag 18 = 0.00978848483546
# lag 19 = 0.0152337659396
# lag 20 = 0.0212186700974
# lag 21 = 0.0236450886268
# lag 22 = 0.0360781481072
# lag 23 = 0.0384382676908
# lag 24 = 0.0335224060123
#
#
# NXT_XEM
# lag 1 = 0.348424258143
# lag 2 = 0.0220833734908
# lag 3 = 0.000328412251374
# lag 4 = 0.00124996873663
# lag 5 = 0.000833117834378
# lag 6 = 0.00251593622172
# lag 7 = 0.00710323492308
# lag 8 = 0.0075767901619
# lag 9 = 0.00432845728983
# lag 10 = 0.00746954499625
# lag 11 = 0.0151813547319
# lag 12 = 0.0163339106943
# lag 13 = 0.0129331345664
# lag 14 = 0.0150811849509
# lag 15 = 0.020421309043
# lag 16 = 0.0351120311625
# lag 17 = 0.0413662725218
# lag 18 = 0.0146169949717
# lag 19 = 0.0327325552562
# lag 20 = 0.0478429389509
# lag 21 = 0.0517421042596
# lag 22 = 0.0583978009392
# lag 23 = 0.0681165026085
# lag 24 = 0.051720424273
#
#
# NXT_ETC
# lag 1 = 2.28942725343e-07
# lag 2 = 4.5992082975e-11
# lag 3 = 2.08855725749e-10
# lag 4 = 8.23548620815e-10
# lag 5 = 2.3928853975e-10
# lag 6 = 2.19191564398e-10
# lag 7 = 9.40721250329e-10
# lag 8 = 4.26110613981e-10
# lag 9 = 7.85158482505e-10
# lag 10 = 1.74267205276e-09
# lag 11 = 5.6576986302e-09
# lag 12 = 1.14151998766e-08
# lag 13 = 1.90410683332e-08
# lag 14 = 2.04919621218e-08
# lag 15 = 1.98547685054e-08
# lag 16 = 2.8298641331e-08
# lag 17 = 2.37991253312e-08
# lag 18 = 2.08982628384e-08
# lag 19 = 2.69706848217e-08
# lag 20 = 6.8294068769e-09
# lag 21 = 1.37334772198e-08
# lag 22 = 2.52772572615e-08
# lag 23 = 2.56611940021e-08
# lag 24 = 1.9526803562e-08
#
#
# NXT_XMR
# lag 1 = 0.021253617479
# lag 2 = 9.27913034848e-05
# lag 3 = 0.000163901120934
# lag 4 = 0.000143803480481
# lag 5 = 0.000282368510796
# lag 6 = 0.000765771484344
# lag 7 = 0.00127429964344
# lag 8 = 0.00199907996445
# lag 9 = 0.00225977358575
# lag 10 = 0.0042689370813
# lag 11 = 0.00572747500204
# lag 12 = 0.00798462569674
# lag 13 = 0.00733533131542
# lag 14 = 0.00968640876925
# lag 15 = 0.00535304162842
# lag 16 = 0.00769183376683
# lag 17 = 0.00931898835541
# lag 18 = 0.0138838722312
# lag 19 = 0.0197923077228
# lag 20 = 0.0284348479568
# lag 21 = 0.0302950748141
# lag 22 = 0.0434050340602
# lag 23 = 0.0398626555683
# lag 24 = 0.0564531292056
#
#
# NXT_ZEC
# lag 1 = 9.24887732894e-06
# lag 2 = 4.33439952196e-06
# lag 3 = 1.40108477265e-05
# lag 4 = 1.82813298771e-05
# lag 5 = 5.8867502996e-06
# lag 6 = 1.02843904386e-06
# lag 7 = 2.45520259041e-06
# lag 8 = 1.11976942762e-07
# lag 9 = 2.18916680517e-07
# lag 10 = 4.82700232574e-07
# lag 11 = 1.75278115783e-06
# lag 12 = 2.46687573258e-06
# lag 13 = 4.05648164433e-06
# lag 14 = 6.29145719882e-06
# lag 15 = 9.53312487496e-06
# lag 16 = 2.08454204537e-05
# lag 17 = 1.64025315818e-05
# lag 18 = 2.66830121326e-05
# lag 19 = 2.82880829673e-05
# lag 20 = 4.96124942131e-05
# lag 21 = 4.3542704501e-05
# lag 22 = 4.4429146538e-05
# lag 23 = 4.34759288814e-05
# lag 24 = 2.38162696825e-05
#
#
# NXT_IOT
# lag 1 = 8.19711665904e-06
# lag 2 = 1.33436060887e-07
# lag 3 = 2.10174468448e-08
# lag 4 = 1.70763805933e-09
# lag 5 = 1.07076178181e-09
# lag 6 = 8.09520901349e-10
# lag 7 = 1.25321589935e-09
# lag 8 = 1.64657914273e-09
# lag 9 = 5.79912874427e-10
# lag 10 = 1.16146906041e-09
# lag 11 = 8.35747756915e-10
# lag 12 = 6.14152368771e-10
# lag 13 = 8.18944852689e-10
# lag 14 = 1.13039243439e-09
# lag 15 = 2.86906475974e-09
# lag 16 = 1.63674368316e-09
# lag 17 = 2.38456680998e-09
# lag 18 = 2.11259766211e-09
# lag 19 = 4.68900556369e-09
# lag 20 = 5.06867427501e-09
# lag 21 = 8.21137397002e-09
# lag 22 = 9.38806409321e-09
# lag 23 = 1.98471619397e-08
# lag 24 = 2.95066738044e-08
#
#
# BCH_BTC
# lag 1 = 2.16291205433e-05
# lag 2 = 0.000447943071921
# lag 3 = 2.16814416796e-05
# lag 4 = 3.40692199919e-05
# lag 5 = 0.000109839420008
# lag 6 = 0.000920731334036
# lag 7 = 0.000902029602589
# lag 8 = 0.00164059379136
# lag 9 = 0.00130734272263
# lag 10 = 0.00152630180916
# lag 11 = 0.000387498028773
# lag 12 = 0.000235583943764
# lag 13 = 0.000125977731361
# lag 14 = 0.00023356885664
# lag 15 = 0.00028071462347
# lag 16 = 0.000473765158548
# lag 17 = 0.000332842260741
# lag 18 = 0.000543823496786
# lag 19 = 0.000701573332585
# lag 20 = 0.000583360013305
# lag 21 = 0.000102007190196
# lag 22 = 0.000116632764791
# lag 23 = 9.74956276745e-05
# lag 24 = 7.70175526082e-05
#
#
# BCH_NXT
# lag 1 = 0.225660123599
# lag 2 = 0.455517898859
# lag 3 = 0.417160475873
# lag 4 = 0.377390935718
# lag 5 = 0.476857171954
# lag 6 = 0.335840254167
# lag 7 = 0.402969073387
# lag 8 = 0.19705571383
# lag 9 = 0.118947504271
# lag 10 = 0.130007366396
# lag 11 = 0.129478346883
# lag 12 = 0.0474928068697
# lag 13 = 0.041470256403
# lag 14 = 0.0422122253523
# lag 15 = 0.0368332459074
# lag 16 = 0.0554831556555
# lag 17 = 0.0430218142117
# lag 18 = 0.0589617722381
# lag 19 = 0.0799956017139
# lag 20 = 0.113459202442
# lag 21 = 0.130082401774
# lag 22 = 0.164366700247
# lag 23 = 0.215506435227
# lag 24 = 0.243091117315
#
#
# BCH_DASH
# lag 1 = 4.66983680555e-06
# lag 2 = 1.88171016674e-05
# lag 3 = 1.16501036596e-08
# lag 4 = 4.19984673359e-08
# lag 5 = 1.10238583266e-08
# lag 6 = 5.94015808478e-11
# lag 7 = 4.46687118409e-12
# lag 8 = 4.79899470236e-12
# lag 9 = 6.12292620561e-13
# lag 10 = 5.02337432622e-14
# lag 11 = 1.41386375684e-12
# lag 12 = 1.37635818586e-12
# lag 13 = 1.93010531767e-15
# lag 14 = 9.23250268416e-16
# lag 15 = 5.59411796348e-16
# lag 16 = 1.97921556077e-16
# lag 17 = 3.17894244379e-20
# lag 18 = 1.08287307832e-19
# lag 19 = 1.51977033963e-19
# lag 20 = 4.22597847193e-20
# lag 21 = 5.26690851597e-19
# lag 22 = 3.84068763777e-20
# lag 23 = 5.68712707163e-17
# lag 24 = 1.14429522745e-16
#
#
# BCH_LTC
# lag 1 = 0.968831664001
# lag 2 = 0.174041719876
# lag 3 = 0.251745740229
# lag 4 = 0.308609914294
# lag 5 = 0.570107156048
# lag 6 = 0.514668927508
# lag 7 = 0.597131145691
# lag 8 = 0.671954472827
# lag 9 = 0.660876617364
# lag 10 = 0.66819871464
# lag 11 = 0.688818503601
# lag 12 = 0.725040020745
# lag 13 = 0.272186401086
# lag 14 = 0.323788988792
# lag 15 = 0.339086321767
# lag 16 = 0.295490417869
# lag 17 = 0.249004079202
# lag 18 = 0.205541536906
# lag 19 = 0.232656318141
# lag 20 = 0.309927511364
# lag 21 = 0.236792460117
# lag 22 = 0.274939580525
# lag 23 = 0.219711585265
# lag 24 = 0.113096854048
#
#
# BCH_XLM
# lag 1 = 0.403347142741
# lag 2 = 0.409794976467
# lag 3 = 0.271196366874
# lag 4 = 0.409449184115
# lag 5 = 0.506424392432
# lag 6 = 0.83519737541
# lag 7 = 0.912003493596
# lag 8 = 0.900395994411
# lag 9 = 0.921927990383
# lag 10 = 0.930782510185
# lag 11 = 0.954751415458
# lag 12 = 0.947746084319
# lag 13 = 0.906076457517
# lag 14 = 0.944257420902
# lag 15 = 0.919771301039
# lag 16 = 0.948841126565
# lag 17 = 0.96175436054
# lag 18 = 0.953310534563
# lag 19 = 0.955720770359
# lag 20 = 0.883286768976
# lag 21 = 0.862005628419
# lag 22 = 0.890911153558
# lag 23 = 0.93955219548
# lag 24 = 0.935553715918
#
#
# BCH_XRP
# lag 1 = 0.780473540748
# lag 2 = 0.43980205961
# lag 3 = 0.343470261699
# lag 4 = 0.411198433207
# lag 5 = 0.579165383786
# lag 6 = 0.407694478865
# lag 7 = 0.445785571371
# lag 8 = 0.476423769633
# lag 9 = 0.537370877241
# lag 10 = 0.55384273019
# lag 11 = 0.663046651117
# lag 12 = 0.592877520035
# lag 13 = 0.65394874847
# lag 14 = 0.62728965925
# lag 15 = 0.658191647502
# lag 16 = 0.656979775208
# lag 17 = 0.577175001342
# lag 18 = 0.607470133798
# lag 19 = 0.64954601571
# lag 20 = 0.694709569205
# lag 21 = 0.681781527817
# lag 22 = 0.724651791766
# lag 23 = 0.793177173464
# lag 24 = 0.721363832041
#
#
# BCH_XEM
# lag 1 = 0.21463235537
# lag 2 = 0.666793264069
# lag 3 = 0.543355262042
# lag 4 = 0.724990522794
# lag 5 = 0.841350216896
# lag 6 = 0.776604267719
# lag 7 = 0.836985692192
# lag 8 = 0.89284029339
# lag 9 = 0.897008134155
# lag 10 = 0.953401589289
# lag 11 = 0.886122170883
# lag 12 = 0.944792085915
# lag 13 = 0.955856269657
# lag 14 = 0.977881405006
# lag 15 = 0.964682987501
# lag 16 = 0.0283810825383
# lag 17 = 0.153030966483
# lag 18 = 0.104754977945
# lag 19 = 0.119131994094
# lag 20 = 0.17209855859
# lag 21 = 0.22878457472
# lag 22 = 0.227220114521
# lag 23 = 0.216365654891
# lag 24 = 0.255943041837
#
#
# BCH_ETC
# lag 1 = 9.40963804026e-06
# lag 2 = 1.16622153578e-07
# lag 3 = 1.04212932104e-08
# lag 4 = 1.41973764944e-09
# lag 5 = 2.8302698495e-09
# lag 6 = 3.26555936127e-10
# lag 7 = 5.29022881169e-12
# lag 8 = 1.57285929914e-11
# lag 9 = 4.26625561631e-11
# lag 10 = 1.78060100073e-11
# lag 11 = 1.03483822732e-10
# lag 12 = 3.52727823206e-10
# lag 13 = 1.00898673776e-15
# lag 14 = 3.21914316854e-19
# lag 15 = 2.39384195298e-19
# lag 16 = 1.74610142382e-20
# lag 17 = 5.46446775544e-20
# lag 18 = 5.4263973391e-21
# lag 19 = 2.61569298851e-24
# lag 20 = 1.03397731132e-23
# lag 21 = 1.0439543244e-23
# lag 22 = 7.05227266907e-24
# lag 23 = 1.7208821037e-23
# lag 24 = 7.69662922661e-23
#
#
# BCH_XMR
# lag 1 = 0.112420723308
# lag 2 = 0.230854606046
# lag 3 = 0.0468963122304
# lag 4 = 0.0532297731404
# lag 5 = 0.128011148363
# lag 6 = 0.00423268656207
# lag 7 = 0.00865537135221
# lag 8 = 0.00170272651443
# lag 9 = 0.00116004426389
# lag 10 = 0.00310200434572
# lag 11 = 0.00245576339245
# lag 12 = 0.00051264020696
# lag 13 = 1.5528372381e-06
# lag 14 = 1.64766295094e-06
# lag 15 = 3.15484382269e-07
# lag 16 = 3.36911470066e-08
# lag 17 = 2.10343935986e-09
# lag 18 = 1.74037344065e-10
# lag 19 = 3.45695009181e-10
# lag 20 = 8.82045460679e-10
# lag 21 = 2.87087675805e-10
# lag 22 = 2.44866825081e-13
# lag 23 = 3.92603653118e-14
# lag 24 = 1.47952986024e-15
#
#
# BCH_ZEC
# lag 1 = 0.960755974293
# lag 2 = 0.719880571544
# lag 3 = 0.728060412523
# lag 4 = 0.719519349822
# lag 5 = 0.723283159102
# lag 6 = 0.798788562765
# lag 7 = 0.679686904228
# lag 8 = 0.645698733122
# lag 9 = 0.728017372995
# lag 10 = 0.822491204215
# lag 11 = 0.791485163421
# lag 12 = 0.834303139098
# lag 13 = 0.354692554329
# lag 14 = 0.447749028796
# lag 15 = 0.512488038901
# lag 16 = 0.49442113899
# lag 17 = 0.31364506117
# lag 18 = 0.309333899757
# lag 19 = 0.334832810755
# lag 20 = 0.119202557386
# lag 21 = 0.107389460608
# lag 22 = 0.0657279662279
# lag 23 = 0.0662135150522
# lag 24 = 0.0292096507116
#
#
# BCH_IOT
# lag 1 = 0.885948241548
# lag 2 = 0.656047281423
# lag 3 = 0.746035646867
# lag 4 = 0.655188714209
# lag 5 = 0.644456472828
# lag 6 = 0.314475946508
# lag 7 = 0.144492983163
# lag 8 = 0.0788369853229
# lag 9 = 0.0593327294593
# lag 10 = 0.115774585899
# lag 11 = 0.140715933717
# lag 12 = 0.0236768326636
# lag 13 = 0.00857383752825
# lag 14 = 0.00598816189957
# lag 15 = 0.0052725442328
# lag 16 = 0.00604539075922
# lag 17 = 0.00506235315791
# lag 18 = 0.011717452108
# lag 19 = 0.0156683365904
# lag 20 = 0.00762200074306
# lag 21 = 0.0011824028911
# lag 22 = 0.000519742543836
# lag 23 = 0.00378254412568
# lag 24 = 0.000122034167026
#
#
# DASH_BTC
# lag 1 = 0.209614187049
# lag 2 = 0.574656097878
# lag 3 = 0.741601604532
# lag 4 = 0.567574045174
# lag 5 = 0.0659969724913
# lag 6 = 0.0340643753812
# lag 7 = 2.10662647284e-06
# lag 8 = 6.64996328224e-07
# lag 9 = 2.34332647707e-09
# lag 10 = 1.44613976329e-09
# lag 11 = 2.22560495322e-09
# lag 12 = 7.68384159485e-09
# lag 13 = 1.4234982608e-08
# lag 14 = 3.26598558594e-08
# lag 15 = 3.51574794438e-09
# lag 16 = 6.99294511203e-09
# lag 17 = 1.23710760612e-08
# lag 18 = 1.53585239273e-08
# lag 19 = 5.31876116609e-08
# lag 20 = 1.71800563773e-09
# lag 21 = 3.99536874688e-09
# lag 22 = 7.98899177164e-09
# lag 23 = 1.25178663621e-10
# lag 24 = 7.93391132581e-10
#
#
# DASH_NXT
# lag 1 = 0.0292567657434
# lag 2 = 0.00601319040456
# lag 3 = 0.0237072247952
# lag 4 = 0.0294348050053
# lag 5 = 0.00328732871326
# lag 6 = 0.0019130350381
# lag 7 = 0.00102477128009
# lag 8 = 0.00239314301174
# lag 9 = 9.36811589089e-05
# lag 10 = 0.000187025845744
# lag 11 = 2.51206620964e-05
# lag 12 = 8.75262736768e-05
# lag 13 = 0.000120094324371
# lag 14 = 0.000339874968515
# lag 15 = 0.00118925555683
# lag 16 = 0.00125988091803
# lag 17 = 0.00259245180518
# lag 18 = 0.00434268908016
# lag 19 = 0.00784759403705
# lag 20 = 0.00468517042078
# lag 21 = 0.00618511656171
# lag 22 = 0.00560341329263
# lag 23 = 0.00419296202544
# lag 24 = 0.00766955014172
#
#
# DASH_BCH
# lag 1 = 1.52083151218e-17
# lag 2 = 3.63644432184e-17
# lag 3 = 1.67095123953e-16
# lag 4 = 4.90483439663e-16
# lag 5 = 1.15978023647e-15
# lag 6 = 5.44605686729e-18
# lag 7 = 4.60971101494e-33
# lag 8 = 1.94843247044e-50
# lag 9 = 2.9413085455e-54
# lag 10 = 1.73971567408e-56
# lag 11 = 6.01229080873e-65
# lag 12 = 3.17965480215e-72
# lag 13 = 3.04399533847e-73
# lag 14 = 1.51790183741e-77
# lag 15 = 2.46644885141e-83
# lag 16 = 6.34241139263e-84
# lag 17 = 7.84545094237e-90
# lag 18 = 7.20790500329e-90
# lag 19 = 5.5378838633e-90
# lag 20 = 7.10925095315e-91
# lag 21 = 3.07955543006e-90
# lag 22 = 3.81113067167e-92
# lag 23 = 1.49897952299e-95
# lag 24 = 1.05186087273e-96
#
#
# DASH_LTC
# lag 1 = 2.98179790067e-05
# lag 2 = 2.11852012033e-06
# lag 3 = 1.46783106513e-05
# lag 4 = 5.03672946918e-05
# lag 5 = 9.2652915481e-05
# lag 6 = 0.000184989219259
# lag 7 = 0.000192999699396
# lag 8 = 4.51970313326e-05
# lag 9 = 2.58859364141e-07
# lag 10 = 1.81837348616e-06
# lag 11 = 3.80061282988e-06
# lag 12 = 6.35237315727e-06
# lag 13 = 1.33939768891e-05
# lag 14 = 2.78373307008e-05
# lag 15 = 3.13408512388e-05
# lag 16 = 3.77030016003e-05
# lag 17 = 0.000126274942682
# lag 18 = 9.97684868449e-05
# lag 19 = 5.1748875205e-05
# lag 20 = 1.19447189606e-05
# lag 21 = 1.37137265759e-05
# lag 22 = 2.21500480325e-05
# lag 23 = 4.70930917173e-05
# lag 24 = 3.23478766308e-05
#
#
# DASH_XLM
# lag 1 = 0.707759004123
# lag 2 = 0.994854417615
# lag 3 = 0.899296249059
# lag 4 = 0.507695487768
# lag 5 = 0.502982058126
# lag 6 = 0.570572707252
# lag 7 = 0.656311120144
# lag 8 = 0.736939770598
# lag 9 = 0.736506638682
# lag 10 = 0.733351409576
# lag 11 = 0.786972745528
# lag 12 = 0.763330267721
# lag 13 = 0.819175071232
# lag 14 = 0.872616245769
# lag 15 = 0.906410527018
# lag 16 = 0.919046411969
# lag 17 = 0.932473540117
# lag 18 = 0.946669889079
# lag 19 = 0.947806138089
# lag 20 = 0.937650015509
# lag 21 = 0.948363545357
# lag 22 = 0.960056896838
# lag 23 = 0.965538175862
# lag 24 = 0.975171081636
#
#
# DASH_XRP
# lag 1 = 0.0266789654303
# lag 2 = 0.0253040165253
# lag 3 = 0.0794013481987
# lag 4 = 0.111196619026
# lag 5 = 0.114735929328
# lag 6 = 0.137142060838
# lag 7 = 0.123936969429
# lag 8 = 0.127881514799
# lag 9 = 0.032811235182
# lag 10 = 0.0569916460457
# lag 11 = 0.101604965739
# lag 12 = 0.136617696791
# lag 13 = 0.185177672717
# lag 14 = 0.227055195789
# lag 15 = 0.236766393073
# lag 16 = 0.239889122909
# lag 17 = 0.325606373324
# lag 18 = 0.394239545867
# lag 19 = 0.423335725329
# lag 20 = 0.476706115508
# lag 21 = 0.5487453383
# lag 22 = 0.61044771223
# lag 23 = 0.559544248741
# lag 24 = 0.580663993755
#
#
# DASH_XEM
# lag 1 = 0.591850881129
# lag 2 = 0.0446815739895
# lag 3 = 0.106681096646
# lag 4 = 0.0511667224588
# lag 5 = 0.0447410361218
# lag 6 = 0.0745489750652
# lag 7 = 0.114035892952
# lag 8 = 0.18862892904
# lag 9 = 0.00624293630662
# lag 10 = 0.00698763387649
# lag 11 = 0.00640806645035
# lag 12 = 0.0102705866267
# lag 13 = 0.012605691841
# lag 14 = 0.0175162969471
# lag 15 = 0.0141781865199
# lag 16 = 0.0161905944414
# lag 17 = 0.0162038944752
# lag 18 = 0.0193477682717
# lag 19 = 0.0153230654064
# lag 20 = 0.0174456412993
# lag 21 = 0.0228580022692
# lag 22 = 0.0250770139255
# lag 23 = 1.92838208346e-06
# lag 24 = 6.33311603961e-07
#
#
# DASH_ETC
# lag 1 = 0.0362436656292
# lag 2 = 0.00621812044779
# lag 3 = 0.00709867321468
# lag 4 = 0.0147858301068
# lag 5 = 0.0354317252083
# lag 6 = 0.0402184597299
# lag 7 = 2.59118075319e-05
# lag 8 = 4.91366622232e-09
# lag 9 = 3.76631759905e-10
# lag 10 = 5.43844241065e-10
# lag 11 = 1.53349955747e-09
# lag 12 = 1.67703717066e-09
# lag 13 = 3.94392637017e-09
# lag 14 = 4.63206231791e-10
# lag 15 = 6.62295139657e-10
# lag 16 = 1.46904706055e-10
# lag 17 = 1.62005181947e-10
# lag 18 = 7.02831025855e-11
# lag 19 = 6.99513137402e-11
# lag 20 = 1.35701879671e-10
# lag 21 = 1.5998133357e-10
# lag 22 = 1.39103487303e-10
# lag 23 = 1.02565016479e-11
# lag 24 = 7.13406519938e-12
#
#
# DASH_XMR
# lag 1 = 0.779627390792
# lag 2 = 2.75590498514e-05
# lag 3 = 0.000136243645769
# lag 4 = 3.72224379979e-06
# lag 5 = 6.26847310212e-06
# lag 6 = 1.59832064071e-07
# lag 7 = 8.09330507904e-08
# lag 8 = 4.90649962026e-08
# lag 9 = 4.70960709949e-07
# lag 10 = 1.25369999034e-06
# lag 11 = 7.89056591889e-07
# lag 12 = 2.5113767908e-06
# lag 13 = 1.82876733846e-06
# lag 14 = 3.63263141242e-08
# lag 15 = 1.06910884135e-08
# lag 16 = 3.09323918094e-08
# lag 17 = 9.46722866966e-09
# lag 18 = 1.29311337458e-08
# lag 19 = 1.83116594154e-09
# lag 20 = 1.07763234471e-09
# lag 21 = 9.90644188693e-12
# lag 22 = 2.16262819287e-11
# lag 23 = 7.88833171319e-11
# lag 24 = 2.18610325538e-10
#
#
# DASH_ZEC
# lag 1 = 0.872992710963
# lag 2 = 0.0113865040088
# lag 3 = 0.0728210733869
# lag 4 = 0.0686646235228
# lag 5 = 0.0975913201384
# lag 6 = 0.0870172176029
# lag 7 = 0.062936234512
# lag 8 = 0.0768655257921
# lag 9 = 0.067899072533
# lag 10 = 0.12402752047
# lag 11 = 0.13235377369
# lag 12 = 0.1841891784
# lag 13 = 0.144311885239
# lag 14 = 0.183409689407
# lag 15 = 0.232941977137
# lag 16 = 0.247475327456
# lag 17 = 0.208791821524
# lag 18 = 0.222777211664
# lag 19 = 0.274891774754
# lag 20 = 0.287338721517
# lag 21 = 0.185567122964
# lag 22 = 0.232834273156
# lag 23 = 0.282786785709
# lag 24 = 0.284339538968
#
#
# DASH_IOT
# lag 1 = 0.000125907959253
# lag 2 = 9.77286441535e-08
# lag 3 = 8.55056447714e-09
# lag 4 = 9.8290702103e-09
# lag 5 = 1.5783127376e-08
# lag 6 = 4.93332220046e-08
# lag 7 = 1.95809719789e-09
# lag 8 = 7.30868054608e-09
# lag 9 = 9.35270475465e-10
# lag 10 = 5.99621672493e-11
# lag 11 = 2.47887983919e-11
# lag 12 = 7.91531687257e-11
# lag 13 = 1.98310706178e-10
# lag 14 = 6.6202606884e-10
# lag 15 = 7.16974660747e-13
# lag 16 = 6.3679245729e-13
# lag 17 = 2.37465577172e-12
# lag 18 = 3.12619546833e-13
# lag 19 = 6.84289448479e-13
# lag 20 = 4.94484279068e-13
# lag 21 = 7.83619757961e-14
# lag 22 = 1.21126277555e-13
# lag 23 = 1.26198517404e-13
# lag 24 = 2.89360086478e-13
#
#
# LTC_BTC
# lag 1 = 0.00307565775906
# lag 2 = 0.000206470117017
# lag 3 = 0.000186987667875
# lag 4 = 0.000424905617265
# lag 5 = 0.000984872618656
# lag 6 = 0.00187299350973
# lag 7 = 0.00375981979284
# lag 8 = 0.00280363244791
# lag 9 = 0.00461072184062
# lag 10 = 0.0070754782538
# lag 11 = 0.00726736427424
# lag 12 = 0.0063399287138
# lag 13 = 0.00949687953726
# lag 14 = 0.0111560374351
# lag 15 = 0.0150614945119
# lag 16 = 0.02251978633
# lag 17 = 0.0294417192829
# lag 18 = 0.0395083305462
# lag 19 = 0.0514931641596
# lag 20 = 0.0672316259867
# lag 21 = 0.0893650567866
# lag 22 = 0.0106773387609
# lag 23 = 0.0150073527695
# lag 24 = 0.0116006676309
#
#
# LTC_NXT
# lag 1 = 0.145216954778
# lag 2 = 0.0785424198325
# lag 3 = 0.100451138627
# lag 4 = 0.111561747162
# lag 5 = 0.145032090678
# lag 6 = 0.127712503821
# lag 7 = 0.226577171137
# lag 8 = 0.276245220061
# lag 9 = 0.260634988433
# lag 10 = 0.304007749451
# lag 11 = 0.132292882461
# lag 12 = 0.0883953631267
# lag 13 = 0.00379631362847
# lag 14 = 0.0055217571335
# lag 15 = 0.00503311029781
# lag 16 = 0.00792225516657
# lag 17 = 0.0142881424096
# lag 18 = 0.0163136117632
# lag 19 = 0.0263389867271
# lag 20 = 0.0236508022594
# lag 21 = 0.0211329653775
# lag 22 = 0.0169643516681
# lag 23 = 0.00883361594126
# lag 24 = 0.0109383508158
#
#
# LTC_BCH
# lag 1 = 0.557837034019
# lag 2 = 0.0720754479062
# lag 3 = 0.0912316662633
# lag 4 = 0.0775831546695
# lag 5 = 0.137814005654
# lag 6 = 0.128197730312
# lag 7 = 0.144294003857
# lag 8 = 0.151439916257
# lag 9 = 0.215710045924
# lag 10 = 0.226472104965
# lag 11 = 0.285704878535
# lag 12 = 0.356542834798
# lag 13 = 0.387692704492
# lag 14 = 0.473668898745
# lag 15 = 0.533328848026
# lag 16 = 0.510144842932
# lag 17 = 0.528921551191
# lag 18 = 0.585283169552
# lag 19 = 0.590961413897
# lag 20 = 0.675755773265
# lag 21 = 0.714539739689
# lag 22 = 0.763977265848
# lag 23 = 0.781570318656
# lag 24 = 0.8225859457
#
#
# LTC_DASH
# lag 1 = 0.63242544342
# lag 2 = 0.723975529805
# lag 3 = 0.759372227101
# lag 4 = 0.384671856217
# lag 5 = 0.457702197812
# lag 6 = 0.520052775952
# lag 7 = 0.547620296242
# lag 8 = 0.388038531032
# lag 9 = 0.320794989485
# lag 10 = 0.391916284297
# lag 11 = 0.485676931136
# lag 12 = 0.552123686345
# lag 13 = 0.630498986838
# lag 14 = 0.524699898025
# lag 15 = 0.564008063994
# lag 16 = 0.606668306288
# lag 17 = 0.668564768399
# lag 18 = 0.720529606583
# lag 19 = 0.566555497149
# lag 20 = 0.197348879604
# lag 21 = 0.179515798197
# lag 22 = 0.17690994987
# lag 23 = 0.205557391088
# lag 24 = 0.242717549068
#
#
# LTC_XLM
# lag 1 = 0.717807190002
# lag 2 = 0.90215336039
# lag 3 = 0.55115990608
# lag 4 = 0.523455023832
# lag 5 = 0.628773668774
# lag 6 = 0.762996816608
# lag 7 = 0.761885439669
# lag 8 = 0.597661687561
# lag 9 = 0.667517014433
# lag 10 = 0.504382354316
# lag 11 = 0.496262179048
# lag 12 = 0.565800962751
# lag 13 = 0.599809393457
# lag 14 = 0.674835954228
# lag 15 = 0.740889487283
# lag 16 = 0.689795141796
# lag 17 = 0.743291809469
# lag 18 = 0.719167872353
# lag 19 = 0.781420956062
# lag 20 = 0.632515637565
# lag 21 = 0.659534778603
# lag 22 = 0.701843905796
# lag 23 = 0.725940133371
# lag 24 = 0.755122084382
#
#
# LTC_XRP
# lag 1 = 0.915112718225
# lag 2 = 0.95454424488
# lag 3 = 0.562786218162
# lag 4 = 0.686480739457
# lag 5 = 0.754820922252
# lag 6 = 0.725058903237
# lag 7 = 0.822334256597
# lag 8 = 0.893392728853
# lag 9 = 0.927959639083
# lag 10 = 0.932692382375
# lag 11 = 0.949876504225
# lag 12 = 0.963833627588
# lag 13 = 0.977111935248
# lag 14 = 0.958349951161
# lag 15 = 0.972051445802
# lag 16 = 0.970348039695
# lag 17 = 0.883931409462
# lag 18 = 0.915692982531
# lag 19 = 0.942454841225
# lag 20 = 0.958946674838
# lag 21 = 0.971273024909
# lag 22 = 0.969302282359
# lag 23 = 0.974392563249
# lag 24 = 0.980308777118
#
#
# LTC_XEM
# lag 1 = 0.928170687946
# lag 2 = 0.272615025196
# lag 3 = 0.178371048995
# lag 4 = 0.233179069454
# lag 5 = 0.318613029746
# lag 6 = 0.511288793421
# lag 7 = 0.215525408421
# lag 8 = 0.267927067471
# lag 9 = 0.339166833281
# lag 10 = 0.376903935493
# lag 11 = 0.452400466563
# lag 12 = 0.517057735337
# lag 13 = 0.531002093559
# lag 14 = 0.559492563829
# lag 15 = 0.601767881029
# lag 16 = 0.674451230739
# lag 17 = 0.771338099011
# lag 18 = 0.746098011209
# lag 19 = 0.710680484703
# lag 20 = 0.717323680466
# lag 21 = 0.757440716926
# lag 22 = 0.796519679299
# lag 23 = 0.815973290601
# lag 24 = 0.644108551815
#
#
# LTC_ETC
# lag 1 = 0.0442028563219
# lag 2 = 0.020984098922
# lag 3 = 0.00738674606896
# lag 4 = 0.0127504141557
# lag 5 = 0.0234991192015
# lag 6 = 0.00156685445605
# lag 7 = 0.00289629559529
# lag 8 = 0.000411823563687
# lag 9 = 0.000684294219389
# lag 10 = 0.000816991665105
# lag 11 = 0.00141581180437
# lag 12 = 0.000694477370993
# lag 13 = 0.00105845496576
# lag 14 = 0.00123452552218
# lag 15 = 0.000620147895005
# lag 16 = 0.000675560538303
# lag 17 = 0.000642318245946
# lag 18 = 0.000268206048542
# lag 19 = 0.000424123050943
# lag 20 = 0.000115671522658
# lag 21 = 0.000194319713921
# lag 22 = 0.000305275400347
# lag 23 = 0.000529987193347
# lag 24 = 0.000741391144866
#
#
# LTC_XMR
# lag 1 = 0.239706315996
# lag 2 = 0.247959038713
# lag 3 = 0.0344956914496
# lag 4 = 0.0457723620791
# lag 5 = 0.073008694074
# lag 6 = 0.124968291972
# lag 7 = 0.170574280784
# lag 8 = 0.25039892702
# lag 9 = 0.351127445608
# lag 10 = 0.370501065457
# lag 11 = 0.347374379331
# lag 12 = 0.254267340777
# lag 13 = 0.309909320371
# lag 14 = 0.338564665947
# lag 15 = 0.372429607077
# lag 16 = 0.377753998733
# lag 17 = 0.243879851919
# lag 18 = 0.226665572524
# lag 19 = 0.281118038031
# lag 20 = 0.210009517771
# lag 21 = 0.153331322873
# lag 22 = 0.0902212833831
# lag 23 = 0.115002790983
# lag 24 = 0.138485174864
#
#
# LTC_ZEC
# lag 1 = 0.210819558835
# lag 2 = 0.242974008247
# lag 3 = 0.257591564784
# lag 4 = 0.303942171501
# lag 5 = 0.298510104757
# lag 6 = 0.386191563879
# lag 7 = 0.525198504654
# lag 8 = 0.520182518487
# lag 9 = 0.602406178925
# lag 10 = 0.693759909518
# lag 11 = 0.74678159673
# lag 12 = 0.79964224952
# lag 13 = 0.791738958753
# lag 14 = 0.817144984567
# lag 15 = 0.831947892629
# lag 16 = 0.847910763454
# lag 17 = 0.700428441795
# lag 18 = 0.669416081678
# lag 19 = 0.614996721713
# lag 20 = 0.654247461877
# lag 21 = 0.67775680317
# lag 22 = 0.738920564939
# lag 23 = 0.640030256331
# lag 24 = 0.52025203809
#
#
# LTC_IOT
# lag 1 = 0.0275854457769
# lag 2 = 0.0193957567308
# lag 3 = 0.0237046674626
# lag 4 = 0.033248146228
# lag 5 = 0.0594843405336
# lag 6 = 0.0726014454159
# lag 7 = 0.101026949108
# lag 8 = 0.148295540312
# lag 9 = 0.199919000896
# lag 10 = 0.198001509132
# lag 11 = 0.226830557862
# lag 12 = 0.292933790719
# lag 13 = 0.365982474032
# lag 14 = 0.394278275587
# lag 15 = 0.452852623467
# lag 16 = 0.519275504026
# lag 17 = 0.341976577164
# lag 18 = 0.274465501556
# lag 19 = 0.24154195261
# lag 20 = 0.291104256379
# lag 21 = 0.333563504735
# lag 22 = 0.359915590177
# lag 23 = 0.338944752152
# lag 24 = 0.379002744929
#
#
# XLM_BTC
# lag 1 = 0.966703123631
# lag 2 = 0.159993747261
# lag 3 = 0.194708331974
# lag 4 = 0.260015004695
# lag 5 = 0.401148135778
# lag 6 = 0.499336336879
# lag 7 = 0.595308089768
# lag 8 = 0.141137455747
# lag 9 = 0.226676963466
# lag 10 = 0.258005252803
# lag 11 = 0.202134422891
# lag 12 = 0.0640011204447
# lag 13 = 0.0520471685722
# lag 14 = 0.0399093180932
# lag 15 = 0.0543453856361
# lag 16 = 0.0633545849067
# lag 17 = 0.0827163829917
# lag 18 = 0.0589214112668
# lag 19 = 0.0668170427228
# lag 20 = 0.0575539450609
# lag 21 = 0.0761490736436
# lag 22 = 0.0945486485925
# lag 23 = 0.111961290458
# lag 24 = 0.0648548519749
#
#
# XLM_NXT
# lag 1 = 0.198367611357
# lag 2 = 0.574668629843
# lag 3 = 0.627957232161
# lag 4 = 0.74149709826
# lag 5 = 0.641003748619
# lag 6 = 0.761442466603
# lag 7 = 0.789213941568
# lag 8 = 0.73233376521
# lag 9 = 0.429607994657
# lag 10 = 0.467942852362
# lag 11 = 0.617541671833
# lag 12 = 0.647556665692
# lag 13 = 0.693263751868
# lag 14 = 0.644639147427
# lag 15 = 0.566374922843
# lag 16 = 0.621429132715
# lag 17 = 0.557634464593
# lag 18 = 0.606693316383
# lag 19 = 0.55825037374
# lag 20 = 0.634418079381
# lag 21 = 0.675975774997
# lag 22 = 0.525419341588
# lag 23 = 0.433907319831
# lag 24 = 0.464474844969
#
#
# XLM_BCH
# lag 1 = 0.104727005401
# lag 2 = 0.120237326862
# lag 3 = 0.0671677883501
# lag 4 = 0.110470643075
# lag 5 = 0.0839725593818
# lag 6 = 0.123845947639
# lag 7 = 0.168423354576
# lag 8 = 0.169834766201
# lag 9 = 0.178988137172
# lag 10 = 0.243778624656
# lag 11 = 0.228831254257
# lag 12 = 0.307295517195
# lag 13 = 0.325068365025
# lag 14 = 0.387864035101
# lag 15 = 0.450827941792
# lag 16 = 0.440093272826
# lag 17 = 0.391584597073
# lag 18 = 0.454798790412
# lag 19 = 0.453467564546
# lag 20 = 0.5206866175
# lag 21 = 0.457286940299
# lag 22 = 0.451618032983
# lag 23 = 0.362699064029
# lag 24 = 0.38886960368
#
#
# XLM_DASH
# lag 1 = 0.0423512127995
# lag 2 = 0.0783203996049
# lag 3 = 0.13589897749
# lag 4 = 0.222601272011
# lag 5 = 0.253499204904
# lag 6 = 0.275563943048
# lag 7 = 0.360346463682
# lag 8 = 0.379435596521
# lag 9 = 0.428840730101
# lag 10 = 0.486015145661
# lag 11 = 0.589773613483
# lag 12 = 0.639014553166
# lag 13 = 0.73277031487
# lag 14 = 0.793236925151
# lag 15 = 0.815973483112
# lag 16 = 0.851957224242
# lag 17 = 0.836805632577
# lag 18 = 0.88153685316
# lag 19 = 0.864444438489
# lag 20 = 0.897386096131
# lag 21 = 0.910992971319
# lag 22 = 0.905820668091
# lag 23 = 0.914407347816
# lag 24 = 0.883499695364
#
#
# XLM_LTC
# lag 1 = 0.287343403377
# lag 2 = 0.183615680277
# lag 3 = 0.240200293928
# lag 4 = 0.360184213603
# lag 5 = 0.421372264248
# lag 6 = 0.29544224966
# lag 7 = 0.390169170482
# lag 8 = 0.0699834697661
# lag 9 = 0.0530996267568
# lag 10 = 0.0680436824431
# lag 11 = 0.0189662227051
# lag 12 = 0.0124049540914
# lag 13 = 0.0104321935842
# lag 14 = 0.0158628400824
# lag 15 = 0.0220249869892
# lag 16 = 0.00310188043142
# lag 17 = 0.00239160754543
# lag 18 = 0.00413274591104
# lag 19 = 0.00253504748809
# lag 20 = 0.00131911393059
# lag 21 = 0.00124857088872
# lag 22 = 0.00181361368088
# lag 23 = 0.00121979450883
# lag 24 = 0.0018937808232
#
#
# XLM_XRP
# lag 1 = 0.926186838532
# lag 2 = 0.643855094245
# lag 3 = 0.706980291505
# lag 4 = 0.610968278125
# lag 5 = 0.913147760465
# lag 6 = 0.561654888396
# lag 7 = 0.610658543266
# lag 8 = 0.882821040994
# lag 9 = 0.656720728553
# lag 10 = 0.68541524282
# lag 11 = 0.386619449915
# lag 12 = 0.462695939615
# lag 13 = 0.677617275325
# lag 14 = 0.00222373136828
# lag 15 = 0.00247445724785
# lag 16 = 0.00227786350843
# lag 17 = 0.00205219342391
# lag 18 = 0.000388248627848
# lag 19 = 0.000581650010199
# lag 20 = 0.00082883104298
# lag 21 = 0.00242308932526
# lag 22 = 0.00355746361712
# lag 23 = 0.00395973219078
# lag 24 = 0.00254600157444
#
#
# XLM_XEM
# lag 1 = 0.00730505673745
# lag 2 = 0.0448514918823
# lag 3 = 1.67510693777e-06
# lag 4 = 5.74234271823e-06
# lag 5 = 4.18883776618e-06
# lag 6 = 2.29429072902e-06
# lag 7 = 4.90009454302e-06
# lag 8 = 1.48267606145e-07
# lag 9 = 3.61079147134e-08
# lag 10 = 6.29672277124e-08
# lag 11 = 3.01049254122e-08
# lag 12 = 7.67678141954e-08
# lag 13 = 1.37302617385e-08
# lag 14 = 5.39569055915e-09
# lag 15 = 1.31413961725e-08
# lag 16 = 2.04337014429e-08
# lag 17 = 4.01938560379e-08
# lag 18 = 6.3152490534e-08
# lag 19 = 5.62697211212e-07
# lag 20 = 6.68838756007e-07
# lag 21 = 1.57471558324e-07
# lag 22 = 8.46268938564e-08
# lag 23 = 2.62234561565e-08
# lag 24 = 3.0252073625e-08
#
#
# XLM_ETC
# lag 1 = 0.216351479705
# lag 2 = 0.419229682654
# lag 3 = 0.594224645834
# lag 4 = 0.399824427759
# lag 5 = 0.450752148324
# lag 6 = 0.506056320629
# lag 7 = 0.602572048235
# lag 8 = 0.684688908365
# lag 9 = 0.560312810255
# lag 10 = 0.486858791247
# lag 11 = 0.577169070868
# lag 12 = 0.66605200297
# lag 13 = 0.691428192113
# lag 14 = 0.726358574361
# lag 15 = 0.734951339691
# lag 16 = 0.799054472609
# lag 17 = 0.779143495938
# lag 18 = 0.819193292258
# lag 19 = 0.705108697884
# lag 20 = 0.713805922143
# lag 21 = 0.713739219162
# lag 22 = 0.679416468816
# lag 23 = 0.700639412694
# lag 24 = 0.758688643175
#
#
# XLM_XMR
# lag 1 = 0.127345065731
# lag 2 = 0.300117917797
# lag 3 = 0.300827412686
# lag 4 = 0.363276879377
# lag 5 = 0.384865090074
# lag 6 = 0.436215936447
# lag 7 = 0.533725701293
# lag 8 = 0.494013790444
# lag 9 = 0.606886442611
# lag 10 = 0.631530914879
# lag 11 = 0.679510614563
# lag 12 = 0.714441312413
# lag 13 = 0.740140877237
# lag 14 = 0.807686759081
# lag 15 = 0.842685770704
# lag 16 = 0.876554156382
# lag 17 = 0.835230277345
# lag 18 = 0.880612387691
# lag 19 = 0.808231179463
# lag 20 = 0.822815457009
# lag 21 = 0.799458695729
# lag 22 = 0.836382891906
# lag 23 = 0.849156404377
# lag 24 = 0.862207937774
#
#
# XLM_ZEC
# lag 1 = 0.118737159114
# lag 2 = 0.269447921894
# lag 3 = 0.398927843076
# lag 4 = 0.541644023341
# lag 5 = 0.647662225126
# lag 6 = 0.486046181982
# lag 7 = 0.576287499654
# lag 8 = 0.613575868004
# lag 9 = 0.775859922046
# lag 10 = 0.837456340809
# lag 11 = 0.832090565396
# lag 12 = 0.867783228868
# lag 13 = 0.902793241746
# lag 14 = 0.916835416322
# lag 15 = 0.936897305498
# lag 16 = 0.929392157951
# lag 17 = 0.913447530489
# lag 18 = 0.938206388487
# lag 19 = 0.959162228934
# lag 20 = 0.950432753067
# lag 21 = 0.960054721028
# lag 22 = 0.972627269581
# lag 23 = 0.980311710103
# lag 24 = 0.985556257375
#
#
# XLM_IOT
# lag 1 = 0.00776388685359
# lag 2 = 0.00705595224515
# lag 3 = 0.0149772494733
# lag 4 = 0.0308310636222
# lag 5 = 0.0724860516157
# lag 6 = 0.125897892161
# lag 7 = 0.185248422037
# lag 8 = 0.0507741139554
# lag 9 = 0.0253414943013
# lag 10 = 0.0267172296215
# lag 11 = 0.0172571002648
# lag 12 = 0.0293623541802
# lag 13 = 0.0552756321571
# lag 14 = 0.0735236251752
# lag 15 = 0.0564287994424
# lag 16 = 0.0771530067159
# lag 17 = 0.0960708066919
# lag 18 = 0.120321031275
# lag 19 = 0.137693117875
# lag 20 = 0.176991389316
# lag 21 = 0.0876869112342
# lag 22 = 0.113506975571
# lag 23 = 0.146964647864
# lag 24 = 0.203386467255
#
#
# XRP_BTC
# lag 1 = 0.0179397060518
# lag 2 = 0.0467103815726
# lag 3 = 0.0817655229913
# lag 4 = 0.0174669855152
# lag 5 = 0.036582589806
# lag 6 = 0.0542436391672
# lag 7 = 0.0613485941153
# lag 8 = 0.0703480557422
# lag 9 = 0.06685984168
# lag 10 = 0.086883852147
# lag 11 = 0.0943570222978
# lag 12 = 0.0671538892864
# lag 13 = 0.0956894730627
# lag 14 = 0.0235358210313
# lag 15 = 0.0330837508057
# lag 16 = 0.0507274698329
# lag 17 = 0.0702050878223
# lag 18 = 0.128369927903
# lag 19 = 0.161090283734
# lag 20 = 0.0722279473219
# lag 21 = 0.0777416376889
# lag 22 = 0.0896610175124
# lag 23 = 0.109884423024
# lag 24 = 0.0861042354907
#
#
# XRP_NXT
# lag 1 = 0.953020213413
# lag 2 = 0.230052403969
# lag 3 = 0.0824837510222
# lag 4 = 0.124069055637
# lag 5 = 0.135096420748
# lag 6 = 0.136042002949
# lag 7 = 0.173028104844
# lag 8 = 0.139630603083
# lag 9 = 0.0401879104494
# lag 10 = 0.0170097092222
# lag 11 = 0.0270687542585
# lag 12 = 0.0111391343477
# lag 13 = 0.0083781454692
# lag 14 = 0.00798045380495
# lag 15 = 0.0153912700795
# lag 16 = 0.0125578512351
# lag 17 = 0.0201522784537
# lag 18 = 0.0261583375249
# lag 19 = 0.0372977362389
# lag 20 = 0.0507796957023
# lag 21 = 0.0471778686754
# lag 22 = 0.097565230281
# lag 23 = 0.105615349412
# lag 24 = 0.0351252587642
#
#
# XRP_BCH
# lag 1 = 0.604437887218
# lag 2 = 0.39136411644
# lag 3 = 0.531386725856
# lag 4 = 0.682757102411
# lag 5 = 0.81971847533
# lag 6 = 0.906297931938
# lag 7 = 0.950449303384
# lag 8 = 0.921405004081
# lag 9 = 0.948056050912
# lag 10 = 0.932127216635
# lag 11 = 0.947638780831
# lag 12 = 0.897458540548
# lag 13 = 0.920017652822
# lag 14 = 0.94921055262
# lag 15 = 0.962859959746
# lag 16 = 0.971580550841
# lag 17 = 0.973932465433
# lag 18 = 0.983455289788
# lag 19 = 0.977722846064
# lag 20 = 0.972351439507
# lag 21 = 0.977102232359
# lag 22 = 0.97159827819
# lag 23 = 0.965429453239
# lag 24 = 0.96602595742
#
#
# XRP_DASH
# lag 1 = 0.128652241044
# lag 2 = 0.192445111479
# lag 3 = 0.259110684497
# lag 4 = 0.268258237393
# lag 5 = 0.205557663621
# lag 6 = 0.17855851994
# lag 7 = 0.243565086115
# lag 8 = 0.23756590973
# lag 9 = 0.249277519139
# lag 10 = 0.192378366482
# lag 11 = 0.309795452956
# lag 12 = 0.402428687946
# lag 13 = 0.443721662291
# lag 14 = 0.344858498442
# lag 15 = 0.363032514703
# lag 16 = 0.323940871382
# lag 17 = 0.298955774192
# lag 18 = 0.352053066145
# lag 19 = 0.412579393766
# lag 20 = 0.386879812129
# lag 21 = 0.433174850648
# lag 22 = 0.470779387376
# lag 23 = 0.5071542155
# lag 24 = 0.485929227464
#
#
# XRP_LTC
# lag 1 = 0.0401499891081
# lag 2 = 0.0404394773393
# lag 3 = 0.0525420347901
# lag 4 = 0.0744613936517
# lag 5 = 0.0497364044143
# lag 6 = 0.0695641143789
# lag 7 = 0.0947637540515
# lag 8 = 0.0569306083022
# lag 9 = 0.0499792109249
# lag 10 = 0.0723496621921
# lag 11 = 0.0768727453462
# lag 12 = 0.107880431873
# lag 13 = 0.075164673415
# lag 14 = 0.0800250798295
# lag 15 = 0.107218626871
# lag 16 = 0.134739299383
# lag 17 = 0.160872575192
# lag 18 = 0.21598900516
# lag 19 = 0.189328601699
# lag 20 = 0.0256242508849
# lag 21 = 0.0396331177356
# lag 22 = 0.0378095405285
# lag 23 = 0.0464998248253
# lag 24 = 0.042555525878
#
#
# XRP_XLM
# lag 1 = 0.13197586296
# lag 2 = 0.0821810546337
# lag 3 = 0.00341921998864
# lag 4 = 0.00242547557466
# lag 5 = 0.000717201693655
# lag 6 = 0.000565394955191
# lag 7 = 0.000286291348522
# lag 8 = 2.74364038706e-05
# lag 9 = 4.36391475316e-05
# lag 10 = 4.06708549148e-05
# lag 11 = 3.46953619424e-05
# lag 12 = 3.75046647802e-05
# lag 13 = 5.31832678601e-05
# lag 14 = 2.92637979125e-05
# lag 15 = 4.50809063546e-05
# lag 16 = 1.36805304463e-05
# lag 17 = 5.36542157279e-06
# lag 18 = 5.3885093145e-06
# lag 19 = 1.69454020163e-05
# lag 20 = 1.2613765426e-05
# lag 21 = 1.30881200611e-05
# lag 22 = 1.65702147936e-06
# lag 23 = 7.21491751996e-07
# lag 24 = 6.59580697196e-07
#
#
# XRP_XEM
# lag 1 = 0.922565418565
# lag 2 = 0.515983554808
# lag 3 = 0.556373748241
# lag 4 = 0.703175096031
# lag 5 = 0.713696562538
# lag 6 = 0.844777802764
# lag 7 = 0.808320483694
# lag 8 = 0.270889905731
# lag 9 = 0.21843721143
# lag 10 = 0.134182900289
# lag 11 = 0.106898257767
# lag 12 = 0.224654808044
# lag 13 = 0.313938216882
# lag 14 = 0.297476965573
# lag 15 = 0.356830393852
# lag 16 = 0.38929394166
# lag 17 = 0.477481094301
# lag 18 = 0.493230241122
# lag 19 = 0.589253242137
# lag 20 = 0.650272514983
# lag 21 = 0.706668740708
# lag 22 = 0.774840210194
# lag 23 = 0.803674036963
# lag 24 = 0.854086554142
#
#
# XRP_ETC
# lag 1 = 0.0292515428115
# lag 2 = 0.032982226859
# lag 3 = 0.0523700783413
# lag 4 = 0.0969477134911
# lag 5 = 0.131174981448
# lag 6 = 0.218793141557
# lag 7 = 0.299982894315
# lag 8 = 0.109114249592
# lag 9 = 0.124568372056
# lag 10 = 0.189955964006
# lag 11 = 0.0950927115866
# lag 12 = 0.137608880241
# lag 13 = 0.129806391248
# lag 14 = 0.0574199644931
# lag 15 = 0.0724962859036
# lag 16 = 0.0700786001218
# lag 17 = 0.0677597497451
# lag 18 = 0.0775227569751
# lag 19 = 0.0831615188017
# lag 20 = 0.0298188818872
# lag 21 = 0.0311026461251
# lag 22 = 0.0203329162505
# lag 23 = 0.0198481144488
# lag 24 = 0.0228750133684
#
#
# XRP_XMR
# lag 1 = 0.467714629485
# lag 2 = 0.464640126723
# lag 3 = 0.438581275412
# lag 4 = 0.499313086943
# lag 5 = 0.337437816046
# lag 6 = 0.0454950524478
# lag 7 = 0.0689136507959
# lag 8 = 0.0658220587707
# lag 9 = 0.0694858037164
# lag 10 = 0.0975016164838
# lag 11 = 0.112647914971
# lag 12 = 0.118438528398
# lag 13 = 0.11098428084
# lag 14 = 0.0514502521577
# lag 15 = 0.0618453840527
# lag 16 = 0.0597689804457
# lag 17 = 0.0782356231294
# lag 18 = 0.0763781515152
# lag 19 = 0.0970781384504
# lag 20 = 0.0996616092151
# lag 21 = 0.0820551305411
# lag 22 = 0.0711616163583
# lag 23 = 0.088598743946
# lag 24 = 0.0897777345949
#
#
# XRP_ZEC
# lag 1 = 0.0108215368533
# lag 2 = 0.0154366393901
# lag 3 = 0.0301302487029
# lag 4 = 0.0371968171623
# lag 5 = 0.0481034668487
# lag 6 = 0.0403994376529
# lag 7 = 0.0519860842274
# lag 8 = 0.0580158583161
# lag 9 = 0.0840081996158
# lag 10 = 0.0992492351099
# lag 11 = 0.135978337689
# lag 12 = 0.217180805142
# lag 13 = 0.276611946342
# lag 14 = 0.332587370402
# lag 15 = 0.289694134267
# lag 16 = 0.343902709082
# lag 17 = 0.346172492993
# lag 18 = 0.399892655934
# lag 19 = 0.442229586877
# lag 20 = 0.434596885254
# lag 21 = 0.462246853472
# lag 22 = 0.526544052428
# lag 23 = 0.563404599919
# lag 24 = 0.377256003012
#
#
# XRP_IOT
# lag 1 = 0.333143853532
# lag 2 = 0.000410645009242
# lag 3 = 0.000424371363082
# lag 4 = 0.000959136622998
# lag 5 = 0.00167190022231
# lag 6 = 0.00290342957196
# lag 7 = 0.00552202359663
# lag 8 = 0.00395613906569
# lag 9 = 0.000421365530366
# lag 10 = 0.000292346926858
# lag 11 = 0.000296595361381
# lag 12 = 0.000420468150293
# lag 13 = 0.000699581739708
# lag 14 = 0.00121385969306
# lag 15 = 0.000737013936335
# lag 16 = 0.000872901350379
# lag 17 = 0.00119296315584
# lag 18 = 0.00136301105332
# lag 19 = 0.00100914214462
# lag 20 = 0.00103990057332
# lag 21 = 0.0017043765805
# lag 22 = 0.00225316010937
# lag 23 = 0.00353514338536
# lag 24 = 0.00618005184897
#
#
# XEM_BTC
# lag 1 = 6.58055189398e-06
# lag 2 = 1.18317406355e-05
# lag 3 = 6.55941460832e-06
# lag 4 = 1.20839747332e-06
# lag 5 = 2.33823202399e-06
# lag 6 = 2.24590693685e-06
# lag 7 = 7.85665044752e-07
# lag 8 = 2.11231511882e-06
# lag 9 = 4.4098655251e-06
# lag 10 = 1.14340645368e-05
# lag 11 = 1.08418211591e-05
# lag 12 = 5.74314219237e-06
# lag 13 = 9.63310294943e-06
# lag 14 = 1.84710813636e-05
# lag 15 = 2.15780758067e-05
# lag 16 = 2.74360313991e-05
# lag 17 = 4.99150517572e-05
# lag 18 = 4.52233249769e-05
# lag 19 = 0.000107194313634
# lag 20 = 1.78467172097e-05
# lag 21 = 1.88573742214e-05
# lag 22 = 2.89952273482e-05
# lag 23 = 2.57269462626e-05
# lag 24 = 1.56903827924e-05
#
#
# XEM_NXT
# lag 1 = 1.99363329723e-06
# lag 2 = 4.13824863965e-07
# lag 3 = 9.97326035914e-10
# lag 4 = 1.29044593777e-11
# lag 5 = 1.28800434626e-13
# lag 6 = 8.24048890787e-14
# lag 7 = 6.11321208973e-16
# lag 8 = 4.76809608947e-16
# lag 9 = 1.36463290736e-15
# lag 10 = 1.42489233679e-15
# lag 11 = 4.47638129351e-15
# lag 12 = 4.88629676636e-15
# lag 13 = 1.80279917201e-14
# lag 14 = 1.62460456872e-14
# lag 15 = 3.74305048388e-14
# lag 16 = 4.80423870546e-14
# lag 17 = 3.06390399657e-14
# lag 18 = 7.32694914007e-14
# lag 19 = 7.51847128974e-14
# lag 20 = 8.43530855377e-14
# lag 21 = 6.41130400386e-14
# lag 22 = 8.58079417489e-15
# lag 23 = 3.92617076443e-15
# lag 24 = 2.23158195295e-15
#
#
# XEM_BCH
# lag 1 = 0.000283674229207
# lag 2 = 0.00106694547414
# lag 3 = 0.00244922843242
# lag 4 = 0.00579234362655
# lag 5 = 0.00548273985633
# lag 6 = 0.00345439316242
# lag 7 = 0.0032041529448
# lag 8 = 0.000766531432006
# lag 9 = 0.00148560730044
# lag 10 = 0.00127454900481
# lag 11 = 0.00160194804359
# lag 12 = 0.00181410153421
# lag 13 = 0.00273964191929
# lag 14 = 0.002442272046
# lag 15 = 0.00382839004627
# lag 16 = 0.00447277847496
# lag 17 = 0.00334260019674
# lag 18 = 0.00521506177164
# lag 19 = 0.00471738776601
# lag 20 = 0.00479881737028
# ...
# lag 12 = 0.0405452303237
# lag 13 = 0.0469680893476
# lag 14 = 0.0915578387637
# lag 15 = 0.11323369412
# lag 16 = 0.118911782398
# lag 17 = 0.151092697641
# lag 18 = 0.171625273271
# lag 19 = 0.193053757296
# lag 20 = 0.240714305657
# lag 21 = 0.356404177591
# lag 22 = 0.372902562437
# lag 23 = 0.418292007691
# lag 24 = 0.456937949374
#
#
# XMR_XEM
# lag 1 = 0.995308492216
# lag 2 = 0.080330514462
# lag 3 = 0.054746920089
# lag 4 = 0.103942179126
# lag 5 = 0.108849564811
# lag 6 = 0.125509109309
# lag 7 = 0.180302484663
# lag 8 = 0.147433398364
# lag 9 = 0.00281658528966
# lag 10 = 0.00143879636
# lag 11 = 0.00185431005156
# lag 12 = 0.00257815213605
# lag 13 = 0.00297346671114
# lag 14 = 0.000274808331017
# lag 15 = 0.000357516175722
# lag 16 = 0.000428319337155
# lag 17 = 0.000213422735586
# lag 18 = 2.02773862203e-06
# lag 19 = 4.29411910232e-06
# lag 20 = 5.31630677049e-06
# lag 21 = 8.72746445595e-06
# lag 22 = 4.47353038026e-06
# lag 23 = 9.32924298921e-06
# lag 24 = 1.34222924692e-05
#
#
# XMR_ETC
# lag 1 = 2.33825835649e-05
# lag 2 = 1.24824063447e-06
# lag 3 = 2.81229695896e-06
# lag 4 = 9.43556186174e-06
# lag 5 = 2.33226983797e-05
# lag 6 = 3.79095402847e-05
# lag 7 = 8.63754328803e-05
# lag 8 = 3.88451682532e-07
# lag 9 = 9.96296743709e-07
# lag 10 = 1.93434569558e-06
# lag 11 = 1.72410140556e-06
# lag 12 = 3.80732390531e-07
# lag 13 = 5.45872237659e-07
# lag 14 = 6.46603712555e-07
# lag 15 = 1.01279493725e-06
# lag 16 = 1.81080384933e-06
# lag 17 = 8.46135274736e-07
# lag 18 = 1.11766220925e-06
# lag 19 = 1.95927873209e-06
# lag 20 = 2.35128031493e-06
# lag 21 = 1.69181588709e-08
# lag 22 = 3.98946139796e-08
# lag 23 = 7.35633134589e-10
# lag 24 = 1.96096377986e-09
#
#
# XMR_ZEC
# lag 1 = 0.039446229068
# lag 2 = 0.0854142591919
# lag 3 = 0.144135299178
# lag 4 = 0.204711646471
# lag 5 = 0.101016667991
# lag 6 = 0.143375526443
# lag 7 = 0.137220050204
# lag 8 = 0.16005700337
# lag 9 = 0.213839374857
# lag 10 = 0.154090121666
# lag 11 = 0.185337638771
# lag 12 = 0.186475637394
# lag 13 = 0.209787411294
# lag 14 = 0.271508978706
# lag 15 = 0.345830950365
# lag 16 = 0.333048489369
# lag 17 = 0.283306761783
# lag 18 = 0.314390076062
# lag 19 = 0.330336963712
# lag 20 = 0.306243385672
# lag 21 = 0.243785308339
# lag 22 = 0.208045724172
# lag 23 = 0.16581154973
# lag 24 = 0.205037353789
#
#
# XMR_IOT
# lag 1 = 0.000238225353224
# lag 2 = 0.000510643283301
# lag 3 = 0.00100161849314
# lag 4 = 8.91989611008e-05
# lag 5 = 0.000177737232524
# lag 6 = 0.00018140571758
# lag 7 = 5.18034313971e-05
# lag 8 = 5.58587848832e-05
# lag 9 = 3.52178262376e-05
# lag 10 = 3.93495218216e-05
# lag 11 = 8.29615081064e-05
# lag 12 = 0.000174305183091
# lag 13 = 0.000228393984537
# lag 14 = 7.33204550667e-05
# lag 15 = 0.00013069911239
# lag 16 = 9.79294961399e-05
# lag 17 = 0.000109991849352
# lag 18 = 0.000178394088822
# lag 19 = 0.000270399825015
# lag 20 = 0.000257933584999
# lag 21 = 0.000291790416461
# lag 22 = 0.000152153839831
# lag 23 = 0.000257377621993
# lag 24 = 0.000381950573092
#
#
# ZEC_BTC
# lag 1 = 0.473866266687
# lag 2 = 0.314111207817
# lag 3 = 0.395209146634
# lag 4 = 0.339713556139
# lag 5 = 0.196158865463
# lag 6 = 0.294591097649
# lag 7 = 0.121401377069
# lag 8 = 0.0578076572123
# lag 9 = 0.0650569338537
# lag 10 = 0.0751703144508
# lag 11 = 0.100787756086
# lag 12 = 0.121973254473
# lag 13 = 0.146920717346
# lag 14 = 0.15224423006
# lag 15 = 0.161750196722
# lag 16 = 0.0891130727853
# lag 17 = 0.113136861453
# lag 18 = 0.137459201784
# lag 19 = 0.109268911895
# lag 20 = 0.0514027954866
# lag 21 = 0.033960305065
# lag 22 = 0.0477464696054
# lag 23 = 0.0541591032623
# lag 24 = 0.0348082545784
#
#
# ZEC_NXT
# lag 1 = 0.736232954364
# lag 2 = 0.65672505916
# lag 3 = 0.00442410791077
# lag 4 = 0.00565886826252
# lag 5 = 0.00328446745143
# lag 6 = 0.00581451834152
# lag 7 = 0.00029558875435
# lag 8 = 0.000581898927483
# lag 9 = 0.000815443454769
# lag 10 = 0.00050020018308
# lag 11 = 0.000356712838758
# lag 12 = 0.000522346665707
# lag 13 = 0.000599200923371
# lag 14 = 0.000617544333391
# lag 15 = 0.000895045545319
# lag 16 = 0.00123655472148
# lag 17 = 0.0018706865218
# lag 18 = 0.00285982460865
# lag 19 = 0.00446657445454
# lag 20 = 0.00365245996232
# lag 21 = 0.00415628111056
# lag 22 = 0.00584480549349
# lag 23 = 0.00378564885054
# lag 24 = 0.00503234563469
#
#
# ZEC_BCH
# lag 1 = 0.127162244797
# lag 2 = 0.00379068353445
# lag 3 = 0.0012338460989
# lag 4 = 0.00093452886529
# lag 5 = 0.00166319739792
# lag 6 = 0.00332418374516
# lag 7 = 0.00252223009631
# lag 8 = 0.000226312576073
# lag 9 = 9.27533300829e-05
# lag 10 = 0.000115110399101
# lag 11 = 0.000107115637616
# lag 12 = 0.000201219031533
# lag 13 = 0.0003416745042
# lag 14 = 0.000607533635442
# lag 15 = 0.000283212942978
# lag 16 = 4.03628128273e-06
# lag 17 = 1.77516184234e-08
# lag 18 = 1.99036923761e-08
# lag 19 = 1.9621623073e-08
# lag 20 = 4.59683953368e-09
# lag 21 = 6.43629034634e-09
# lag 22 = 8.07530700821e-09
# lag 23 = 1.18759353466e-08
# lag 24 = 2.1026825211e-08
#
#
# ZEC_DASH
# lag 1 = 6.78755667152e-11
# lag 2 = 5.69287779179e-10
# lag 3 = 1.13906286079e-09
# lag 4 = 3.48334557994e-10
# lag 5 = 1.46074088805e-11
# lag 6 = 1.06117345441e-11
# lag 7 = 3.36999655355e-11
# lag 8 = 1.06829415957e-10
# lag 9 = 2.08294173502e-15
# lag 10 = 2.99690594818e-15
# lag 11 = 7.53760129725e-16
# lag 12 = 2.38375771791e-15
# lag 13 = 4.6133619478e-15
# lag 14 = 3.00891751299e-15
# lag 15 = 1.6836165326e-15
# lag 16 = 5.62474156735e-15
# lag 17 = 1.67717454007e-14
# lag 18 = 4.09515274532e-14
# lag 19 = 6.85435773033e-14
# lag 20 = 1.96705622586e-13
# lag 21 = 3.71563272719e-13
# lag 22 = 1.08683493845e-12
# lag 23 = 8.1086298749e-13
# lag 24 = 7.94509381755e-13
#
#
# ZEC_LTC
# lag 1 = 0.0142988484602
# lag 2 = 0.0374700062169
# lag 3 = 0.0777166210625
# lag 4 = 0.022621590909
# lag 5 = 0.0323301697146
# lag 6 = 0.0264673073898
# lag 7 = 0.00506052876265
# lag 8 = 0.00528548760184
# lag 9 = 0.00862909103432
# lag 10 = 0.00876771175552
# lag 11 = 0.00834845485299
# lag 12 = 0.013888401544
# lag 13 = 0.00968467560474
# lag 14 = 0.00987978968848
# lag 15 = 0.0108926023006
# lag 16 = 0.0143388388126
# lag 17 = 0.0196867913905
# lag 18 = 0.0104268219172
# lag 19 = 0.0126764733169
# lag 20 = 0.0105675601829
# lag 21 = 0.0104569297237
# lag 22 = 0.0156517002924
# lag 23 = 0.0179453379592
# lag 24 = 0.0124021689941
#
#
# ZEC_XLM
# lag 1 = 0.723369654653
# lag 2 = 0.709574441338
# lag 3 = 0.684808270713
# lag 4 = 0.754658359516
# lag 5 = 0.784071499957
# lag 6 = 0.775333080677
# lag 7 = 0.558411969035
# lag 8 = 0.495013379866
# lag 9 = 0.557826010624
# lag 10 = 0.590842771845
# lag 11 = 0.674120381223
# lag 12 = 0.753360746494
# lag 13 = 0.815135994717
# lag 14 = 0.83693062953
# lag 15 = 0.86712359984
# lag 16 = 0.90474423221
# lag 17 = 0.899216268073
# lag 18 = 0.861288278852
# lag 19 = 0.892247485998
# lag 20 = 0.764210146395
# lag 21 = 0.803996001063
# lag 22 = 0.831972208135
# lag 23 = 0.755657993435
# lag 24 = 0.623983887387
#
#
# ZEC_XRP
# lag 1 = 0.180380329069
# lag 2 = 0.296312971371
# lag 3 = 0.29088161328
# lag 4 = 0.408148774333
# lag 5 = 0.404630909968
# lag 6 = 0.227804494288
# lag 7 = 0.0383179899225
# lag 8 = 0.055573396911
# lag 9 = 0.0449776204304
# lag 10 = 0.0465305432173
# lag 11 = 0.0449124310175
# lag 12 = 0.0659353834243
# lag 13 = 0.0861641327133
# lag 14 = 0.108973265433
# lag 15 = 0.129237755734
# lag 16 = 0.154051857662
# lag 17 = 0.208837228058
# lag 18 = 0.0301540763012
# lag 19 = 0.0350010397014
# lag 20 = 0.0179140492372
# lag 21 = 0.0132583583641
# lag 22 = 0.0136529655632
# lag 23 = 0.0223416144991
# lag 24 = 0.0379057125203
#
#
# ZEC_XEM
# lag 1 = 0.609096804536
# lag 2 = 0.747029442648
# lag 3 = 0.609609886638
# lag 4 = 0.662122595211
# lag 5 = 0.686612007597
# lag 6 = 0.767270528092
# lag 7 = 0.693451100566
# lag 8 = 0.604208572881
# lag 9 = 0.540149142669
# lag 10 = 0.443119563501
# lag 11 = 0.33882898165
# lag 12 = 0.428090857413
# lag 13 = 0.510219820943
# lag 14 = 0.236662904127
# lag 15 = 0.212143929122
# lag 16 = 0.215820089993
# lag 17 = 0.186901293211
# lag 18 = 0.213609137025
# lag 19 = 0.227920764168
# lag 20 = 0.159824548487
# lag 21 = 0.204638152937
# lag 22 = 0.264836055505
# lag 23 = 0.331361813555
# lag 24 = 0.163448422274
#
#
# ZEC_ETC
# lag 1 = 0.00158747124079
# lag 2 = 0.00323408310609
# lag 3 = 0.0088391251267
# lag 4 = 0.0189506169353
# lag 5 = 0.0306502416415
# lag 6 = 0.0466398337797
# lag 7 = 0.0406603549933
# lag 8 = 0.000437138688798
# lag 9 = 0.000857689655115
# lag 10 = 0.00107865321674
# lag 11 = 0.000180016436945
# lag 12 = 0.000325181488982
# lag 13 = 0.000440537696625
# lag 14 = 0.000556291957361
# lag 15 = 0.000743965239649
# lag 16 = 0.00104483863047
# lag 17 = 0.000745486438427
# lag 18 = 0.00117644694543
# lag 19 = 0.00156935857638
# lag 20 = 0.00195287841214
# lag 21 = 0.0026608559803
# lag 22 = 0.00327290694152
# lag 23 = 0.00267766017361
# lag 24 = 0.00376256627256
#
#
# ZEC_XMR
# lag 1 = 0.0429609589967
# lag 2 = 0.0855934952449
# lag 3 = 0.0409098855854
# lag 4 = 0.0242586453197
# lag 5 = 0.0429260556829
# lag 6 = 0.0374499770443
# lag 7 = 0.0170941982955
# lag 8 = 0.00283985407194
# lag 9 = 6.19640505766e-05
# lag 10 = 3.86708607705e-05
# lag 11 = 8.04624404041e-06
# lag 12 = 1.34938478377e-05
# lag 13 = 2.41991973108e-05
# lag 14 = 1.74742907387e-05
# lag 15 = 4.13831488707e-05
# lag 16 = 8.67508969971e-05
# lag 17 = 9.56553081646e-05
# lag 18 = 0.000161444519196
# lag 19 = 0.000246649748157
# lag 20 = 0.000244206030353
# lag 21 = 0.000274092403637
# lag 22 = 0.000156878419172
# lag 23 = 0.000397977103225
# lag 24 = 1.94530207157e-05
#
#
# ZEC_IOT
# lag 1 = 0.000135194188616
# lag 2 = 0.000582637431217
# lag 3 = 0.000327840052946
# lag 4 = 0.000106743312084
# lag 5 = 0.000296533127332
# lag 6 = 0.000810952444474
# lag 7 = 9.91259528054e-05
# lag 8 = 0.000177936773911
# lag 9 = 0.000285166789083
# lag 10 = 0.000161884215469
# lag 11 = 0.000285727022604
# lag 12 = 0.000540574271401
# lag 13 = 0.000868629784945
# lag 14 = 0.00121383690137
# lag 15 = 0.00219580377565
# lag 16 = 0.00295906655109
# lag 17 = 0.00348001323848
# lag 18 = 0.00386083826466
# lag 19 = 0.0053247363531
# lag 20 = 0.00813070542159
# lag 21 = 0.00719814994878
# lag 22 = 0.0107079642538
# lag 23 = 0.018565347912
# lag 24 = 0.021725253951
#
#
# IOT_BTC
# lag 1 = 0.744149169117
# lag 2 = 0.00832864879608
# lag 3 = 0.0150032616292
# lag 4 = 0.0179089653465
# lag 5 = 0.000823433619213
# lag 6 = 0.00262287931952
# lag 7 = 0.0014720343271
# lag 8 = 0.00288774378938
# lag 9 = 0.00543736997401
# lag 10 = 0.00812646440628
# lag 11 = 0.00724525194219
# lag 12 = 0.00632451139798
# lag 13 = 0.00911799085462
# lag 14 = 0.00570936839543
# lag 15 = 0.0084744696787
# lag 16 = 0.0134122944695
# lag 17 = 0.00967462831067
# lag 18 = 0.0144679070162
# lag 19 = 0.0201860980333
# lag 20 = 0.0275751215208
# lag 21 = 0.0394945617212
# lag 22 = 0.052619401527
# lag 23 = 0.0609019568902
# lag 24 = 0.0777925111879
#
#
# IOT_NXT
# lag 1 = 0.784380272602
# lag 2 = 0.839200435182
# lag 3 = 0.870289543533
# lag 4 = 0.869341081942
# lag 5 = 0.854253279091
# lag 6 = 0.759133718739
# lag 7 = 0.528688905099
# lag 8 = 0.617791649894
# lag 9 = 0.31276692583
# lag 10 = 0.388538985069
# lag 11 = 0.226370202512
# lag 12 = 0.251559520247
# lag 13 = 0.1789601361
# lag 14 = 0.219685235971
# lag 15 = 0.205534209618
# lag 16 = 0.23392727382
# lag 17 = 0.260017446634
# lag 18 = 0.287937263856
# lag 19 = 0.316365483329
# lag 20 = 0.364079345325
# lag 21 = 0.402728249971
# lag 22 = 0.275362313231
# lag 23 = 0.309713095002
# lag 24 = 0.37129926516
#
#
# IOT_BCH
# lag 1 = 0.160044783965
# lag 2 = 0.000198945087397
# lag 3 = 4.29979921369e-07
# lag 4 = 3.53851736664e-07
# lag 5 = 5.16366889845e-07
# lag 6 = 3.77014293564e-07
# lag 7 = 4.4244384832e-07
# lag 8 = 9.44787206275e-07
# lag 9 = 2.14329999246e-06
# lag 10 = 3.84551823186e-06
# lag 11 = 8.25092638574e-06
# lag 12 = 1.80223142804e-05
# lag 13 = 2.85065282787e-05
# lag 14 = 3.15620845801e-05
# lag 15 = 4.9499928051e-05
# lag 16 = 5.77469511278e-05
# lag 17 = 1.49451374773e-05
# lag 18 = 2.70958831562e-05
# lag 19 = 2.8876114433e-05
# lag 20 = 2.940465579e-05
# lag 21 = 3.30794435792e-05
# lag 22 = 5.05630013466e-05
# lag 23 = 3.04721659787e-05
# lag 24 = 2.52133404286e-05
#
#
# IOT_DASH
# lag 1 = 0.28684363098
# lag 2 = 0.433545344157
# lag 3 = 0.657601515103
# lag 4 = 0.5336024196
# lag 5 = 0.449042608878
# lag 6 = 0.589630940807
# lag 7 = 0.576630336995
# lag 8 = 0.453386534333
# lag 9 = 0.591492838116
# lag 10 = 0.531287981634
# lag 11 = 0.612985224569
# lag 12 = 0.446216847049
# lag 13 = 0.536054264094
# lag 14 = 0.50143532895
# lag 15 = 0.531640176219
# lag 16 = 0.538725012691
# lag 17 = 0.606413145984
# lag 18 = 0.641875913737
# lag 19 = 0.57844679594
# lag 20 = 0.575316279353
# lag 21 = 0.589563630205
# lag 22 = 0.568303782723
# lag 23 = 0.607910959086
# lag 24 = 0.509499881048
#
#
# IOT_LTC
# lag 1 = 0.308427248588
# lag 2 = 0.314984338456
# lag 3 = 0.465241400228
# lag 4 = 0.574492029283
# lag 5 = 0.526312550283
# lag 6 = 0.697481159843
# lag 7 = 0.586702878804
# lag 8 = 0.118891233781
# lag 9 = 0.151877750379
# lag 10 = 0.133325769543
# lag 11 = 0.129424106529
# lag 12 = 0.0249426599078
# lag 13 = 0.0337645102307
# lag 14 = 0.0296541148691
# lag 15 = 0.0344426601967
# lag 16 = 0.0492633854857
# lag 17 = 0.0473200350364
# lag 18 = 0.0607578210861
# lag 19 = 0.0258380426714
# lag 20 = 0.0202715648909
# lag 21 = 0.0205657747082
# lag 22 = 0.0133988869188
# lag 23 = 0.0157117976698
# lag 24 = 0.00493148636289
#
#
# IOT_XLM
# lag 1 = 0.75788496532
# lag 2 = 0.829994842344
# lag 3 = 0.382388387766
# lag 4 = 0.451131899809
# lag 5 = 0.593206148202
# lag 6 = 0.479796021738
# lag 7 = 0.434639375149
# lag 8 = 0.4027480527
# lag 9 = 0.276159409708
# lag 10 = 0.183968757053
# lag 11 = 0.182634659956
# lag 12 = 0.230794594753
# lag 13 = 0.257777167595
# lag 14 = 0.307163272967
# lag 15 = 0.354474439698
# lag 16 = 0.400915095737
# lag 17 = 0.443683182185
# lag 18 = 0.323875755097
# lag 19 = 0.356384351311
# lag 20 = 0.347913077167
# lag 21 = 0.354999311721
# lag 22 = 0.409180089327
# lag 23 = 0.475807249443
# lag 24 = 0.536532147105
#
#
# IOT_XRP
# lag 1 = 0.761496792796
# lag 2 = 0.887425980602
# lag 3 = 0.956188363736
# lag 4 = 0.918430959444
# lag 5 = 0.824856700507
# lag 6 = 0.889583870011
# lag 7 = 0.985313148773
# lag 8 = 0.974031592899
# lag 9 = 0.967355697641
# lag 10 = 0.982593736358
# lag 11 = 0.989406769965
# lag 12 = 0.986830611443
# lag 13 = 0.989841194622
# lag 14 = 0.991214554851
# lag 15 = 0.948946173796
# lag 16 = 0.614508397643
# lag 17 = 0.511906313706
# lag 18 = 0.461839097992
# lag 19 = 0.532743767053
# lag 20 = 0.568510473403
# lag 21 = 0.646734786865
# lag 22 = 0.585761116847
# lag 23 = 0.598273872232
# lag 24 = 0.577519252768
#
#
# IOT_XEM
# lag 1 = 0.526379527214
# lag 2 = 0.677854084117
# lag 3 = 0.317070382528
# lag 4 = 0.380728016738
# lag 5 = 0.42389229481
# lag 6 = 0.448593302303
# lag 7 = 0.655876988757
# lag 8 = 0.595161155229
# lag 9 = 0.767600806954
# lag 10 = 0.840891180711
# lag 11 = 0.457960403506
# lag 12 = 0.384226523333
# lag 13 = 0.420385032302
# lag 14 = 0.498110316269
# lag 15 = 0.522019012304
# lag 16 = 0.554042411319
# lag 17 = 0.598785919373
# lag 18 = 0.598797503574
# lag 19 = 0.604352300903
# lag 20 = 0.60640460531
# lag 21 = 0.676872721158
# lag 22 = 0.743367828085
# lag 23 = 0.711331962754
# lag 24 = 0.75113334798
#
#
# IOT_ETC
# lag 1 = 0.0821729764649
# lag 2 = 0.0976951843706
# lag 3 = 0.180338657512
# lag 4 = 0.304603189342
# lag 5 = 0.314147576971
# lag 6 = 0.463490729534
# lag 7 = 0.608096230802
# lag 8 = 0.339646849744
# lag 9 = 0.311686949726
# lag 10 = 0.397072325591
# lag 11 = 0.445259704525
# lag 12 = 0.386954930232
# lag 13 = 0.408282425408
# lag 14 = 0.0289193322898
# lag 15 = 0.0366989169834
# lag 16 = 0.0586112021413
# lag 17 = 0.0613028786472
# lag 18 = 0.0661797039176
# lag 19 = 0.0835662065149
# lag 20 = 0.0388961796659
# lag 21 = 0.0319788948882
# lag 22 = 0.039446686236
# lag 23 = 0.0427935211408
# lag 24 = 0.0513002399211
#
#
# IOT_XMR
# lag 1 = 0.410738248441
# lag 2 = 0.740499536721
# lag 3 = 0.453644489184
# lag 4 = 0.592726175536
# lag 5 = 0.60438316347
# lag 6 = 0.699662934252
# lag 7 = 0.442532506257
# lag 8 = 0.452552745347
# lag 9 = 0.414632139957
# lag 10 = 0.525648092265
# lag 11 = 0.63345024191
# lag 12 = 0.674266291196
# lag 13 = 0.73098819827
# lag 14 = 0.759962861767
# lag 15 = 0.804934474432
# lag 16 = 0.799679113364
# lag 17 = 0.805497521415
# lag 18 = 0.786078168899
# lag 19 = 0.797186677261
# lag 20 = 0.791718320226
# lag 21 = 0.433066407024
# lag 22 = 0.480838360413
# lag 23 = 0.555074411507
# lag 24 = 0.354770775699
#
#
# IOT_ZEC
# lag 1 = 0.763704783725
# lag 2 = 0.27613683843
# lag 3 = 0.377244024039
# lag 4 = 0.387748009268
# lag 5 = 0.347217037995
# lag 6 = 0.484810575094
# lag 7 = 0.544331830727
# lag 8 = 0.477012066108
# lag 9 = 0.637588389935
# lag 10 = 0.672737715128
# lag 11 = 0.704070449413
# lag 12 = 0.0366168779408
# lag 13 = 0.0549017080616
# lag 14 = 0.0720318456043
# lag 15 = 0.107221332
# lag 16 = 0.131714224836
# lag 17 = 0.122943872382
# lag 18 = 0.115561325083
# lag 19 = 0.145839771671
# lag 20 = 0.174838699527
# lag 21 = 0.205601888633
# lag 22 = 0.232623488716
# lag 23 = 0.17982324034
# lag 24 = 0.0632285723498

# %%
# Printing top correlated coins results

# Manually gone through the test results to identify these pairs.
top = ['NXT_LTC', 'NXT_IOT', 'BCH_ETC', 'XEM_NXT', 'XEM_LTC', 'XEM_ETH', 'XEM_IOT', 'DASH_BCH', 'XMR_BCH', 'XMR_DASH', 'ZEC_DASH']
#rep = ['NXT_LTC', 'XEM_NXT', 'XEM_LTC', 'XEM_IOT']
#new = ['NXT_ETC', 'XEM_ETC', 'XEM_BTC', 'XEM_DASH','DASH_LTC', 'DASH_IOT']
for key, values in cor.items():
    if key in top:
        print('\n')
        print('\033[1m' + key + '\033[0m')
        for i in range(1, lag+1):
            print('lag', i, '=', values[i][0]['lrtest'][1])
# Out:
# NXT_LTC
# lag 1 = 3.58498047098e-11
# lag 2 = 1.93941607242e-12
# lag 3 = 1.1887229165e-13
# lag 4 = 9.49020598167e-14
# lag 5 = 5.09592784482e-13
# lag 6 = 1.27389503811e-12
# lag 7 = 1.03066336673e-12
# lag 8 = 2.27943342847e-12
# lag 9 = 3.48405255351e-12
# lag 10 = 3.52696377913e-12
# lag 11 = 4.80797144466e-12
# lag 12 = 7.80533581529e-12
# lag 13 = 4.32535046338e-12
# lag 14 = 3.31829080928e-12
# lag 15 = 5.23359457488e-12
# lag 16 = 1.45563813851e-11
# lag 17 = 3.46744532129e-12
# lag 18 = 6.05432006909e-12
# lag 19 = 1.07563492835e-11
# lag 20 = 3.11311316205e-12
# lag 21 = 6.42203781551e-12
# lag 22 = 1.15764517678e-11
# lag 23 = 1.23749021054e-11
# lag 24 = 7.13622427179e-12
#
#
# NXT_IOT
# lag 1 = 8.19711665904e-06
# lag 2 = 1.33436060887e-07
# lag 3 = 2.10174468448e-08
# lag 4 = 1.70763805933e-09
# lag 5 = 1.07076178181e-09
# lag 6 = 8.09520901349e-10
# lag 7 = 1.25321589935e-09
# lag 8 = 1.64657914273e-09
# lag 9 = 5.79912874427e-10
# lag 10 = 1.16146906041e-09
# lag 11 = 8.35747756915e-10
# lag 12 = 6.14152368771e-10
# lag 13 = 8.18944852689e-10
# lag 14 = 1.13039243439e-09
# lag 15 = 2.86906475974e-09
# lag 16 = 1.63674368316e-09
# lag 17 = 2.38456680998e-09
# lag 18 = 2.11259766211e-09
# lag 19 = 4.68900556369e-09
# lag 20 = 5.06867427501e-09
# lag 21 = 8.21137397002e-09
# lag 22 = 9.38806409321e-09
# lag 23 = 1.98471619397e-08
# lag 24 = 2.95066738044e-08
#
#
# BCH_ETC
# lag 1 = 9.40963804026e-06
# lag 2 = 1.16622153578e-07
# lag 3 = 1.04212932104e-08
# lag 4 = 1.41973764944e-09
# lag 5 = 2.8302698495e-09
# lag 6 = 3.26555936127e-10
# lag 7 = 5.29022881169e-12
# lag 8 = 1.57285929914e-11
# lag 9 = 4.26625561631e-11
# lag 10 = 1.78060100073e-11
# lag 11 = 1.03483822732e-10
# lag 12 = 3.52727823206e-10
# lag 13 = 1.00898673776e-15
# lag 14 = 3.21914316854e-19
# lag 15 = 2.39384195298e-19
# lag 16 = 1.74610142382e-20
# lag 17 = 5.46446775544e-20
# lag 18 = 5.4263973391e-21
# lag 19 = 2.61569298851e-24
# lag 20 = 1.03397731132e-23
# lag 21 = 1.0439543244e-23
# lag 22 = 7.05227266907e-24
# lag 23 = 1.7208821037e-23
# lag 24 = 7.69662922661e-23
#
#
# DASH_BCH
# lag 1 = 1.52083151218e-17
# lag 2 = 3.63644432184e-17
# lag 3 = 1.67095123953e-16
# lag 4 = 4.90483439663e-16
# lag 5 = 1.15978023647e-15
# lag 6 = 5.44605686729e-18
# lag 7 = 4.60971101494e-33
# lag 8 = 1.94843247044e-50
# lag 9 = 2.9413085455e-54
# lag 10 = 1.73971567408e-56
# lag 11 = 6.01229080873e-65
# lag 12 = 3.17965480215e-72
# lag 13 = 3.04399533847e-73
# lag 14 = 1.51790183741e-77
# lag 15 = 2.46644885141e-83
# lag 16 = 6.34241139263e-84
# lag 17 = 7.84545094237e-90
# lag 18 = 7.20790500329e-90
# lag 19 = 5.5378838633e-90
# lag 20 = 7.10925095315e-91
# lag 21 = 3.07955543006e-90
# lag 22 = 3.81113067167e-92
# lag 23 = 1.49897952299e-95
# lag 24 = 1.05186087273e-96
#
#
# XEM_NXT
# lag 1 = 1.99363329723e-06
# lag 2 = 4.13824863965e-07
# lag 3 = 9.97326035914e-10
# lag 4 = 1.29044593777e-11
# lag 5 = 1.28800434626e-13
# lag 6 = 8.24048890787e-14
# lag 7 = 6.11321208973e-16
# lag 8 = 4.76809608947e-16
# lag 9 = 1.36463290736e-15
# lag 10 = 1.42489233679e-15
# lag 11 = 4.47638129351e-15
# lag 12 = 4.88629676636e-15
# lag 13 = 1.80279917201e-14
# lag 14 = 1.62460456872e-14
# lag 15 = 3.74305048388e-14
# lag 16 = 4.80423870546e-14
# lag 17 = 3.06390399657e-14
# lag 18 = 7.32694914007e-14
# lag 19 = 7.51847128974e-14
# lag 20 = 8.43530855377e-14
# lag 21 = 6.41130400386e-14
# lag 22 = 8.58079417489e-15
# lag 23 = 3.92617076443e-15
# lag 24 = 2.23158195295e-15
#
#
# XEM_LTC
# lag 1 = 2.10991244056e-12
# lag 2 = 4.78326894172e-13
# lag 3 = 1.0689878953e-14
# lag 4 = 1.58556078633e-15
# lag 5 = 9.8175660121e-17
# lag 6 = 2.6739825779e-16
# lag 7 = 1.10962366026e-17
# lag 8 = 3.7080382875e-17
# lag 9 = 1.60883967562e-16
# lag 10 = 5.16959661208e-16
# lag 11 = 1.82605836983e-15
# lag 12 = 2.86069625296e-15
# lag 13 = 7.02385796218e-15
# lag 14 = 1.53543533233e-14
# lag 15 = 1.83273481567e-14
# lag 16 = 4.97683126974e-14
# lag 17 = 8.76241568222e-14
# lag 18 = 5.86106766505e-14
# lag 19 = 2.0813659111e-13
# lag 20 = 3.14223719599e-14
# lag 21 = 1.77741544471e-14
# lag 22 = 9.10678483469e-14
# lag 23 = 2.29208045075e-14
# lag 24 = 2.09908347012e-15
#
#
# XEM_IOT
# lag 1 = 3.83681512368e-09
# lag 2 = 1.92904837518e-11
# lag 3 = 5.1478124346e-15
# lag 4 = 5.81509882111e-15
# lag 5 = 1.1415857175e-15
# lag 6 = 1.28751116274e-15
# lag 7 = 1.74809909001e-18
# lag 8 = 4.33098501036e-20
# lag 9 = 3.02590521519e-20
# lag 10 = 1.42397256753e-19
# lag 11 = 2.83474350464e-19
# lag 12 = 6.34016788422e-19
# lag 13 = 2.52831592222e-18
# lag 14 = 4.22384998328e-18
# lag 15 = 9.55771994221e-18
# lag 16 = 2.61965044188e-17
# lag 17 = 7.82425633563e-18
# lag 18 = 5.8377678284e-18
# lag 19 = 8.48249798015e-18
# lag 20 = 2.53097517884e-17
# lag 21 = 1.23592937701e-17
# lag 22 = 2.40768661637e-17
# lag 23 = 5.21937937883e-17
# lag 24 = 1.64182518872e-16
#
#
# XMR_BCH
# lag 1 = 0.00027800724063
# lag 2 = 3.45695899142e-08
# lag 3 = 1.15447791989e-07
# lag 4 = 4.30594365901e-07
# lag 5 = 2.82747001816e-06
# lag 6 = 2.64494750151e-06
# lag 7 = 1.86117649678e-08
# lag 8 = 4.21659385987e-10
# lag 9 = 1.72796473527e-19
# lag 10 = 1.60023288321e-19
# lag 11 = 4.65132972244e-20
# lag 12 = 9.35893848884e-20
# lag 13 = 7.45458685086e-21
# lag 14 = 3.13551844493e-20
# lag 15 = 5.18360376989e-21
# lag 16 = 2.86218924605e-22
# lag 17 = 1.27160756994e-22
# lag 18 = 3.54498950943e-22
# lag 19 = 1.28073303789e-22
# lag 20 = 1.78041756443e-22
# lag 21 = 2.52735986946e-22
# lag 22 = 1.61080092655e-24
# lag 23 = 2.44017572678e-24
# lag 24 = 9.44029083036e-24
#
#
# XMR_DASH
# lag 1 = 1.44313554407e-09
# lag 2 = 1.75492008652e-09
# lag 3 = 5.9226083691e-09
# lag 4 = 2.01914093098e-08
# lag 5 = 4.50446369055e-08
# lag 6 = 8.48602963188e-08
# lag 7 = 2.39647504579e-07
# lag 8 = 1.14006529245e-07
# lag 9 = 5.3218814163e-07
# lag 10 = 9.50809107451e-08
# lag 11 = 1.43257372819e-07
# lag 12 = 5.49668991784e-07
# lag 13 = 1.17473558179e-06
# lag 14 = 7.44601444335e-07
# lag 15 = 1.20006407896e-08
# lag 16 = 8.39081875146e-09
# lag 17 = 1.5553619062e-09
# lag 18 = 9.89982441252e-11
# lag 19 = 3.76822452336e-11
# lag 20 = 1.33503928802e-11
# lag 21 = 5.757487722e-12
# lag 22 = 2.35744238505e-12
# lag 23 = 4.28516609759e-12
# lag 24 = 1.12769722378e-11
#
#
# ZEC_DASH
# lag 1 = 6.78755667152e-11
# lag 2 = 5.69287779179e-10
# lag 3 = 1.13906286079e-09
# lag 4 = 3.48334557994e-10
# lag 5 = 1.46074088805e-11
# lag 6 = 1.06117345441e-11
# lag 7 = 3.36999655355e-11
# lag 8 = 1.06829415957e-10
# lag 9 = 2.08294173502e-15
# lag 10 = 2.99690594818e-15
# lag 11 = 7.53760129725e-16
# lag 12 = 2.38375771791e-15
# lag 13 = 4.6133619478e-15
# lag 14 = 3.00891751299e-15
# lag 15 = 1.6836165326e-15
# lag 16 = 5.62474156735e-15
# lag 17 = 1.67717454007e-14
# lag 18 = 4.09515274532e-14
# lag 19 = 6.85435773033e-14
# lag 20 = 1.96705622586e-13
# lag 21 = 3.71563272719e-13
# lag 22 = 1.08683493845e-12
# lag 23 = 8.1086298749e-13
# lag 24 = 7.94509381755e-13

# %%
# Scaling and visualizing XEM_IOT

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
df_plot = pd.DataFrame(index=df.index)
df_plot['XEM'] = sc_x.fit_transform(df['XEM'].values.reshape(-1,1))
df_plot['IOT'] = sc_x.fit_transform(df['IOT'].values.reshape(-1,1))

# Plot 1- scaled overlay plot of DASH/ETH prices 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.plot(df.index, df_plot['XEM'], color='blue')
plt.plot(df.index, df_plot['IOT'], color='green')
#plt.xlim(('2017-09-15', '2017-10-15'))
plt.ylim((-4, 4))
plt.legend(loc='lower left')
plt.xlabel('Time')
plt.ylabel('Prices (scaled)')
plt.title('XEM/IOT Prices over Time')
plt.show()

# %%
# Performing Granger Test on XEM_IOT, with maxlag = 50

highest_cor = sm.grangercausalitytests(XEM_IOT, 50)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=34.9553 , p=0.0000  , df_denom=1996, df_num=1
# ssr based chi2 test:   chi2=35.0078 , p=0.0000  , df=1
# likelihood ratio test: chi2=34.7048 , p=0.0000  , df=1
# parameter F test:         F=34.9553 , p=0.0000  , df_denom=1996, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=24.9161 , p=0.0000  , df_denom=1993, df_num=2
# ssr based chi2 test:   chi2=49.9572 , p=0.0000  , df=2
# likelihood ratio test: chi2=49.3428 , p=0.0000  , df=2
# parameter F test:         F=24.9161 , p=0.0000  , df_denom=1993, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=23.5332 , p=0.0000  , df_denom=1990, df_num=3
# ssr based chi2 test:   chi2=70.8478 , p=0.0000  , df=3
# likelihood ratio test: chi2=69.6200 , p=0.0000  , df=3
# parameter F test:         F=23.5332 , p=0.0000  , df_denom=1990, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=18.4524 , p=0.0000  , df_denom=1987, df_num=4
# ssr based chi2 test:   chi2=74.1439 , p=0.0000  , df=4
# likelihood ratio test: chi2=72.8000 , p=0.0000  , df=4
# parameter F test:         F=18.4524 , p=0.0000  , df_denom=1987, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=16.1029 , p=0.0000  , df_denom=1984, df_num=5
# ssr based chi2 test:   chi2=80.9607 , p=0.0000  , df=5
# likelihood ratio test: chi2=79.3610 , p=0.0000  , df=5
# parameter F test:         F=16.1029 , p=0.0000  , df_denom=1984, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=13.8855 , p=0.0000  , df_denom=1981, df_num=6
# ssr based chi2 test:   chi2=83.8600 , p=0.0000  , df=6
# likelihood ratio test: chi2=82.1445 , p=0.0000  , df=6
# parameter F test:         F=13.8855 , p=0.0000  , df_denom=1981, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=14.3886 , p=0.0000  , df_denom=1978, df_num=7
# ssr based chi2 test:   chi2=101.4839, p=0.0000  , df=7
# likelihood ratio test: chi2=98.9846 , p=0.0000  , df=7
# parameter F test:         F=14.3886 , p=0.0000  , df_denom=1978, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=13.9804 , p=0.0000  , df_denom=1975, df_num=8
# ssr based chi2 test:   chi2=112.8061, p=0.0000  , df=8
# likelihood ratio test: chi2=109.7277, p=0.0000  , df=8
# parameter F test:         F=13.9804 , p=0.0000  , df_denom=1975, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=12.8384 , p=0.0000  , df_denom=1972, df_num=9
# ssr based chi2 test:   chi2=116.6589, p=0.0000  , df=9
# likelihood ratio test: chi2=113.3691, p=0.0000  , df=9
# parameter F test:         F=12.8384 , p=0.0000  , df_denom=1972, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=11.4878 , p=0.0000  , df_denom=1969, df_num=10
# ssr based chi2 test:   chi2=116.1029, p=0.0000  , df=10
# likelihood ratio test: chi2=112.8422, p=0.0000  , df=10
# parameter F test:         F=11.4878 , p=0.0000  , df_denom=1969, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=10.5479 , p=0.0000  , df_denom=1966, df_num=11
# ssr based chi2 test:   chi2=117.3848, p=0.0000  , df=11
# likelihood ratio test: chi2=114.0515, p=0.0000  , df=11
# parameter F test:         F=10.5479 , p=0.0000  , df_denom=1966, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=9.7348  , p=0.0000  , df_denom=1963, df_num=12
# ssr based chi2 test:   chi2=118.3053, p=0.0000  , df=12
# likelihood ratio test: chi2=114.9188, p=0.0000  , df=12
# parameter F test:         F=9.7348  , p=0.0000  , df_denom=1963, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=8.9372  , p=0.0000  , df_denom=1960, df_num=13
# ssr based chi2 test:   chi2=117.7845, p=0.0000  , df=13
# likelihood ratio test: chi2=114.4256, p=0.0000  , df=13
# parameter F test:         F=8.9372  , p=0.0000  , df_denom=1960, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=8.3906  , p=0.0000  , df_denom=1957, df_num=14
# ssr based chi2 test:   chi2=119.2098, p=0.0000  , df=14
# likelihood ratio test: chi2=115.7691, p=0.0000  , df=14
# parameter F test:         F=8.3906  , p=0.0000  , df_denom=1957, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=7.8651  , p=0.0000  , df_denom=1954, df_num=15
# ssr based chi2 test:   chi2=119.8476, p=0.0000  , df=15
# likelihood ratio test: chi2=116.3689, p=0.0000  , df=15
# parameter F test:         F=7.8651  , p=0.0000  , df_denom=1954, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=7.3722  , p=0.0000  , df_denom=1951, df_num=16
# ssr based chi2 test:   chi2=119.9509, p=0.0000  , df=16
# likelihood ratio test: chi2=116.4647, p=0.0000  , df=16
# parameter F test:         F=7.3722  , p=0.0000  , df_denom=1951, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=7.2433  , p=0.0000  , df_denom=1948, df_num=17
# ssr based chi2 test:   chi2=125.3478, p=0.0000  , df=17
# likelihood ratio test: chi2=121.5456, p=0.0000  , df=17
# parameter F test:         F=7.2433  , p=0.0000  , df_denom=1948, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=7.0068  , p=0.0000  , df_denom=1945, df_num=18
# ssr based chi2 test:   chi2=128.5222, p=0.0000  , df=18
# likelihood ratio test: chi2=124.5270, p=0.0000  , df=18
# parameter F test:         F=7.0068  , p=0.0000  , df_denom=1945, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=6.7094  , p=0.0000  , df_denom=1942, df_num=19
# ssr based chi2 test:   chi2=130.0394, p=0.0000  , df=19
# likelihood ratio test: chi2=125.9493, p=0.0000  , df=19
# parameter F test:         F=6.7094  , p=0.0000  , df_denom=1942, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=6.3522  , p=0.0000  , df_denom=1939, df_num=20
# ssr based chi2 test:   chi2=129.7308, p=0.0000  , df=20
# likelihood ratio test: chi2=125.6578, p=0.0000  , df=20
# parameter F test:         F=6.3522  , p=0.0000  , df_denom=1939, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=6.2364  , p=0.0000  , df_denom=1936, df_num=21
# ssr based chi2 test:   chi2=133.8740, p=0.0000  , df=21
# likelihood ratio test: chi2=129.5403, p=0.0000  , df=21
# parameter F test:         F=6.2364  , p=0.0000  , df_denom=1936, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=5.9763  , p=0.0000  , df_denom=1933, df_num=22
# ssr based chi2 test:   chi2=134.5398, p=0.0000  , df=22
# likelihood ratio test: chi2=130.1617, p=0.0000  , df=22
# parameter F test:         F=5.9763  , p=0.0000  , df_denom=1933, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=5.7252  , p=0.0000  , df_denom=1930, df_num=23
# ssr based chi2 test:   chi2=134.8858, p=0.0000  , df=23
# likelihood ratio test: chi2=130.4835, p=0.0000  , df=23
# parameter F test:         F=5.7252  , p=0.0000  , df_denom=1930, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=5.4541  , p=0.0000  , df_denom=1927, df_num=24
# ssr based chi2 test:   chi2=134.2264, p=0.0000  , df=24
# likelihood ratio test: chi2=129.8640, p=0.0000  , df=24
# parameter F test:         F=5.4541  , p=0.0000  , df_denom=1927, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=5.3378  , p=0.0000  , df_denom=1924, df_num=25
# ssr based chi2 test:   chi2=136.9810, p=0.0000  , df=25
# likelihood ratio test: chi2=132.4395, p=0.0000  , df=25
# parameter F test:         F=5.3378  , p=0.0000  , df_denom=1924, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=5.0929  , p=0.0000  , df_denom=1921, df_num=26
# ssr based chi2 test:   chi2=136.0689, p=0.0000  , df=26
# likelihood ratio test: chi2=131.5842, p=0.0000  , df=26
# parameter F test:         F=5.0929  , p=0.0000  , df_denom=1921, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=4.8876  , p=0.0000  , df_denom=1918, df_num=27
# ssr based chi2 test:   chi2=135.7505, p=0.0000  , df=27
# likelihood ratio test: chi2=131.2841, p=0.0000  , df=27
# parameter F test:         F=4.8876  , p=0.0000  , df_denom=1918, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=4.8144  , p=0.0000  , df_denom=1915, df_num=28
# ssr based chi2 test:   chi2=138.8145, p=0.0000  , df=28
# likelihood ratio test: chi2=134.1465, p=0.0000  , df=28
# parameter F test:         F=4.8144  , p=0.0000  , df_denom=1915, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=4.6453  , p=0.0000  , df_denom=1912, df_num=29
# ssr based chi2 test:   chi2=138.8704, p=0.0000  , df=29
# likelihood ratio test: chi2=134.1965, p=0.0000  , df=29
# parameter F test:         F=4.6453  , p=0.0000  , df_denom=1912, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=4.4732  , p=0.0000  , df_denom=1909, df_num=30
# ssr based chi2 test:   chi2=138.4838, p=0.0000  , df=30
# likelihood ratio test: chi2=133.8331, p=0.0000  , df=30
# parameter F test:         F=4.4732  , p=0.0000  , df_denom=1909, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=4.4060  , p=0.0000  , df_denom=1906, df_num=31
# ssr based chi2 test:   chi2=141.1003, p=0.0000  , df=31
# likelihood ratio test: chi2=136.2739, p=0.0000  , df=31
# parameter F test:         F=4.4060  , p=0.0000  , df_denom=1906, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=4.2612  , p=0.0000  , df_denom=1903, df_num=32
# ssr based chi2 test:   chi2=141.0157, p=0.0000  , df=32
# likelihood ratio test: chi2=136.1926, p=0.0000  , df=32
# parameter F test:         F=4.2612  , p=0.0000  , df_denom=1903, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=4.2511  , p=0.0000  , df_denom=1900, df_num=33
# ssr based chi2 test:   chi2=145.2336, p=0.0000  , df=33
# likelihood ratio test: chi2=140.1220, p=0.0000  , df=33
# parameter F test:         F=4.2511  , p=0.0000  , df_denom=1900, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=3.9654  , p=0.0000  , df_denom=1897, df_num=34
# ssr based chi2 test:   chi2=139.7290, p=0.0000  , df=34
# likelihood ratio test: chi2=134.9869, p=0.0000  , df=34
# parameter F test:         F=3.9654  , p=0.0000  , df_denom=1897, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=3.8586  , p=0.0000  , df_denom=1894, df_num=35
# ssr based chi2 test:   chi2=140.1144, p=0.0000  , df=35
# likelihood ratio test: chi2=135.3444, p=0.0000  , df=35
# parameter F test:         F=3.8586  , p=0.0000  , df_denom=1894, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=3.2095  , p=0.0000  , df_denom=1891, df_num=36
# ssr based chi2 test:   chi2=120.0014, p=0.0000  , df=36
# likelihood ratio test: chi2=116.4781, p=0.0000  , df=36
# parameter F test:         F=3.2095  , p=0.0000  , df_denom=1891, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=3.1232  , p=0.0000  , df_denom=1888, df_num=37
# ssr based chi2 test:   chi2=120.1476, p=0.0000  , df=37
# likelihood ratio test: chi2=116.6142, p=0.0000  , df=37
# parameter F test:         F=3.1232  , p=0.0000  , df_denom=1888, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=3.0615  , p=0.0000  , df_denom=1885, df_num=38
# ssr based chi2 test:   chi2=121.0892, p=0.0000  , df=38
# likelihood ratio test: chi2=117.4995, p=0.0000  , df=38
# parameter F test:         F=3.0615  , p=0.0000  , df_denom=1885, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=2.9952  , p=0.0000  , df_denom=1882, df_num=39
# ssr based chi2 test:   chi2=121.7151, p=0.0000  , df=39
# likelihood ratio test: chi2=118.0871, p=0.0000  , df=39
# parameter F test:         F=2.9952  , p=0.0000  , df_denom=1882, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=2.8918  , p=0.0000  , df_denom=1879, df_num=40
# ssr based chi2 test:   chi2=120.6586, p=0.0000  , df=40
# likelihood ratio test: chi2=117.0904, p=0.0000  , df=40
# parameter F test:         F=2.8918  , p=0.0000  , df_denom=1879, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=2.8033  , p=0.0000  , df_denom=1876, df_num=41
# ssr based chi2 test:   chi2=120.0208, p=0.0000  , df=41
# likelihood ratio test: chi2=116.4878, p=0.0000  , df=41
# parameter F test:         F=2.8033  , p=0.0000  , df_denom=1876, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=2.7615  , p=0.0000  , df_denom=1873, df_num=42
# ssr based chi2 test:   chi2=121.2484, p=0.0000  , df=42
# likelihood ratio test: chi2=117.6423, p=0.0000  , df=42
# parameter F test:         F=2.7615  , p=0.0000  , df_denom=1873, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=2.6695  , p=0.0000  , df_denom=1870, df_num=43
# ssr based chi2 test:   chi2=120.1299, p=0.0000  , df=43
# likelihood ratio test: chi2=116.5871, p=0.0000  , df=43
# parameter F test:         F=2.6695  , p=0.0000  , df_denom=1870, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=2.6547  , p=0.0000  , df_denom=1867, df_num=44
# ssr based chi2 test:   chi2=122.3731, p=0.0000  , df=44
# likelihood ratio test: chi2=118.6976, p=0.0000  , df=44
# parameter F test:         F=2.6547  , p=0.0000  , df_denom=1867, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=2.6102  , p=0.0000  , df_denom=1864, df_num=45
# ssr based chi2 test:   chi2=123.1940, p=0.0000  , df=45
# likelihood ratio test: chi2=119.4682, p=0.0000  , df=45
# parameter F test:         F=2.6102  , p=0.0000  , df_denom=1864, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=2.5345  , p=0.0000  , df_denom=1861, df_num=46
# ssr based chi2 test:   chi2=122.4124, p=0.0000  , df=46
# likelihood ratio test: chi2=118.7310, p=0.0000  , df=46
# parameter F test:         F=2.5345  , p=0.0000  , df_denom=1861, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=2.5516  , p=0.0000  , df_denom=1858, df_num=47
# ssr based chi2 test:   chi2=126.0554, p=0.0000  , df=47
# likelihood ratio test: chi2=122.1543, p=0.0000  , df=47
# parameter F test:         F=2.5516  , p=0.0000  , df_denom=1858, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=2.5391  , p=0.0000  , df_denom=1855, df_num=48
# ssr based chi2 test:   chi2=128.2491, p=0.0000  , df=48
# likelihood ratio test: chi2=124.2119, p=0.0000  , df=48
# parameter F test:         F=2.5391  , p=0.0000  , df_denom=1855, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=2.4898  , p=0.0000  , df_denom=1852, df_num=49
# ssr based chi2 test:   chi2=128.5211, p=0.0000  , df=49
# likelihood ratio test: chi2=124.4651, p=0.0000  , df=49
# parameter F test:         F=2.4898  , p=0.0000  , df_denom=1852, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=2.4723  , p=0.0000  , df_denom=1849, df_num=50
# ssr based chi2 test:   chi2=130.3691, p=0.0000  , df=50
# likelihood ratio test: chi2=126.1961, p=0.0000  , df=50
# parameter F test:         F=2.4723  , p=0.0000  , df_denom=1849, df_num=50

# %%
# XEM_IOT Grenger Test results
for key, values in highest_cor.items():
        print('lag', key, '=', values[0]['lrtest'][1])
# Out:
# lag 1 = 3.83681512368e-09
# lag 2 = 1.92904837518e-11
# lag 3 = 5.1478124346e-15
# lag 4 = 5.81509882111e-15
# lag 5 = 1.1415857175e-15
# lag 6 = 1.28751116274e-15
# lag 7 = 1.74809909001e-18
# lag 8 = 4.33098501036e-20
# lag 9 = 3.02590521519e-20
# lag 10 = 1.42397256753e-19
# lag 11 = 2.83474350464e-19
# lag 12 = 6.34016788422e-19
# lag 13 = 2.52831592222e-18
# lag 14 = 4.22384998328e-18
# lag 15 = 9.55771994221e-18
# lag 16 = 2.61965044188e-17
# lag 17 = 7.82425633563e-18
# lag 18 = 5.8377678284e-18
# lag 19 = 8.48249798015e-18
# lag 20 = 2.53097517884e-17
# lag 21 = 1.23592937701e-17
# lag 22 = 2.40768661637e-17
# lag 23 = 5.21937937883e-17
# lag 24 = 1.64182518872e-16
# lag 25 = 1.34122725997e-16
# lag 26 = 4.47038275736e-16
# lag 27 = 1.15762794224e-15
# lag 28 = 8.18534818147e-16
# lag 29 = 1.78791001789e-15
# lag 30 = 4.52317469851e-15
# lag 31 = 3.71150878438e-15
# lag 32 = 8.1726343506e-15
# lag 33 = 3.70713895096e-15
# lag 34 = 5.63053091229e-14
# lag 35 = 9.95926378485e-14
# lag 36 = 2.04417521232e-10
# lag 37 = 3.57041592843e-10
# lag 38 = 4.73767391217e-10
# lag 39 = 6.92204214687e-10
# lag 40 = 1.72534724113e-09
# lag 41 = 3.68392238165e-09
# lag 42 = 4.30495447536e-09
# lag 43 = 1.0386097669e-08
# lag 44 = 8.75755177041e-09
# lag 45 = 1.14126585029e-08
# lag 46 = 2.39688561511e-08
# lag 47 = 1.32136727098e-08
# lag 48 = 1.12761222235e-08
# lag 49 = 1.70409928143e-08
# lag 50 = 1.6073737401e-08

# %%
#XEM_IOT.to_csv('xem_iot.csv')

# %% [markdown]
# ### Conclusions:
# We performed Granger Causality Test on all of the 132 possible pairs contructed from the 12 "most popular" coins. DASH_BCH was previously selected as the cointegrated pair with the strongest correlation. However, with further research, we found out that the strong correlation was due to surge in Korean trading. Therefore, we instead picked XEM_IOT as our cointegrated pair since it has the strongest correlation under normal condition. For the purpose of this project, IOT historical prices will be used as one of XEM price predictors in a machine learning model.
